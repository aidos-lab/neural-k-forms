# %% [markdown]
# # De Rham Neural Networks

# %% [markdown]
# In this notebook, we develop a few examples of simple De Rham Neural Networks.

# %%
import numpy as np
import matplotlib as mpl
import torch
import torch.nn as nn
from matplotlib import pyplot as plt
from matplotlib import colors as mcolors

# %% [markdown]
# ## 1-form Simplicial Representation Learning: Vector Fields

# %% [markdown]
# As a first example, we will consider vector fields over $\mathbb{R}^2$. $1$-forms, which are in bijection with and dual to vector fields, can be written in the form:
# $\begin{equation} \omega = f_x(x,y) dx + f_y(x,y) dy \end{equation}$ where both $f_x$ and $f_y$ are functions from $\mathbb{R}^2$ to $\mathbb{R}$. By the identification
# $ \begin{equation} \mathsf{Hom}(\mathbb{R}^2, \mathbb{R}) \oplus  \mathsf{Hom}(\mathbb{R}^2, \mathbb{R}) \cong \mathsf{Hom}(\mathbb{R}^2, \mathbb{R}^2)  \end{equation}$ we can represent a $1$-form as a single function from $\mathbb{R}^2 \to \mathbb{R}^2$. To learn such a function, we define a simple MLP below which goes from $\mathbb{R}^2 \to \mathbb{R}^2$.

# %%
import torch
import torch.nn as nn
 
c = 6 # number of features/columns in cochain data matrix

vf = nn.Sequential(
    nn.Linear(2, 2*c)
)

# %% [markdown]
# To drive home the fact that the above MLP actually defines a vector field, we can plot it. The 'tangent vector' at each point $(x,y) \in \mathbb{R}^2$ is the vector given by
# $\begin{equation}  (f_x(x,y),f_y(x,y)) \end{equation}$ which corresponds to the MLP above via
# $\begin{equation} f_x(x,y) = \pi_x \circ \text{vf.forward}(x,y) \end{equation}$ and $\begin{equation} f_y(x,y) = \pi_y \circ \text{vf.forward}(x,y). \end{equation}$

# %%
## plot a vector field given a function f: R^2 -> R^2
def plot_component_vf(f, ax, comp = 0, x_range=5, y_range=5):

    x = np.linspace(-x_range,x_range,20)
    y = np.linspace(-y_range,y_range,20)
    X,Y = np.meshgrid(x,y)

    X = torch.tensor(X).double()
    Y = torch.tensor(Y).double()


    U = np.zeros((20,20))
    V = np.zeros((20,20))
    for i in range(20):
        for j in range(20):
            inp = np.array([X[i,j],Y[i,j]])
            inp = torch.tensor(inp).float()

            tv = f.forward(inp).reshape(2,c)

            U[i,j] = tv[:,comp][0]
            V[i,j] = tv[:,comp][1]
    ax.quiver(X,Y,U,V)

fig, ax = plt.subplots()

# make a figure with 6 subplots arranged in 2 rows and 3 columns
for i in range(c):
    ax = plt.subplot(2, 3, i+1)
    plot_component_vf(vf, ax, comp = i, x_range=10, y_range=10)


# add a title to the figure
fig.suptitle('Initialised feature vector fields')


plt.show()
# Out:
# /var/folders/w2/2q_ql79j5_s6kq_b56rg9xdc0000gn/T/ipykernel_973/2424882568.py:29: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   ax = plt.subplot(2, 3, i+1)

# %% [markdown]
# ## Integrating Paths Agains Vector Fields

# %%
# a function for turning a path into a chain
def path_to_chain(p):
    """  
    A function for turning a path into a chain

    Parameters
    ----------
    p : numpy array
        A path in R^n, represented as a numpy array of shape (p,n), where p is the number of points in the path

    Returns
    -------
    chain : numpy array
        A chain in R^n, represented as a numpy array of shape (p-1,2,n), where p is the number of points in the path.
        The middle index corresponds to start and endpoints of the edges in the chain.
    """

    r = len(p) - 1

    n = p[0].shape[0]
    
    
    chain = torch.zeros((r,2,n))

    chain[:,1,:] = torch.tensor(p[1:,:])
    chain[:,0,:] = torch.tensor(p[0:-1,:])

    return chain

    
# a function for turning a chain into a discretized chain
def discretize_chain(chain,d):
    """ 
    A function for turning a chain into a discretized chain

    Parameters
    ----------
    chain : numpy array
        A chain in R^n, represented as a numpy array of shape (p-1,2,n), where p is the number of points in the path.

    d : int
        The number of points in the discretized chain

    Returns
    -------
    d_chain : numpy array
        A discretized chain in R^n, represented as a numpy array of shape (p-1,d,n), where p is the number of points in the path.

    """

    r = chain.shape[0]

    n = chain.shape[2]

    d_chain = torch.zeros((r,d,n))

    t = np.linspace(0,1,d)

    for i in range(d):

        d_chain[:,i,:] = (1-t[i]) * chain[:,0,:] + t[i] * chain[:,1,:] 

    return d_chain

# %%
# a function for turning a chain into a cochain data matrix
def gen_CDM2(vf,chain, d = 5):
    """
    A function for generating a cochain data matrix from a chain and a vector field

    Parameters
    ----------
    vf : a Pytorch Sequential object
        The vector field to be applied to the chain
    
    \chain : a torch tensor of shape (r,2,n)
        The chain to be turned into a cochain data matrix

    d : int
        The number of discrete steps in the discretization of the chain
    
    Returns
    -------
    out : a torch tensor of shape (r,c)
        The cochain data matrix
    """

    
    # discretize the chain
    chain = discretize_chain(chain, d)

    # number of simplicies
    r = chain.shape[0]

    # number of discrete steps
    d = chain.shape[1]

    # dimension of ambient space
    n = chain.shape[2]

    # number of feature-cochains in the cochain data matrix
    c = int(vf[-1].out_features / n)

    # apply the vector field to the discretized chain
    out = vf(chain).reshape((r,d,n,c))

    # calculate the simplex gradients
    simplex_grad = chain[:,1,:] - chain[:,0,:]

    # swap dimensions n and c in out
    out = out.permute(0,1,3,2)

    # calculate the inner product of the vector field and the simplex gradients at each discrete step on each simplex
    inner_prod = torch.matmul(out,simplex_grad.T/(d-1))

    # take diagonal of out3 along axis 0 and 3 (this corresponds to correcting the broadcasted multplication effect)
    inner_prod = torch.diagonal(inner_prod, dim1 = 0, dim2 = 3)

    # permute dimensions 0 and 2 of out4
    inner_prod = inner_prod.permute(2,0,1)

    # apply the trapzoidal rule to the inner product
    cdm = (inner_prod[:,1:,:] + inner_prod[:,0:-1,:])/2
    cdm = cdm.sum(axis = 1)

    return cdm

# %% [markdown]
# ### Synthetic Dataset of paths

# %%
## plot a set of points and connect consecutive points with lines
def plot_points(points, ax, color = 'black', alpha = 1, linewidth = 1):

    n = points.shape[0]

    for i in range(n-1):
        ax.plot(points[i:i+2,0],points[i:i+2,1], color = color, alpha = alpha, linewidth = linewidth)

    return ax

# %%
def generate_diagonal_paths(num_paths=100,eps = 0.02, num_pts = 50):
    
    Paths = []
    for i in range(num_paths): 
        x = np.sort(np.random.uniform(low=-1, high=1, size=num_pts))
        noise_x= np.random.uniform(low= -eps, high = eps,  size = num_pts)
        noise_y= np.random.uniform(low= -eps, high = eps,  size = num_pts)

        x_trans = np.random.randint(-2,2)
        y_trans = np.random.randint(-2,2)

        r = np.random.uniform(0.2, 2.5)

        x_values = list(r*x+noise_x+x_trans)
        y_values = list(r*np.sin(x+noise_y)+ y_trans)

        path = np.stack((x_values,y_values))
    
        Paths.append(path.T)
        
    return Paths


def generate_antidiagonal_paths(num_paths=100,eps = 0.01, num_pts = 50):
    
    Paths = []
    for i in range(num_paths): 
        x = np.sort(np.random.uniform(low=-1, high=1, size=num_pts))

        noise_x= np.random.uniform(low= -eps, high = eps,  size = num_pts)
        noise_y= np.random.uniform(low= -eps, high = eps,  size = num_pts)

        x_trans = np.random.randint(-2,2)
        y_trans = np.random.randint(-2,2)

        r = np.random.uniform(0.2, 2.5)

        x_values = list(r*x+noise_x + x_trans)
        y_values = list(-r*np.sin(x+noise_y)+y_trans)
        path = np.stack((x_values,y_values))
    
        Paths.append(path.T)
        
    return Paths
        



def generate_circular_paths(num_paths=100,eps = 0.02, num_pts = 50):
    
    Paths = []
    for i in range(num_paths): 
        endpoint = np.random.randint(0,num_pts)

        k = np.random.randint(1,4)
        phase = np.random.uniform(0,2*np.pi)
        
        sample_angles = list(np.sort(np.random.uniform(0,2*np.pi/k, num_pts)+phase))

        #angles= sample_angles[endpoint:]+ sample_angles[:endpoint]
        angles = np.array(sample_angles)
        
        noise_x= np.random.uniform(low= -eps, high = eps,  size = num_pts)
        noise_y= np.random.uniform(low= -eps, high = eps,  size = num_pts)

        x_trans = np.random.randint(-5,5)
        y_trans = np.random.randint(-5,5)

        r = np.random.uniform(0.2, 2.5)

        x_values = r*np.cos(angles)+noise_x
        y_values = r*np.sin(angles)+noise_y

        path = np.stack((x_values,y_values))
    
        Paths.append(path.T)

    return Paths

# %%
# generate data
noise = 0.05
pts = 30

p0 = generate_diagonal_paths(num_paths=100,eps = noise, num_pts = 50)
p1 = generate_antidiagonal_paths(num_paths=100,eps = noise, num_pts = 50)
p2 = generate_circular_paths(num_paths=100,eps = noise, num_pts = 50)

# join together p0, p1, p2
paths = p0+p1+p2

# %%
# generate labels
labels = np.concatenate((np.zeros(100),np.ones(100),2*np.ones(100)))

# perform a one hot encoding of the labels and transform to torch
labels = torch.nn.functional.one_hot(torch.tensor(labels).to(torch.int64))

# %%
fig, ax = plt.subplots(1,1,figsize = (10,10))

for i in range(5):


    plot_points(paths[0+i], ax, color = 'green', alpha = 0.6, linewidth = 2)

    plot_points(paths[100+i], ax, color = 'red', alpha = 0.6, linewidth = 2)

    plot_points(paths[200+i], ax, color = 'blue', alpha = 0.6, linewidth = 2)

plt.show()

# %%
# a function for calculating the length of a path
def path_length(path):
    """
    Calculates the length of a path
    """
    length = 0
    for i in range(len(path)-1):
        length += np.linalg.norm(path[i+1]-path[i])
    return length

# %% [markdown]
# ### Running the model

# %% [markdown]
# First up, we initialise the vector field as a simple MLP with ReLU activations.

# %%
c = 3 # number of features/columns in cochain data matrix

vf = nn.Sequential(
    nn.Linear(2, 50),
    nn.ReLU(),
    nn.Linear(50, 30),
    nn.ReLU(),
    nn.Linear(30, 2*c)
)

# %%
print(sum(p.numel() for p in vf.parameters()))
# Out:
# 1866

# %% [markdown]
# We can plot the corresponding vector fields below. Note that these are a result of the standard random weight initialisations.

# %%
fig, axs = plt.subplots(3, 1, figsize=(5, 15))

for i in range(3):
    ax = axs[i]
    plot_component_vf(vf, ax, comp = i, x_range=10, y_range=10)
    ax.set_title('Component {}'.format(i+1))

# add a title to the figure
fig.suptitle('Initial feature vector fields')

plt.show()

# %% [markdown]
# By looking at the summed rows of the corresponding cochain data matrix, we get a mapping from each path to R^3, where 3 is the number of feature vector fields and the coordinates corespond to integration along each vector field. As we can see, the initialised vector fields do not generate representations that separate the paths into the three classes.

# %%
# make a 3d scatter plot of vf evaluated on the set of paths, colored by labels
fig = plt.figure(figsize=(10,10))

ax = fig.add_subplot(111, projection='3d')

correct = 0

for i in range(len(paths)):
        
        p = paths[i]
        l = labels[i]

        p = path_to_chain(p)
        
        X = gen_CDM2(vf, p, d = 5)
        
        X = torch.sum(X, dim = 0)

        lb = torch.argmax(l)

        pred = torch.argmax(torch.nn.functional.softmax(X))

        if pred == lb:
            correct +=1
        
        
        if lb == 0:
            ax.scatter(X[0].detach().numpy(), X[1].detach().numpy(), X[2].detach().numpy(), color = 'green', alpha = 0.5)
        elif lb == 1:
            ax.scatter(X[0].detach().numpy(), X[1].detach().numpy(), X[2].detach().numpy(), color = 'red', alpha = 0.5)
        elif lb == 2:
            ax.scatter(X[0].detach().numpy(), X[1].detach().numpy(), X[2].detach().numpy(), color = 'blue', alpha = 0.5)


print('Accuracy: {}'.format(correct/len(paths)))


# add a title to the figure
fig.suptitle('Path embeddedings before training colored by label')

plt.show()
# Out:
# /var/folders/w2/2q_ql79j5_s6kq_b56rg9xdc0000gn/T/ipykernel_861/334403156.py:21: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   pred = torch.argmax(torch.nn.functional.softmax(X))
# Accuracy: 0.48

# %% [markdown]
# ### Training and Gradient Descent
#
# Now we begin the training phase. We use stand SGD with a learning rate of 0.01 and a momentum of 0.9. We train for 50 epoches and employ a Cross-Entropy loss.

# %%
import torch.optim as optim

# create your optimizer
optimizer = optim.SGD(vf.parameters(), lr=1e-2)

criterion = nn.CrossEntropyLoss()

# %%
epochs = 50

batch_size = 300

losses = torch.zeros((batch_size,epochs))

for j in range(epochs):

    # make a random choice of size batch_size
    idx = np.random.choice(len(paths), size=batch_size, replace=False)

    batch_paths = [paths[i] for i in idx]
    batch_labels = labels[idx]

        
    for i in range(batch_size):

        p = batch_paths[i]
        l = batch_labels[i]

        p = path_to_chain(p)
        
        X = gen_CDM2(vf, p, d = 5)
        X = torch.sum(X, dim = 0)

        sm = torch.nn.functional.softmax(X)


        loss = criterion(sm,l.float())

        losses[i,j] = loss.detach()

        
        loss.backward()

        # for some reason it works better doing the backprop/gradient step after each path

        optimizer.step()

        optimizer.zero_grad()

    # clear print statement from previous iteration
    # clear_output(wait=True)
    
    print("Epoch = ", j, "Loss = ", torch.sum(losses[:,j])/batch_size)


fig, axs = plt.subplots(3, 1, figsize=(5, 15))

for i in range(3):
    ax = axs[i]
    plot_component_vf(vf, ax, comp = i, x_range=10, y_range=10)
    ax.set_title('Component {}'.format(i+1))

# add a title to the figure
fig.suptitle('Final feature vector fields')

plt.show()
# Out:
# /var/folders/w2/2q_ql79j5_s6kq_b56rg9xdc0000gn/T/ipykernel_861/263785379.py:26: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   sm = torch.nn.functional.softmax(X)
# Epoch =  0 Loss =  tensor(1.0415)
# Epoch =  1 Loss =  tensor(0.9100)
# Epoch =  2 Loss =  tensor(0.8270)
# Epoch =  3 Loss =  tensor(0.7901)
# Epoch =  4 Loss =  tensor(0.7671)
# Epoch =  5 Loss =  tensor(0.7477)
# Epoch =  6 Loss =  tensor(0.7268)
# Epoch =  7 Loss =  tensor(0.7055)
# Epoch =  8 Loss =  tensor(0.6898)
# Epoch =  9 Loss =  tensor(0.6769)
# Epoch =  10 Loss =  tensor(0.6662)
# Epoch =  11 Loss =  tensor(0.6573)
# Epoch =  12 Loss =  tensor(0.6490)
# Epoch =  13 Loss =  tensor(0.6432)
# Epoch =  14 Loss =  tensor(0.6374)
# Epoch =  15 Loss =  tensor(0.6324)
# Epoch =  16 Loss =  tensor(0.6268)
# Epoch =  17 Loss =  tensor(0.6242)
# Epoch =  18 Loss =  tensor(0.6204)
# Epoch =  19 Loss =  tensor(0.6170)
# Epoch =  20 Loss =  tensor(0.6141)
# Epoch =  21 Loss =  tensor(0.6110)
# Epoch =  22 Loss =  tensor(0.6090)
# Epoch =  23 Loss =  tensor(0.6066)
# Epoch =  24 Loss =  tensor(0.6044)
# Epoch =  25 Loss =  tensor(0.6024)
# Epoch =  26 Loss =  tensor(0.6005)
# Epoch =  27 Loss =  tensor(0.5987)
# Epoch =  28 Loss =  tensor(0.5970)
# Epoch =  29 Loss =  tensor(0.5956)
# Epoch =  30 Loss =  tensor(0.5942)
# Epoch =  31 Loss =  tensor(0.5927)
# Epoch =  32 Loss =  tensor(0.5918)
# Epoch =  33 Loss =  tensor(0.5904)
# Epoch =  34 Loss =  tensor(0.5895)
# Epoch =  35 Loss =  tensor(0.5884)
# Epoch =  36 Loss =  tensor(0.5873)
# Epoch =  37 Loss =  tensor(0.5865)
# Epoch =  38 Loss =  tensor(0.5855)
# Epoch =  39 Loss =  tensor(0.5847)
# Epoch =  40 Loss =  tensor(0.5839)
# Epoch =  41 Loss =  tensor(0.5832)
# Epoch =  42 Loss =  tensor(0.5826)
# Epoch =  43 Loss =  tensor(0.5816)
# Epoch =  44 Loss =  tensor(0.5812)
# Epoch =  45 Loss =  tensor(0.5805)
# Epoch =  46 Loss =  tensor(0.5799)
# Epoch =  47 Loss =  tensor(0.5794)
# Epoch =  48 Loss =  tensor(0.5788)
# Epoch =  49 Loss =  tensor(0.5783)

# %% [markdown]
# As we see below, the loss behaves very nicely with respect to the epochs.

# %%
# plot the loss
L = torch.sum(losses,axis=0)/batch_size
plt.plot(L)
plt.title('Loss')

# add x and y labels
plt.xlabel('Epoch')
plt.ylabel('Average Loss')

plt.show()

# %%
# make a 3d scatter plot of vf evaluated on the set of paths, colored by labels
fig = plt.figure(figsize=(10,10))

ax = fig.add_subplot(111, projection='3d')

# evaluate the accuracy of the classifier on the training data
correct = 0
total = 0

for i in range(len(paths)):
        
        p = paths[i]
        l = labels[i]
        
        p = path_to_chain(p)
        X = gen_CDM2(vf, p)
        
        X = torch.sum(X, dim = 0)/path_length(p)

        lb = torch.argmax(l)

        pred = torch.argmax(torch.nn.functional.softmax(X))

        if pred == torch.argmax(l):
                correct += 1
        total += 1
        
        
        if lb == 0:
            ax.scatter(X[0].detach().numpy(), X[1].detach().numpy(), X[2].detach().numpy(), color = 'green', alpha = 0.5)
        elif lb == 1:
            ax.scatter(X[0].detach().numpy(), X[1].detach().numpy(), X[2].detach().numpy(), color = 'red', alpha = 0.5)
        elif lb == 2:
            ax.scatter(X[0].detach().numpy(), X[1].detach().numpy(), X[2].detach().numpy(), color = 'blue', alpha = 0.5)


print('Accuracy of the network on the 300 training paths: %d %%' % (100 * correct / total))

# add a title to the figure
fig.suptitle('Path embeddedings after training colored by label')

plt.show()
# Out:
# /var/folders/w2/2q_ql79j5_s6kq_b56rg9xdc0000gn/T/ipykernel_861/1883341664.py:22: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   pred = torch.argmax(torch.nn.functional.softmax(X))
# Accuracy of the network on the 300 training paths: 99 %

# %%
fig, axs = plt.subplots(3, 1, figsize=(5, 15))

# plot the three component vector fields
for i in range(3):
    ax = axs[i]
    plot_component_vf(vf, ax, comp = i, x_range=4, y_range=4)
    ax.set_title('Component {}'.format(i+1))

# add a title to the figure
fig.suptitle('Final feature vector fields')

# add example paths from each class
for i in range(20):

    plot_points(paths[0+i], axs[0], color = 'green', alpha = 0.6, linewidth = 2)

    plot_points(paths[100+i], axs[1], color = 'red', alpha = 0.6, linewidth = 2)

    plot_points(paths[200+i], axs[2], color = 'blue', alpha = 0.6, linewidth = 2)

plt.show()

# %% [markdown]
# ## 0-forms: Scalar Fields

# %% [markdown]
# Many authors have considered whether comparable results can be performed by networks that take only the point cloud of embedded vertices into account. To test whether the $1$-simplices are in fact necessary, we will take a $0$-form cochain representation network with as many parameters as the above as a comparison.
#
# To clarify, a $0$-form cochain neural network consists of learning $c$-features (for $c \in \mathbb{N}$) where each feature is a function from $\mathbb{R}^2 \to \mathbb{R}$. This can modelled as a simple MLP i.e. a function from $\mathbb{R}^2 \to \mathbb{R}^c$ with a finite number of parameters.

# %% [markdown]
# ### Initialisation
#
# We initiaise the function below, and note that this has slightly more paramters than our previous model.

# %%
c = 3 # number of features/columns in cochain data matrix

scalar = nn.Sequential(
    nn.Linear(2, 50),
    nn.ReLU(),
    nn.Linear(50, 32),
    nn.ReLU(),
    nn.Linear(32, c)
)

# print the total number of parameters in the model
print("Total Number of Parameters: ", sum(p.numel() for p in scalar.parameters()))
# Out:
# Total Number of Parameters:  1881

# %% [markdown]
# Like the previous example, we can plot individual $0$-form component features as scalar fields over $\mathbb{R}^2$, where $\mathbb{R}^2$ is the ambient embedding spaces of the nodes. This gives a helpful aid in interpreting the results of the network.

# %%
# a function to plot a heatmap of the scalar field
def plot_scalar_field_comp(scalar, ax, comp = 0, x_range = 5, y_range = 5, n = 100):
    x = np.linspace(-x_range, x_range, n)
    y = np.linspace(-y_range, y_range, n)
    X, Y = np.meshgrid(x, y)
    Z = np.zeros((n,n))
    for i in range(n):
        for j in range(n):
            Z[i,j] = scalar(torch.tensor([X[i,j],Y[i,j]]).float())[comp]
    ax.pcolormesh(X, Y, Z, cmap = 'viridis')

    # add a colorbar
    fig.colorbar(ax.pcolormesh(X, Y, Z, cmap = 'plasma'), ax=ax)

    # add a title labelling the component
    ax.set_title('Component {}'.format(comp))


fig, axs = plt.subplots(3, 1, figsize=(5, 15))

# plot the three component vector fields
for i in range(3):
    ax = axs[i]
    plot_scalar_field_comp(scalar, ax, comp = i, x_range=5, y_range=5)

# add a title to the figure
fig.suptitle('Initial feature scalar fields')
# Out:
# Text(0.5, 0.98, 'Initial feature scalar fields')

# %% [markdown]
# Again, as in the previous example, specifiying 3 features means that we embed set of points corresponding to a path into $\mathbb{R}^3$. To demonstrate, we show the embedding of the three paths in the dataset below at the initialisation stage.

# %%
# make a 3d scatter plot of vf evaluated on the set of paths, colored by labels
fig = plt.figure(figsize=(10,10))

ax = fig.add_subplot(111, projection='3d')

# evaluate the accuracy of the classifier on the training data
correct = 0
total = 0

for i in range(len(paths)):
        
        p = paths[i]
        l = labels[i]
        
        out = scalar(torch.tensor(p).float())
        X = torch.sum(out, dim = 0)

        lb = torch.argmax(l)

        pred = torch.argmax(torch.nn.functional.softmax(X))

        if pred == torch.argmax(l):
                correct += 1
        total += 1
        
        
        if lb == 0:
            ax.scatter(X[0].detach().numpy(), X[1].detach().numpy(), X[2].detach().numpy(), color = 'green', alpha = 0.5)
        elif lb == 1:
            ax.scatter(X[0].detach().numpy(), X[1].detach().numpy(), X[2].detach().numpy(), color = 'red', alpha = 0.5)
        elif lb == 2:
            ax.scatter(X[0].detach().numpy(), X[1].detach().numpy(), X[2].detach().numpy(), color = 'blue', alpha = 0.5)


# add a title to the figure
ax.set_title('Initial feature scalar field embedding')

# print accuracy
print('Accuracy of the network on the 300 training paths: ", %d %%' % (100 * correct / total))
# Out:
# /var/folders/w2/2q_ql79j5_s6kq_b56rg9xdc0000gn/T/ipykernel_973/352978634.py:20: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   pred = torch.argmax(torch.nn.functional.softmax(X))
# Accuracy of the network on the 300 training paths: ", 32 %

# %% [markdown]
# ### Training
#
# To make the results comparable, we use the same loss, SGD and epoch parameters as before

# %%
import torch.optim as optim

# create your optimizer
scalar_optimizer = optim.SGD(scalar.parameters(), lr=1e-4, momentum=0.9)

scalar_criterion = nn.CrossEntropyLoss()

# %%
epochs = 500

batch_size = 300

losses = torch.zeros((batch_size,epochs))

for j in range(epochs):

    # make a random choice of size batch_size
    idx = np.random.choice(len(paths), size=batch_size, replace=False)

    #idx = np.arange(batch_size)
    batch_paths = [paths[i] for i in idx]
    batch_labels = labels[idx]

        
    for i in range(batch_size):

        p = batch_paths[i]
        l = batch_labels[i]

        out = scalar(torch.tensor(p).float())
        out = torch.sum(out, dim = 0)
        
        sm = torch.nn.functional.softmax(out)


        loss = scalar_criterion(sm,l.float())

        losses[i,j] = loss.detach()

        
        loss.backward()

        # for some reason it works better doing the backprop/gradient step after each path
        

        scalar_optimizer.step()

        scalar_optimizer.zero_grad()

    # clear print statement from previous iteration
    # clear_output(wait=True)
    
    print("Epoch = ", j, "Loss = ", torch.sum(losses[:,j])/batch_size, "Pred: ", sm)
# Out:
# /var/folders/w2/2q_ql79j5_s6kq_b56rg9xdc0000gn/T/ipykernel_973/3264048846.py:25: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   sm = torch.nn.functional.softmax(out)
# Epoch =  0 Loss =  tensor(1.1943) Pred:  tensor([5.8366e-04, 9.9928e-01, 1.3891e-04], grad_fn=<SoftmaxBackward0>)
# Epoch =  1 Loss =  tensor(1.1146) Pred:  tensor([8.5069e-01, 1.4931e-01, 5.8741e-10], grad_fn=<SoftmaxBackward0>)
# Epoch =  2 Loss =  tensor(1.1099) Pred:  tensor([2.9601e-03, 9.9704e-01, 4.6253e-07], grad_fn=<SoftmaxBackward0>)
# Epoch =  3 Loss =  tensor(1.1046) Pred:  tensor([9.9965e-01, 3.4789e-04, 2.2432e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  4 Loss =  tensor(1.0643) Pred:  tensor([5.6492e-03, 9.9434e-01, 9.1332e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  5 Loss =  tensor(1.0712) Pred:  tensor([1.0000e+00, 2.1859e-06, 8.1932e-09], grad_fn=<SoftmaxBackward0>)
# Epoch =  6 Loss =  tensor(1.0790) Pred:  tensor([1.6257e-01, 8.3743e-01, 1.1671e-07], grad_fn=<SoftmaxBackward0>)
# Epoch =  7 Loss =  tensor(1.0687) Pred:  tensor([9.9404e-01, 5.8823e-03, 7.4777e-05], grad_fn=<SoftmaxBackward0>)
# Epoch =  8 Loss =  tensor(1.0527) Pred:  tensor([9.9880e-01, 1.1977e-03, 7.8954e-09], grad_fn=<SoftmaxBackward0>)
# Epoch =  9 Loss =  tensor(1.0587) Pred:  tensor([9.9601e-01, 3.8946e-03, 9.3589e-05], grad_fn=<SoftmaxBackward0>)
# Epoch =  10 Loss =  tensor(1.0546) Pred:  tensor([4.8416e-01, 5.1583e-01, 1.2260e-05], grad_fn=<SoftmaxBackward0>)
# Epoch =  11 Loss =  tensor(1.0426) Pred:  tensor([7.2003e-05, 9.9993e-01, 2.5042e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  12 Loss =  tensor(1.0296) Pred:  tensor([4.0955e-06, 1.0000e+00, 4.5672e-09], grad_fn=<SoftmaxBackward0>)
# Epoch =  13 Loss =  tensor(1.0238) Pred:  tensor([1.0000e+00, 1.9921e-08, 5.8781e-08], grad_fn=<SoftmaxBackward0>)
# Epoch =  14 Loss =  tensor(1.0203) Pred:  tensor([1.0000e+00, 3.7503e-06, 1.0736e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  15 Loss =  tensor(1.0147) Pred:  tensor([1.0000e+00, 1.2304e-08, 1.1073e-08], grad_fn=<SoftmaxBackward0>)
# Epoch =  16 Loss =  tensor(1.0212) Pred:  tensor([1.4506e-06, 1.0000e+00, 1.4111e-08], grad_fn=<SoftmaxBackward0>)
# Epoch =  17 Loss =  tensor(1.0175) Pred:  tensor([8.2808e-01, 1.7192e-01, 5.2101e-07], grad_fn=<SoftmaxBackward0>)
# Epoch =  18 Loss =  tensor(1.0160) Pred:  tensor([1.0000e+00, 3.1766e-19, 8.5882e-14], grad_fn=<SoftmaxBackward0>)
# Epoch =  19 Loss =  tensor(1.0110) Pred:  tensor([1.4012e-05, 9.9999e-01, 1.7302e-08], grad_fn=<SoftmaxBackward0>)
# Epoch =  20 Loss =  tensor(1.0220) Pred:  tensor([1.8601e-03, 9.9814e-01, 8.2610e-07], grad_fn=<SoftmaxBackward0>)
# Epoch =  21 Loss =  tensor(1.0140) Pred:  tensor([1.0000e+00, 1.2564e-06, 2.7381e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  22 Loss =  tensor(1.0135) Pred:  tensor([5.5614e-06, 9.9999e-01, 2.2284e-08], grad_fn=<SoftmaxBackward0>)
# Epoch =  23 Loss =  tensor(1.0100) Pred:  tensor([2.4716e-04, 9.9975e-01, 1.4884e-07], grad_fn=<SoftmaxBackward0>)
# Epoch =  24 Loss =  tensor(1.0405) Pred:  tensor([1.0000e+00, 3.3157e-09, 2.5084e-11], grad_fn=<SoftmaxBackward0>)
# Epoch =  25 Loss =  tensor(1.0196) Pred:  tensor([7.2107e-11, 1.0000e+00, 2.4180e-11], grad_fn=<SoftmaxBackward0>)
# Epoch =  26 Loss =  tensor(1.0000) Pred:  tensor([2.6823e-03, 9.9732e-01, 1.5734e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  27 Loss =  tensor(1.0135) Pred:  tensor([1.0000e+00, 9.8722e-24, 1.5555e-17], grad_fn=<SoftmaxBackward0>)
# Epoch =  28 Loss =  tensor(1.0214) Pred:  tensor([1.0000e+00, 4.6617e-12, 2.0214e-11], grad_fn=<SoftmaxBackward0>)
# Epoch =  29 Loss =  tensor(1.0083) Pred:  tensor([9.9820e-01, 1.7716e-03, 2.4917e-05], grad_fn=<SoftmaxBackward0>)
# Epoch =  30 Loss =  tensor(1.0029) Pred:  tensor([7.2011e-05, 9.9993e-01, 6.4473e-08], grad_fn=<SoftmaxBackward0>)
# Epoch =  31 Loss =  tensor(1.0017) Pred:  tensor([1.0000e+00, 9.5163e-13, 9.9592e-14], grad_fn=<SoftmaxBackward0>)
# Epoch =  32 Loss =  tensor(1.0008) Pred:  tensor([9.9997e-01, 1.8014e-05, 7.4955e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  33 Loss =  tensor(0.9980) Pred:  tensor([1.0000e+00, 2.1873e-17, 4.1569e-13], grad_fn=<SoftmaxBackward0>)
# Epoch =  34 Loss =  tensor(1.0086) Pred:  tensor([3.3021e-03, 9.9668e-01, 1.3504e-05], grad_fn=<SoftmaxBackward0>)
# Epoch =  35 Loss =  tensor(1.0067) Pred:  tensor([2.3259e-09, 1.0000e+00, 1.3735e-13], grad_fn=<SoftmaxBackward0>)
# Epoch =  36 Loss =  tensor(0.9932) Pred:  tensor([1.4914e-03, 9.9851e-01, 9.2245e-08], grad_fn=<SoftmaxBackward0>)
# Epoch =  37 Loss =  tensor(1.0001) Pred:  tensor([8.2931e-11, 1.0000e+00, 7.5332e-15], grad_fn=<SoftmaxBackward0>)
# Epoch =  38 Loss =  tensor(0.9969) Pred:  tensor([1.0000e+00, 1.9159e-22, 2.4139e-15], grad_fn=<SoftmaxBackward0>)
# Epoch =  39 Loss =  tensor(0.9972) Pred:  tensor([1.0411e-06, 1.0000e+00, 9.9713e-09], grad_fn=<SoftmaxBackward0>)
# Epoch =  40 Loss =  tensor(0.9912) Pred:  tensor([3.3859e-01, 6.6137e-01, 4.5463e-05], grad_fn=<SoftmaxBackward0>)
# Epoch =  41 Loss =  tensor(0.9909) Pred:  tensor([3.6320e-05, 9.9996e-01, 7.3344e-09], grad_fn=<SoftmaxBackward0>)
# Epoch =  42 Loss =  tensor(0.9905) Pred:  tensor([0.8475, 0.1505, 0.0020], grad_fn=<SoftmaxBackward0>)
# Epoch =  43 Loss =  tensor(0.9911) Pred:  tensor([5.7625e-05, 9.9994e-01, 1.8188e-09], grad_fn=<SoftmaxBackward0>)
# Epoch =  44 Loss =  tensor(0.9968) Pred:  tensor([1.0000e+00, 5.5320e-10, 4.4377e-08], grad_fn=<SoftmaxBackward0>)
# Epoch =  45 Loss =  tensor(0.9948) Pred:  tensor([1.3360e-05, 9.9998e-01, 1.6845e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  46 Loss =  tensor(0.9972) Pred:  tensor([3.2185e-10, 1.0000e+00, 1.1123e-13], grad_fn=<SoftmaxBackward0>)
# Epoch =  47 Loss =  tensor(0.9895) Pred:  tensor([1.0000e+00, 3.5443e-08, 3.4958e-08], grad_fn=<SoftmaxBackward0>)
# Epoch =  48 Loss =  tensor(0.9930) Pred:  tensor([1.1831e-06, 1.0000e+00, 5.5859e-08], grad_fn=<SoftmaxBackward0>)
# Epoch =  49 Loss =  tensor(0.9963) Pred:  tensor([1.0000e+00, 3.3603e-11, 4.7968e-14], grad_fn=<SoftmaxBackward0>)
# Epoch =  50 Loss =  tensor(0.9860) Pred:  tensor([1.0000e+00, 2.7745e-12, 2.7908e-10], grad_fn=<SoftmaxBackward0>)
# Epoch =  51 Loss =  tensor(0.9906) Pred:  tensor([7.0084e-06, 9.9999e-01, 1.9737e-08], grad_fn=<SoftmaxBackward0>)
# Epoch =  52 Loss =  tensor(0.9824) Pred:  tensor([9.9926e-01, 6.4102e-04, 1.0387e-04], grad_fn=<SoftmaxBackward0>)
# Epoch =  53 Loss =  tensor(0.9901) Pred:  tensor([7.1781e-06, 9.9999e-01, 2.2881e-10], grad_fn=<SoftmaxBackward0>)
# Epoch =  54 Loss =  tensor(0.9813) Pred:  tensor([9.9814e-01, 1.8629e-03, 4.9328e-08], grad_fn=<SoftmaxBackward0>)
# Epoch =  55 Loss =  tensor(0.9866) Pred:  tensor([1.0000e+00, 9.8988e-18, 3.9123e-12], grad_fn=<SoftmaxBackward0>)
# Epoch =  56 Loss =  tensor(0.9828) Pred:  tensor([9.9997e-01, 2.5215e-05, 5.9693e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  57 Loss =  tensor(0.9850) Pred:  tensor([1.0000e+00, 3.2465e-08, 1.8730e-07], grad_fn=<SoftmaxBackward0>)
# Epoch =  58 Loss =  tensor(0.9825) Pred:  tensor([4.2535e-07, 1.0000e+00, 3.8986e-08], grad_fn=<SoftmaxBackward0>)
# Epoch =  59 Loss =  tensor(0.9824) Pred:  tensor([9.9004e-01, 9.9575e-03, 1.4552e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  60 Loss =  tensor(0.9806) Pred:  tensor([9.9999e-01, 6.9190e-06, 7.6873e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  61 Loss =  tensor(0.9828) Pred:  tensor([1.0000e+00, 1.9968e-32, 6.6924e-23], grad_fn=<SoftmaxBackward0>)
# Epoch =  62 Loss =  tensor(0.9794) Pred:  tensor([1.0000e+00, 3.8966e-09, 1.1936e-07], grad_fn=<SoftmaxBackward0>)
# Epoch =  63 Loss =  tensor(0.9810) Pred:  tensor([1.0000e+00, 1.3862e-06, 2.6635e-09], grad_fn=<SoftmaxBackward0>)
# Epoch =  64 Loss =  tensor(0.9799) Pred:  tensor([1.0000e+00, 4.8359e-22, 1.1083e-15], grad_fn=<SoftmaxBackward0>)
# Epoch =  65 Loss =  tensor(0.9950) Pred:  tensor([0.4163, 0.5803, 0.0035], grad_fn=<SoftmaxBackward0>)
# Epoch =  66 Loss =  tensor(0.9856) Pred:  tensor([6.3968e-08, 1.0000e+00, 9.2995e-09], grad_fn=<SoftmaxBackward0>)
# Epoch =  67 Loss =  tensor(0.9828) Pred:  tensor([1.4767e-03, 9.9852e-01, 3.9838e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  68 Loss =  tensor(0.9843) Pred:  tensor([9.9931e-01, 5.4116e-04, 1.4567e-04], grad_fn=<SoftmaxBackward0>)
# Epoch =  69 Loss =  tensor(0.9824) Pred:  tensor([1.0365e-05, 9.9999e-01, 1.1819e-09], grad_fn=<SoftmaxBackward0>)
# Epoch =  70 Loss =  tensor(0.9775) Pred:  tensor([8.4128e-04, 9.9916e-01, 8.6169e-07], grad_fn=<SoftmaxBackward0>)
# Epoch =  71 Loss =  tensor(0.9765) Pred:  tensor([7.5817e-10, 1.0000e+00, 8.8744e-12], grad_fn=<SoftmaxBackward0>)
# Epoch =  72 Loss =  tensor(0.9796) Pred:  tensor([5.3159e-06, 9.9999e-01, 8.9238e-10], grad_fn=<SoftmaxBackward0>)
# Epoch =  73 Loss =  tensor(0.9851) Pred:  tensor([9.2976e-01, 7.0229e-02, 1.1642e-05], grad_fn=<SoftmaxBackward0>)
# Epoch =  74 Loss =  tensor(0.9781) Pred:  tensor([1.0000e+00, 2.4813e-07, 1.6445e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  75 Loss =  tensor(0.9781) Pred:  tensor([2.7197e-09, 1.0000e+00, 9.0608e-10], grad_fn=<SoftmaxBackward0>)
# Epoch =  76 Loss =  tensor(0.9787) Pred:  tensor([1.0000e+00, 1.8239e-08, 4.3072e-07], grad_fn=<SoftmaxBackward0>)
# Epoch =  77 Loss =  tensor(0.9809) Pred:  tensor([1.0000e+00, 4.6666e-16, 3.6323e-11], grad_fn=<SoftmaxBackward0>)
# Epoch =  78 Loss =  tensor(0.9761) Pred:  tensor([1.0000e+00, 4.4670e-14, 2.8409e-11], grad_fn=<SoftmaxBackward0>)
# Epoch =  79 Loss =  tensor(0.9786) Pred:  tensor([1.0000e+00, 1.7007e-18, 6.6366e-13], grad_fn=<SoftmaxBackward0>)
# Epoch =  80 Loss =  tensor(0.9806) Pred:  tensor([8.3400e-01, 1.6598e-01, 1.3965e-05], grad_fn=<SoftmaxBackward0>)
# Epoch =  81 Loss =  tensor(0.9790) Pred:  tensor([9.9987e-01, 1.2847e-04, 6.6963e-10], grad_fn=<SoftmaxBackward0>)
# Epoch =  82 Loss =  tensor(0.9871) Pred:  tensor([9.9968e-01, 1.9172e-04, 1.3264e-04], grad_fn=<SoftmaxBackward0>)
# Epoch =  83 Loss =  tensor(0.9745) Pred:  tensor([1.5831e-16, 1.0000e+00, 3.0062e-14], grad_fn=<SoftmaxBackward0>)
# Epoch =  84 Loss =  tensor(0.9853) Pred:  tensor([1.2415e-09, 1.0000e+00, 5.9828e-10], grad_fn=<SoftmaxBackward0>)
# Epoch =  85 Loss =  tensor(0.9756) Pred:  tensor([9.6569e-01, 3.4310e-02, 4.3042e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  86 Loss =  tensor(0.9799) Pred:  tensor([2.8920e-08, 1.0000e+00, 2.9776e-09], grad_fn=<SoftmaxBackward0>)
# Epoch =  87 Loss =  tensor(0.9816) Pred:  tensor([3.9793e-12, 1.0000e+00, 3.3038e-11], grad_fn=<SoftmaxBackward0>)
# Epoch =  88 Loss =  tensor(0.9754) Pred:  tensor([1.0000e+00, 3.3576e-24, 3.3333e-17], grad_fn=<SoftmaxBackward0>)
# Epoch =  89 Loss =  tensor(0.9759) Pred:  tensor([9.9964e-01, 2.8595e-04, 7.1517e-05], grad_fn=<SoftmaxBackward0>)
# Epoch =  90 Loss =  tensor(0.9761) Pred:  tensor([2.4772e-11, 1.0000e+00, 6.4487e-14], grad_fn=<SoftmaxBackward0>)
# Epoch =  91 Loss =  tensor(0.9781) Pred:  tensor([1.0000e+00, 8.4459e-11, 7.4182e-10], grad_fn=<SoftmaxBackward0>)
# Epoch =  92 Loss =  tensor(0.9844) Pred:  tensor([1.0000e+00, 3.6466e-29, 4.8788e-19], grad_fn=<SoftmaxBackward0>)
# Epoch =  93 Loss =  tensor(0.9744) Pred:  tensor([1.0000e+00, 1.4446e-18, 5.7915e-14], grad_fn=<SoftmaxBackward0>)
# Epoch =  94 Loss =  tensor(0.9771) Pred:  tensor([1.0000e+00, 4.2925e-37, 2.0282e-23], grad_fn=<SoftmaxBackward0>)
# Epoch =  95 Loss =  tensor(0.9747) Pred:  tensor([9.9950e-01, 3.8863e-04, 1.0728e-04], grad_fn=<SoftmaxBackward0>)
# Epoch =  96 Loss =  tensor(0.9750) Pred:  tensor([9.9979e-01, 1.5324e-04, 5.8542e-05], grad_fn=<SoftmaxBackward0>)
# Epoch =  97 Loss =  tensor(0.9802) Pred:  tensor([9.9999e-01, 6.3718e-06, 3.8556e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  98 Loss =  tensor(0.9762) Pred:  tensor([1.0000e+00, 5.8362e-09, 9.0413e-08], grad_fn=<SoftmaxBackward0>)
# Epoch =  99 Loss =  tensor(0.9742) Pred:  tensor([1.0000e+00, 2.2418e-07, 8.7669e-07], grad_fn=<SoftmaxBackward0>)
# Epoch =  100 Loss =  tensor(0.9761) Pred:  tensor([2.9356e-04, 9.9971e-01, 7.3399e-08], grad_fn=<SoftmaxBackward0>)
# Epoch =  101 Loss =  tensor(0.9754) Pred:  tensor([0.9319, 0.0665, 0.0016], grad_fn=<SoftmaxBackward0>)
# Epoch =  102 Loss =  tensor(0.9771) Pred:  tensor([9.3562e-06, 9.9999e-01, 3.6192e-09], grad_fn=<SoftmaxBackward0>)
# Epoch =  103 Loss =  tensor(0.9777) Pred:  tensor([1.0785e-05, 9.9999e-01, 2.5504e-07], grad_fn=<SoftmaxBackward0>)
# Epoch =  104 Loss =  tensor(0.9749) Pred:  tensor([3.0784e-04, 9.9969e-01, 1.0098e-07], grad_fn=<SoftmaxBackward0>)
# Epoch =  105 Loss =  tensor(0.9849) Pred:  tensor([3.9297e-06, 1.0000e+00, 1.8340e-08], grad_fn=<SoftmaxBackward0>)
# Epoch =  106 Loss =  tensor(0.9795) Pred:  tensor([7.7278e-06, 9.9999e-01, 1.1374e-07], grad_fn=<SoftmaxBackward0>)
# Epoch =  107 Loss =  tensor(0.9804) Pred:  tensor([1.0000e+00, 2.3616e-12, 6.2023e-10], grad_fn=<SoftmaxBackward0>)
# Epoch =  108 Loss =  tensor(0.9758) Pred:  tensor([1.0000e+00, 1.0575e-22, 1.2331e-16], grad_fn=<SoftmaxBackward0>)
# Epoch =  109 Loss =  tensor(0.9732) Pred:  tensor([5.8670e-02, 9.4108e-01, 2.5293e-04], grad_fn=<SoftmaxBackward0>)
# Epoch =  110 Loss =  tensor(0.9735) Pred:  tensor([1.0000e+00, 2.1969e-34, 5.9237e-24], grad_fn=<SoftmaxBackward0>)
# Epoch =  111 Loss =  tensor(0.9762) Pred:  tensor([2.9976e-10, 1.0000e+00, 2.1689e-10], grad_fn=<SoftmaxBackward0>)
# Epoch =  112 Loss =  tensor(0.9746) Pred:  tensor([1.0000e+00, 1.7402e-30, 5.1173e-21], grad_fn=<SoftmaxBackward0>)
# Epoch =  113 Loss =  tensor(0.9754) Pred:  tensor([1.0000e+00, 0.0000e+00, 4.6101e-30], grad_fn=<SoftmaxBackward0>)
# Epoch =  114 Loss =  tensor(0.9734) Pred:  tensor([3.6005e-09, 1.0000e+00, 4.9649e-10], grad_fn=<SoftmaxBackward0>)
# Epoch =  115 Loss =  tensor(0.9730) Pred:  tensor([1.1561e-06, 1.0000e+00, 3.0306e-07], grad_fn=<SoftmaxBackward0>)
# Epoch =  116 Loss =  tensor(0.9752) Pred:  tensor([1.0000e+00, 8.4855e-12, 8.5965e-10], grad_fn=<SoftmaxBackward0>)
# Epoch =  117 Loss =  tensor(0.9759) Pred:  tensor([1.0000e+00, 2.0784e-11, 7.8718e-09], grad_fn=<SoftmaxBackward0>)
# Epoch =  118 Loss =  tensor(0.9743) Pred:  tensor([9.9995e-01, 2.8606e-05, 2.5699e-05], grad_fn=<SoftmaxBackward0>)
# Epoch =  119 Loss =  tensor(0.9735) Pred:  tensor([1.0000e+00, 6.7906e-21, 1.0053e-14], grad_fn=<SoftmaxBackward0>)
# Epoch =  120 Loss =  tensor(0.9771) Pred:  tensor([1.0000e+00, 1.5710e-19, 1.9212e-13], grad_fn=<SoftmaxBackward0>)
# Epoch =  121 Loss =  tensor(0.9720) Pred:  tensor([1., 0., 0.], grad_fn=<SoftmaxBackward0>)
# Epoch =  122 Loss =  tensor(0.9740) Pred:  tensor([1.0000e+00, 6.4179e-43, 1.4488e-26], grad_fn=<SoftmaxBackward0>)
# Epoch =  123 Loss =  tensor(0.9713) Pred:  tensor([1.0000e+00, 4.2553e-38, 3.3848e-26], grad_fn=<SoftmaxBackward0>)
# Epoch =  124 Loss =  tensor(0.9731) Pred:  tensor([1.0000e+00, 0.0000e+00, 1.2752e-43], grad_fn=<SoftmaxBackward0>)
# Epoch =  125 Loss =  tensor(0.9772) Pred:  tensor([1.0000e+00, 2.8488e-12, 4.7745e-10], grad_fn=<SoftmaxBackward0>)
# Epoch =  126 Loss =  tensor(0.9850) Pred:  tensor([9.8607e-01, 1.3928e-02, 1.2182e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  127 Loss =  tensor(0.9794) Pred:  tensor([1.0000e+00, 1.2788e-09, 5.2755e-08], grad_fn=<SoftmaxBackward0>)
# Epoch =  128 Loss =  tensor(0.9729) Pred:  tensor([1.6980e-01, 8.3019e-01, 2.2324e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  129 Loss =  tensor(0.9767) Pred:  tensor([9.7677e-01, 2.2468e-02, 7.6239e-04], grad_fn=<SoftmaxBackward0>)
# Epoch =  130 Loss =  tensor(0.9822) Pred:  tensor([1.0000e+00, 1.7477e-38, 8.2555e-24], grad_fn=<SoftmaxBackward0>)
# Epoch =  131 Loss =  tensor(0.9745) Pred:  tensor([1.0000e+00, 2.0207e-42, 3.5185e-26], grad_fn=<SoftmaxBackward0>)
# Epoch =  132 Loss =  tensor(0.9774) Pred:  tensor([1.0000e+00, 1.3770e-09, 6.5624e-08], grad_fn=<SoftmaxBackward0>)
# Epoch =  133 Loss =  tensor(0.9774) Pred:  tensor([1.9804e-07, 1.0000e+00, 2.3187e-08], grad_fn=<SoftmaxBackward0>)
# Epoch =  134 Loss =  tensor(0.9711) Pred:  tensor([1.0000e+00, 2.2100e-20, 9.3823e-19], grad_fn=<SoftmaxBackward0>)
# Epoch =  135 Loss =  tensor(0.9728) Pred:  tensor([2.8191e-04, 9.9972e-01, 3.4080e-07], grad_fn=<SoftmaxBackward0>)
# Epoch =  136 Loss =  tensor(0.9721) Pred:  tensor([1.0000e+00, 8.3235e-30, 1.5231e-19], grad_fn=<SoftmaxBackward0>)
# Epoch =  137 Loss =  tensor(0.9735) Pred:  tensor([1.0000e+00, 1.3682e-13, 1.4027e-10], grad_fn=<SoftmaxBackward0>)
# Epoch =  138 Loss =  tensor(0.9718) Pred:  tensor([9.9992e-01, 7.6574e-05, 1.5808e-07], grad_fn=<SoftmaxBackward0>)
# Epoch =  139 Loss =  tensor(0.9734) Pred:  tensor([1.0000e+00, 2.5443e-13, 1.1644e-10], grad_fn=<SoftmaxBackward0>)
# Epoch =  140 Loss =  tensor(0.9736) Pred:  tensor([9.0861e-01, 9.1377e-02, 1.6624e-05], grad_fn=<SoftmaxBackward0>)
# Epoch =  141 Loss =  tensor(0.9738) Pred:  tensor([1.9753e-01, 8.0246e-01, 1.6381e-05], grad_fn=<SoftmaxBackward0>)
# Epoch =  142 Loss =  tensor(0.9749) Pred:  tensor([1.0000e+00, 5.9319e-25, 4.1969e-18], grad_fn=<SoftmaxBackward0>)
# Epoch =  143 Loss =  tensor(0.9732) Pred:  tensor([1.0000e+00, 3.9239e-11, 1.4241e-08], grad_fn=<SoftmaxBackward0>)
# Epoch =  144 Loss =  tensor(0.9698) Pred:  tensor([2.3999e-22, 1.0000e+00, 1.3434e-17], grad_fn=<SoftmaxBackward0>)
# Epoch =  145 Loss =  tensor(0.9773) Pred:  tensor([1.2665e-14, 1.0000e+00, 6.9498e-13], grad_fn=<SoftmaxBackward0>)
# Epoch =  146 Loss =  tensor(0.9718) Pred:  tensor([1.0000e+00, 1.5289e-12, 2.8198e-10], grad_fn=<SoftmaxBackward0>)
# Epoch =  147 Loss =  tensor(0.9723) Pred:  tensor([1.0000e+00, 5.2040e-41, 3.4871e-27], grad_fn=<SoftmaxBackward0>)
# Epoch =  148 Loss =  tensor(0.9720) Pred:  tensor([1.0000e+00, 1.5039e-30, 6.0620e-22], grad_fn=<SoftmaxBackward0>)
# Epoch =  149 Loss =  tensor(0.9703) Pred:  tensor([9.6208e-01, 3.7813e-02, 1.0521e-04], grad_fn=<SoftmaxBackward0>)
# Epoch =  150 Loss =  tensor(0.9720) Pred:  tensor([1.3672e-07, 1.0000e+00, 1.3952e-09], grad_fn=<SoftmaxBackward0>)
# Epoch =  151 Loss =  tensor(0.9707) Pred:  tensor([3.1379e-09, 1.0000e+00, 4.1279e-10], grad_fn=<SoftmaxBackward0>)
# Epoch =  152 Loss =  tensor(0.9725) Pred:  tensor([3.1283e-16, 1.0000e+00, 7.2935e-14], grad_fn=<SoftmaxBackward0>)
# Epoch =  153 Loss =  tensor(0.9723) Pred:  tensor([1.0000e+00, 2.7312e-12, 7.4268e-10], grad_fn=<SoftmaxBackward0>)
# Epoch =  154 Loss =  tensor(0.9719) Pred:  tensor([1.3379e-06, 1.0000e+00, 2.0356e-08], grad_fn=<SoftmaxBackward0>)
# Epoch =  155 Loss =  tensor(0.9744) Pred:  tensor([1., 0., 0.], grad_fn=<SoftmaxBackward0>)
# Epoch =  156 Loss =  tensor(0.9719) Pred:  tensor([2.4421e-11, 1.0000e+00, 2.8649e-11], grad_fn=<SoftmaxBackward0>)
# Epoch =  157 Loss =  tensor(0.9760) Pred:  tensor([1.0000e+00, 7.0703e-29, 2.3600e-21], grad_fn=<SoftmaxBackward0>)
# Epoch =  158 Loss =  tensor(0.9716) Pred:  tensor([1.0000e+00, 9.3813e-08, 2.2493e-07], grad_fn=<SoftmaxBackward0>)
# Epoch =  159 Loss =  tensor(0.9684) Pred:  tensor([1.0000e+00, 0.0000e+00, 4.9706e-39], grad_fn=<SoftmaxBackward0>)
# Epoch =  160 Loss =  tensor(0.9716) Pred:  tensor([1.0000e+00, 1.9890e-06, 3.7972e-10], grad_fn=<SoftmaxBackward0>)
# Epoch =  161 Loss =  tensor(0.9745) Pred:  tensor([1.5928e-02, 9.8407e-01, 4.8842e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  162 Loss =  tensor(0.9715) Pred:  tensor([9.9506e-01, 4.8988e-03, 4.5772e-05], grad_fn=<SoftmaxBackward0>)
# Epoch =  163 Loss =  tensor(0.9722) Pred:  tensor([3.2951e-05, 9.9997e-01, 9.6178e-09], grad_fn=<SoftmaxBackward0>)
# Epoch =  164 Loss =  tensor(0.9713) Pred:  tensor([1.0000e+00, 4.9676e-31, 5.3694e-21], grad_fn=<SoftmaxBackward0>)
# Epoch =  165 Loss =  tensor(0.9698) Pred:  tensor([7.5444e-23, 1.0000e+00, 1.0618e-17], grad_fn=<SoftmaxBackward0>)
# Epoch =  166 Loss =  tensor(0.9712) Pred:  tensor([3.7478e-03, 9.9625e-01, 1.1432e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  167 Loss =  tensor(0.9696) Pred:  tensor([9.9957e-01, 4.0073e-04, 2.4587e-05], grad_fn=<SoftmaxBackward0>)
# Epoch =  168 Loss =  tensor(0.9707) Pred:  tensor([1.0000e+00, 6.9897e-36, 5.8755e-25], grad_fn=<SoftmaxBackward0>)
# Epoch =  169 Loss =  tensor(0.9732) Pred:  tensor([1.5662e-07, 1.0000e+00, 1.9909e-09], grad_fn=<SoftmaxBackward0>)
# Epoch =  170 Loss =  tensor(0.9695) Pred:  tensor([1., 0., 0.], grad_fn=<SoftmaxBackward0>)
# Epoch =  171 Loss =  tensor(0.9733) Pred:  tensor([7.6667e-08, 1.0000e+00, 1.9166e-10], grad_fn=<SoftmaxBackward0>)
# Epoch =  172 Loss =  tensor(0.9714) Pred:  tensor([3.4738e-14, 1.0000e+00, 1.2881e-11], grad_fn=<SoftmaxBackward0>)
# Epoch =  173 Loss =  tensor(0.9698) Pred:  tensor([1.0000e+00, 2.8973e-18, 1.8885e-15], grad_fn=<SoftmaxBackward0>)
# Epoch =  174 Loss =  tensor(0.9688) Pred:  tensor([1.0000e+00, 9.1331e-10, 4.4373e-08], grad_fn=<SoftmaxBackward0>)
# Epoch =  175 Loss =  tensor(0.9776) Pred:  tensor([9.5390e-01, 4.5262e-02, 8.3494e-04], grad_fn=<SoftmaxBackward0>)
# Epoch =  176 Loss =  tensor(0.9696) Pred:  tensor([2.9908e-04, 9.9970e-01, 3.8597e-07], grad_fn=<SoftmaxBackward0>)
# Epoch =  177 Loss =  tensor(0.9686) Pred:  tensor([1.0000e+00, 2.2923e-23, 7.4804e-17], grad_fn=<SoftmaxBackward0>)
# Epoch =  178 Loss =  tensor(0.9773) Pred:  tensor([1.0460e-07, 1.0000e+00, 3.5474e-08], grad_fn=<SoftmaxBackward0>)
# Epoch =  179 Loss =  tensor(0.9709) Pred:  tensor([1.4777e-05, 9.9999e-01, 7.2944e-09], grad_fn=<SoftmaxBackward0>)
# Epoch =  180 Loss =  tensor(0.9686) Pred:  tensor([1.0000e+00, 2.6705e-21, 8.9347e-15], grad_fn=<SoftmaxBackward0>)
# Epoch =  181 Loss =  tensor(0.9706) Pred:  tensor([3.8814e-04, 9.9961e-01, 1.6691e-07], grad_fn=<SoftmaxBackward0>)
# Epoch =  182 Loss =  tensor(0.9700) Pred:  tensor([1., 0., 0.], grad_fn=<SoftmaxBackward0>)
# Epoch =  183 Loss =  tensor(0.9685) Pred:  tensor([4.7552e-12, 1.0000e+00, 3.8259e-11], grad_fn=<SoftmaxBackward0>)
# Epoch =  184 Loss =  tensor(0.9694) Pred:  tensor([1.0000e+00, 2.5771e-21, 5.4152e-15], grad_fn=<SoftmaxBackward0>)
# Epoch =  185 Loss =  tensor(0.9708) Pred:  tensor([9.4834e-01, 5.1644e-02, 1.6172e-05], grad_fn=<SoftmaxBackward0>)
# Epoch =  186 Loss =  tensor(0.9696) Pred:  tensor([1.0000e+00, 5.8383e-38, 2.3744e-24], grad_fn=<SoftmaxBackward0>)
# Epoch =  187 Loss =  tensor(0.9698) Pred:  tensor([1.0000e+00, 1.5976e-22, 3.4464e-15], grad_fn=<SoftmaxBackward0>)
# Epoch =  188 Loss =  tensor(0.9692) Pred:  tensor([4.9868e-07, 1.0000e+00, 4.3429e-09], grad_fn=<SoftmaxBackward0>)
# Epoch =  189 Loss =  tensor(0.9694) Pred:  tensor([1., 0., 0.], grad_fn=<SoftmaxBackward0>)
# Epoch =  190 Loss =  tensor(0.9697) Pred:  tensor([5.5741e-09, 1.0000e+00, 3.8169e-09], grad_fn=<SoftmaxBackward0>)
# Epoch =  191 Loss =  tensor(0.9694) Pred:  tensor([1.0000e+00, 0.0000e+00, 6.9304e-39], grad_fn=<SoftmaxBackward0>)
# Epoch =  192 Loss =  tensor(0.9706) Pred:  tensor([1.0000e+00, 2.0144e-13, 4.6573e-10], grad_fn=<SoftmaxBackward0>)
# Epoch =  193 Loss =  tensor(0.9692) Pred:  tensor([7.6593e-05, 9.9992e-01, 1.0110e-07], grad_fn=<SoftmaxBackward0>)
# Epoch =  194 Loss =  tensor(0.9678) Pred:  tensor([1.0000e+00, 0.0000e+00, 7.0213e-39], grad_fn=<SoftmaxBackward0>)
# Epoch =  195 Loss =  tensor(0.9699) Pred:  tensor([1.0000e+00, 1.8703e-14, 3.4684e-11], grad_fn=<SoftmaxBackward0>)
# Epoch =  196 Loss =  tensor(0.9708) Pred:  tensor([9.9951e-01, 4.8449e-04, 1.3119e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  197 Loss =  tensor(0.9739) Pred:  tensor([1.0000e+00, 2.3395e-26, 2.4203e-18], grad_fn=<SoftmaxBackward0>)
# Epoch =  198 Loss =  tensor(0.9712) Pred:  tensor([1.0000e+00, 1.1435e-42, 2.0147e-26], grad_fn=<SoftmaxBackward0>)
# Epoch =  199 Loss =  tensor(0.9708) Pred:  tensor([1.6128e-02, 9.8387e-01, 2.2757e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  200 Loss =  tensor(0.9691) Pred:  tensor([8.9206e-01, 1.0794e-01, 8.9978e-07], grad_fn=<SoftmaxBackward0>)
# Epoch =  201 Loss =  tensor(0.9690) Pred:  tensor([1.0000e+00, 7.9117e-22, 3.8538e-15], grad_fn=<SoftmaxBackward0>)
# Epoch =  202 Loss =  tensor(0.9702) Pred:  tensor([1.0000e+00, 0.0000e+00, 3.7526e-33], grad_fn=<SoftmaxBackward0>)
# Epoch =  203 Loss =  tensor(0.9696) Pred:  tensor([9.9428e-01, 5.7221e-03, 9.1358e-07], grad_fn=<SoftmaxBackward0>)
# Epoch =  204 Loss =  tensor(0.9694) Pred:  tensor([9.9081e-01, 9.1503e-03, 3.8297e-05], grad_fn=<SoftmaxBackward0>)
# Epoch =  205 Loss =  tensor(0.9695) Pred:  tensor([1.0000e+00, 2.0142e-39, 8.1104e-27], grad_fn=<SoftmaxBackward0>)
# Epoch =  206 Loss =  tensor(0.9699) Pred:  tensor([9.6021e-01, 3.9785e-02, 6.1218e-07], grad_fn=<SoftmaxBackward0>)
# Epoch =  207 Loss =  tensor(0.9683) Pred:  tensor([1.0000e+00, 0.0000e+00, 7.4269e-44], grad_fn=<SoftmaxBackward0>)
# Epoch =  208 Loss =  tensor(0.9718) Pred:  tensor([3.0133e-06, 1.0000e+00, 2.5520e-09], grad_fn=<SoftmaxBackward0>)
# Epoch =  209 Loss =  tensor(0.9690) Pred:  tensor([1.0000e+00, 4.6030e-28, 2.0942e-18], grad_fn=<SoftmaxBackward0>)
# Epoch =  210 Loss =  tensor(0.9676) Pred:  tensor([1.0455e-11, 1.0000e+00, 2.7066e-12], grad_fn=<SoftmaxBackward0>)
# Epoch =  211 Loss =  tensor(0.9735) Pred:  tensor([4.7305e-16, 1.0000e+00, 2.1419e-14], grad_fn=<SoftmaxBackward0>)
# Epoch =  212 Loss =  tensor(0.9703) Pred:  tensor([1.0000e+00, 0.0000e+00, 1.2258e-40], grad_fn=<SoftmaxBackward0>)
# Epoch =  213 Loss =  tensor(0.9697) Pred:  tensor([9.9989e-01, 1.1223e-04, 2.9848e-10], grad_fn=<SoftmaxBackward0>)
# Epoch =  214 Loss =  tensor(0.9703) Pred:  tensor([1.2288e-03, 9.9877e-01, 3.7125e-08], grad_fn=<SoftmaxBackward0>)
# Epoch =  215 Loss =  tensor(0.9677) Pred:  tensor([9.9436e-01, 5.6441e-03, 3.7127e-07], grad_fn=<SoftmaxBackward0>)
# Epoch =  216 Loss =  tensor(0.9689) Pred:  tensor([1.0000e+00, 1.7299e-13, 8.0895e-11], grad_fn=<SoftmaxBackward0>)
# Epoch =  217 Loss =  tensor(0.9715) Pred:  tensor([1.0000e+00, 1.6196e-33, 2.2005e-23], grad_fn=<SoftmaxBackward0>)
# Epoch =  218 Loss =  tensor(0.9689) Pred:  tensor([1.0000e+00, 5.0026e-22, 1.4888e-15], grad_fn=<SoftmaxBackward0>)
# Epoch =  219 Loss =  tensor(0.9697) Pred:  tensor([1.0000e+00, 1.8419e-06, 2.6523e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  220 Loss =  tensor(0.9707) Pred:  tensor([5.9626e-12, 1.0000e+00, 1.8971e-10], grad_fn=<SoftmaxBackward0>)
# Epoch =  221 Loss =  tensor(0.9734) Pred:  tensor([3.0008e-04, 9.9970e-01, 3.4767e-07], grad_fn=<SoftmaxBackward0>)
# Epoch =  222 Loss =  tensor(0.9688) Pred:  tensor([7.1541e-01, 2.8435e-01, 2.3492e-04], grad_fn=<SoftmaxBackward0>)
# Epoch =  223 Loss =  tensor(0.9721) Pred:  tensor([1.0000e+00, 4.7124e-27, 7.7470e-19], grad_fn=<SoftmaxBackward0>)
# Epoch =  224 Loss =  tensor(0.9711) Pred:  tensor([4.6878e-18, 1.0000e+00, 2.9689e-15], grad_fn=<SoftmaxBackward0>)
# Epoch =  225 Loss =  tensor(0.9706) Pred:  tensor([1.0000e+00, 2.6605e-13, 1.3599e-11], grad_fn=<SoftmaxBackward0>)
# Epoch =  226 Loss =  tensor(0.9681) Pred:  tensor([1.8306e-19, 1.0000e+00, 6.8615e-18], grad_fn=<SoftmaxBackward0>)
# Epoch =  227 Loss =  tensor(0.9686) Pred:  tensor([2.0774e-32, 1.0000e+00, 2.1323e-23], grad_fn=<SoftmaxBackward0>)
# Epoch =  228 Loss =  tensor(0.9701) Pred:  tensor([2.5317e-12, 1.0000e+00, 2.7431e-12], grad_fn=<SoftmaxBackward0>)
# Epoch =  229 Loss =  tensor(0.9684) Pred:  tensor([9.4911e-16, 1.0000e+00, 1.1238e-13], grad_fn=<SoftmaxBackward0>)
# Epoch =  230 Loss =  tensor(0.9689) Pred:  tensor([8.2914e-17, 1.0000e+00, 7.8011e-17], grad_fn=<SoftmaxBackward0>)
# Epoch =  231 Loss =  tensor(0.9677) Pred:  tensor([9.8433e-01, 1.5388e-02, 2.8559e-04], grad_fn=<SoftmaxBackward0>)
# Epoch =  232 Loss =  tensor(0.9695) Pred:  tensor([9.9915e-01, 8.4856e-04, 1.9861e-08], grad_fn=<SoftmaxBackward0>)
# Epoch =  233 Loss =  tensor(0.9679) Pred:  tensor([5.6937e-08, 1.0000e+00, 1.5525e-09], grad_fn=<SoftmaxBackward0>)
# Epoch =  234 Loss =  tensor(0.9696) Pred:  tensor([1.0000e+00, 3.9582e-22, 1.2842e-15], grad_fn=<SoftmaxBackward0>)
# Epoch =  235 Loss =  tensor(0.9691) Pred:  tensor([1.0000e+00, 9.4941e-09, 1.9105e-07], grad_fn=<SoftmaxBackward0>)
# Epoch =  236 Loss =  tensor(0.9684) Pred:  tensor([1.0000e+00, 6.4325e-24, 5.4029e-16], grad_fn=<SoftmaxBackward0>)
# Epoch =  237 Loss =  tensor(0.9684) Pred:  tensor([1.0000e+00, 4.8397e-24, 4.7299e-16], grad_fn=<SoftmaxBackward0>)
# Epoch =  238 Loss =  tensor(0.9701) Pred:  tensor([1.0000e+00, 2.4965e-14, 1.4876e-10], grad_fn=<SoftmaxBackward0>)
# Epoch =  239 Loss =  tensor(0.9685) Pred:  tensor([9.2431e-06, 9.9999e-01, 5.1024e-08], grad_fn=<SoftmaxBackward0>)
# Epoch =  240 Loss =  tensor(0.9678) Pred:  tensor([4.7785e-03, 9.9522e-01, 2.2861e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  241 Loss =  tensor(0.9706) Pred:  tensor([9.8573e-01, 1.4228e-02, 4.4658e-05], grad_fn=<SoftmaxBackward0>)
# Epoch =  242 Loss =  tensor(0.9686) Pred:  tensor([2.9815e-07, 1.0000e+00, 3.3936e-09], grad_fn=<SoftmaxBackward0>)
# Epoch =  243 Loss =  tensor(0.9695) Pred:  tensor([1.0000e+00, 4.4696e-24, 5.7061e-21], grad_fn=<SoftmaxBackward0>)
# Epoch =  244 Loss =  tensor(0.9682) Pred:  tensor([6.7465e-04, 9.9933e-01, 2.2915e-08], grad_fn=<SoftmaxBackward0>)
# Epoch =  245 Loss =  tensor(0.9688) Pred:  tensor([1.0000e+00, 0.0000e+00, 8.9517e-35], grad_fn=<SoftmaxBackward0>)
# Epoch =  246 Loss =  tensor(0.9672) Pred:  tensor([1., 0., 0.], grad_fn=<SoftmaxBackward0>)
# Epoch =  247 Loss =  tensor(0.9675) Pred:  tensor([1.0000e+00, 0.0000e+00, 2.3962e-28], grad_fn=<SoftmaxBackward0>)
# Epoch =  248 Loss =  tensor(0.9685) Pred:  tensor([5.9766e-11, 1.0000e+00, 1.0634e-11], grad_fn=<SoftmaxBackward0>)
# Epoch =  249 Loss =  tensor(0.9704) Pred:  tensor([1.0000e+00, 2.2936e-14, 4.7396e-11], grad_fn=<SoftmaxBackward0>)
# Epoch =  250 Loss =  tensor(0.9680) Pred:  tensor([1., 0., 0.], grad_fn=<SoftmaxBackward0>)
# Epoch =  251 Loss =  tensor(0.9696) Pred:  tensor([1.0000e+00, 6.4456e-23, 1.1035e-15], grad_fn=<SoftmaxBackward0>)
# Epoch =  252 Loss =  tensor(0.9721) Pred:  tensor([1.0000e+00, 7.7556e-16, 2.7557e-12], grad_fn=<SoftmaxBackward0>)
# Epoch =  253 Loss =  tensor(0.9706) Pred:  tensor([1.0000e+00, 0.0000e+00, 1.8504e-33], grad_fn=<SoftmaxBackward0>)
# Epoch =  254 Loss =  tensor(0.9700) Pred:  tensor([9.9826e-01, 1.7232e-03, 1.4206e-05], grad_fn=<SoftmaxBackward0>)
# Epoch =  255 Loss =  tensor(0.9683) Pred:  tensor([1.0000e+00, 3.1978e-16, 7.8888e-13], grad_fn=<SoftmaxBackward0>)
# Epoch =  256 Loss =  tensor(0.9717) Pred:  tensor([1.0000e+00, 0.0000e+00, 1.3350e-37], grad_fn=<SoftmaxBackward0>)
# Epoch =  257 Loss =  tensor(0.9685) Pred:  tensor([1.0000e+00, 0.0000e+00, 3.0121e-32], grad_fn=<SoftmaxBackward0>)
# Epoch =  258 Loss =  tensor(0.9680) Pred:  tensor([1.0000e+00, 4.4231e-26, 1.4920e-18], grad_fn=<SoftmaxBackward0>)
# Epoch =  259 Loss =  tensor(0.9693) Pred:  tensor([1.0000e+00, 0.0000e+00, 1.3896e-39], grad_fn=<SoftmaxBackward0>)
# Epoch =  260 Loss =  tensor(0.9678) Pred:  tensor([9.5587e-11, 1.0000e+00, 2.8479e-10], grad_fn=<SoftmaxBackward0>)
# Epoch =  261 Loss =  tensor(0.9709) Pred:  tensor([1.0000e+00, 0.0000e+00, 9.1967e-42], grad_fn=<SoftmaxBackward0>)
# Epoch =  262 Loss =  tensor(0.9690) Pred:  tensor([7.4074e-10, 1.0000e+00, 3.7387e-11], grad_fn=<SoftmaxBackward0>)
# Epoch =  263 Loss =  tensor(0.9713) Pred:  tensor([6.6801e-19, 1.0000e+00, 8.0091e-15], grad_fn=<SoftmaxBackward0>)
# Epoch =  264 Loss =  tensor(0.9677) Pred:  tensor([1.0000e+00, 4.1619e-43, 1.7192e-28], grad_fn=<SoftmaxBackward0>)
# Epoch =  265 Loss =  tensor(0.9678) Pred:  tensor([9.9999e-01, 6.9815e-06, 3.3888e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  266 Loss =  tensor(0.9818) Pred:  tensor([1.0000e+00, 2.7504e-29, 6.8529e-19], grad_fn=<SoftmaxBackward0>)
# Epoch =  267 Loss =  tensor(0.9698) Pred:  tensor([1., 0., 0.], grad_fn=<SoftmaxBackward0>)
# Epoch =  268 Loss =  tensor(0.9688) Pred:  tensor([1.0000e+00, 7.6798e-24, 2.2350e-16], grad_fn=<SoftmaxBackward0>)
# Epoch =  269 Loss =  tensor(0.9689) Pred:  tensor([9.9215e-14, 1.0000e+00, 4.2050e-13], grad_fn=<SoftmaxBackward0>)
# Epoch =  270 Loss =  tensor(0.9685) Pred:  tensor([1.0000e+00, 1.0298e-16, 2.7163e-12], grad_fn=<SoftmaxBackward0>)
# Epoch =  271 Loss =  tensor(0.9688) Pred:  tensor([4.6175e-06, 1.0000e+00, 1.6443e-09], grad_fn=<SoftmaxBackward0>)
# Epoch =  272 Loss =  tensor(0.9700) Pred:  tensor([1.0000e+00, 1.9252e-12, 4.8695e-15], grad_fn=<SoftmaxBackward0>)
# Epoch =  273 Loss =  tensor(0.9682) Pred:  tensor([1., 0., 0.], grad_fn=<SoftmaxBackward0>)
# Epoch =  274 Loss =  tensor(0.9685) Pred:  tensor([1.0000e+00, 1.3489e-13, 1.3905e-10], grad_fn=<SoftmaxBackward0>)
# Epoch =  275 Loss =  tensor(0.9704) Pred:  tensor([2.0079e-09, 1.0000e+00, 2.2199e-11], grad_fn=<SoftmaxBackward0>)
# Epoch =  276 Loss =  tensor(0.9684) Pred:  tensor([1.0000e+00, 2.3217e-26, 1.1511e-21], grad_fn=<SoftmaxBackward0>)
# Epoch =  277 Loss =  tensor(0.9715) Pred:  tensor([3.6417e-16, 1.0000e+00, 2.2515e-14], grad_fn=<SoftmaxBackward0>)
# Epoch =  278 Loss =  tensor(0.9682) Pred:  tensor([1.0000e+00, 2.8908e-23, 8.2889e-16], grad_fn=<SoftmaxBackward0>)
# Epoch =  279 Loss =  tensor(0.9676) Pred:  tensor([1.0000e+00, 1.2307e-17, 2.1282e-12], grad_fn=<SoftmaxBackward0>)
# Epoch =  280 Loss =  tensor(0.9683) Pred:  tensor([9.8714e-01, 1.2855e-02, 3.6372e-07], grad_fn=<SoftmaxBackward0>)
# Epoch =  281 Loss =  tensor(0.9703) Pred:  tensor([1.0000e+00, 1.0005e-38, 3.2858e-24], grad_fn=<SoftmaxBackward0>)
# Epoch =  282 Loss =  tensor(0.9700) Pred:  tensor([1.0000e+00, 1.0398e-42, 3.2911e-27], grad_fn=<SoftmaxBackward0>)
# Epoch =  283 Loss =  tensor(0.9683) Pred:  tensor([1.0000e+00, 1.2838e-23, 2.5823e-16], grad_fn=<SoftmaxBackward0>)
# Epoch =  284 Loss =  tensor(0.9687) Pred:  tensor([5.5061e-11, 1.0000e+00, 5.0694e-11], grad_fn=<SoftmaxBackward0>)
# Epoch =  285 Loss =  tensor(0.9686) Pred:  tensor([1.0000e+00, 3.4999e-09, 7.8130e-08], grad_fn=<SoftmaxBackward0>)
# Epoch =  286 Loss =  tensor(0.9711) Pred:  tensor([7.7068e-12, 1.0000e+00, 1.6366e-10], grad_fn=<SoftmaxBackward0>)
# Epoch =  287 Loss =  tensor(0.9672) Pred:  tensor([9.9996e-01, 2.1260e-05, 1.4579e-05], grad_fn=<SoftmaxBackward0>)
# Epoch =  288 Loss =  tensor(0.9690) Pred:  tensor([1.9600e-04, 9.9980e-01, 2.0570e-07], grad_fn=<SoftmaxBackward0>)
# Epoch =  289 Loss =  tensor(0.9701) Pred:  tensor([9.9972e-01, 2.7862e-04, 1.4212e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  290 Loss =  tensor(0.9673) Pred:  tensor([1.0000e+00, 2.4656e-09, 1.2863e-07], grad_fn=<SoftmaxBackward0>)
# Epoch =  291 Loss =  tensor(0.9675) Pred:  tensor([1.7259e-03, 9.9827e-01, 1.7262e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  292 Loss =  tensor(0.9694) Pred:  tensor([1.3870e-02, 9.8603e-01, 1.0397e-04], grad_fn=<SoftmaxBackward0>)
# Epoch =  293 Loss =  tensor(0.9693) Pred:  tensor([1.0000e+00, 2.7052e-14, 1.6340e-10], grad_fn=<SoftmaxBackward0>)
# Epoch =  294 Loss =  tensor(0.9679) Pred:  tensor([1.0000e+00, 0.0000e+00, 9.3745e-39], grad_fn=<SoftmaxBackward0>)
# Epoch =  295 Loss =  tensor(0.9705) Pred:  tensor([1., 0., 0.], grad_fn=<SoftmaxBackward0>)
# Epoch =  296 Loss =  tensor(0.9696) Pred:  tensor([9.2828e-01, 7.1649e-02, 6.9238e-05], grad_fn=<SoftmaxBackward0>)
# Epoch =  297 Loss =  tensor(0.9686) Pred:  tensor([9.9990e-01, 9.1935e-05, 7.2056e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  298 Loss =  tensor(0.9695) Pred:  tensor([1.0000e+00, 5.6727e-25, 1.1126e-16], grad_fn=<SoftmaxBackward0>)
# Epoch =  299 Loss =  tensor(0.9694) Pred:  tensor([2.1868e-15, 1.0000e+00, 1.0230e-13], grad_fn=<SoftmaxBackward0>)
# Epoch =  300 Loss =  tensor(0.9682) Pred:  tensor([1.0000e+00, 3.8749e-14, 4.1478e-10], grad_fn=<SoftmaxBackward0>)
# Epoch =  301 Loss =  tensor(0.9698) Pred:  tensor([1.0000e+00, 0.0000e+00, 1.3364e-32], grad_fn=<SoftmaxBackward0>)
# Epoch =  302 Loss =  tensor(0.9682) Pred:  tensor([9.9794e-01, 2.0502e-03, 1.0658e-05], grad_fn=<SoftmaxBackward0>)
# Epoch =  303 Loss =  tensor(0.9679) Pred:  tensor([9.9906e-01, 9.3591e-04, 1.8829e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  304 Loss =  tensor(0.9669) Pred:  tensor([3.6919e-20, 1.0000e+00, 2.0669e-18], grad_fn=<SoftmaxBackward0>)
# Epoch =  305 Loss =  tensor(0.9683) Pred:  tensor([1., 0., 0.], grad_fn=<SoftmaxBackward0>)
# Epoch =  306 Loss =  tensor(0.9682) Pred:  tensor([3.7229e-03, 9.9628e-01, 9.3987e-08], grad_fn=<SoftmaxBackward0>)
# Epoch =  307 Loss =  tensor(0.9694) Pred:  tensor([1.0000e+00, 1.9024e-14, 2.3241e-10], grad_fn=<SoftmaxBackward0>)
# Epoch =  308 Loss =  tensor(0.9668) Pred:  tensor([8.1411e-09, 1.0000e+00, 1.3989e-09], grad_fn=<SoftmaxBackward0>)
# Epoch =  309 Loss =  tensor(0.9666) Pred:  tensor([1.5453e-04, 9.9985e-01, 3.6783e-07], grad_fn=<SoftmaxBackward0>)
# Epoch =  310 Loss =  tensor(0.9671) Pred:  tensor([1.0000e+00, 7.1390e-15, 1.7107e-12], grad_fn=<SoftmaxBackward0>)
# Epoch =  311 Loss =  tensor(0.9680) Pred:  tensor([1., 0., 0.], grad_fn=<SoftmaxBackward0>)
# Epoch =  312 Loss =  tensor(0.9689) Pred:  tensor([1.0000e+00, 4.4231e-16, 5.6129e-13], grad_fn=<SoftmaxBackward0>)
# Epoch =  313 Loss =  tensor(0.9678) Pred:  tensor([1.0000e+00, 1.4649e-33, 4.1918e-22], grad_fn=<SoftmaxBackward0>)
# Epoch =  314 Loss =  tensor(0.9684) Pred:  tensor([1.5232e-17, 1.0000e+00, 1.5868e-13], grad_fn=<SoftmaxBackward0>)
# Epoch =  315 Loss =  tensor(0.9685) Pred:  tensor([2.6101e-10, 1.0000e+00, 4.4842e-11], grad_fn=<SoftmaxBackward0>)
# Epoch =  316 Loss =  tensor(0.9674) Pred:  tensor([9.9974e-01, 2.1739e-04, 4.7413e-05], grad_fn=<SoftmaxBackward0>)
# Epoch =  317 Loss =  tensor(0.9661) Pred:  tensor([3.2344e-04, 9.9968e-01, 6.0027e-07], grad_fn=<SoftmaxBackward0>)
# Epoch =  318 Loss =  tensor(0.9670) Pred:  tensor([1.0000e+00, 1.5571e-12, 1.4207e-09], grad_fn=<SoftmaxBackward0>)
# Epoch =  319 Loss =  tensor(0.9660) Pred:  tensor([1.0000e+00, 5.7989e-17, 3.3878e-12], grad_fn=<SoftmaxBackward0>)
# Epoch =  320 Loss =  tensor(0.9684) Pred:  tensor([1.0053e-23, 1.0000e+00, 1.6881e-18], grad_fn=<SoftmaxBackward0>)
# Epoch =  321 Loss =  tensor(0.9681) Pred:  tensor([9.9169e-01, 8.2703e-03, 3.7562e-05], grad_fn=<SoftmaxBackward0>)
# Epoch =  322 Loss =  tensor(0.9664) Pred:  tensor([9.9990e-01, 9.8227e-05, 1.9621e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  323 Loss =  tensor(0.9662) Pred:  tensor([9.9882e-01, 1.1829e-03, 1.6941e-07], grad_fn=<SoftmaxBackward0>)
# Epoch =  324 Loss =  tensor(0.9660) Pred:  tensor([1.0000e+00, 1.0195e-06, 8.3778e-07], grad_fn=<SoftmaxBackward0>)
# Epoch =  325 Loss =  tensor(0.9677) Pred:  tensor([1.0000e+00, 4.3873e-29, 1.8281e-19], grad_fn=<SoftmaxBackward0>)
# Epoch =  326 Loss =  tensor(0.9654) Pred:  tensor([1.0000e+00, 0.0000e+00, 2.9826e-29], grad_fn=<SoftmaxBackward0>)
# Epoch =  327 Loss =  tensor(0.9690) Pred:  tensor([1.0000e+00, 1.0357e-32, 1.6538e-22], grad_fn=<SoftmaxBackward0>)
# Epoch =  328 Loss =  tensor(0.9675) Pred:  tensor([9.9964e-01, 3.4552e-04, 1.0921e-05], grad_fn=<SoftmaxBackward0>)
# Epoch =  329 Loss =  tensor(0.9680) Pred:  tensor([1.0000e+00, 3.8750e-16, 8.8050e-13], grad_fn=<SoftmaxBackward0>)
# Epoch =  330 Loss =  tensor(0.9662) Pred:  tensor([5.4028e-12, 1.0000e+00, 9.1714e-12], grad_fn=<SoftmaxBackward0>)
# Epoch =  331 Loss =  tensor(0.9674) Pred:  tensor([1., 0., 0.], grad_fn=<SoftmaxBackward0>)
# Epoch =  332 Loss =  tensor(0.9677) Pred:  tensor([4.6353e-09, 1.0000e+00, 2.9290e-11], grad_fn=<SoftmaxBackward0>)
# Epoch =  333 Loss =  tensor(0.9663) Pred:  tensor([1.0000e+00, 0.0000e+00, 8.0692e-35], grad_fn=<SoftmaxBackward0>)
# Epoch =  334 Loss =  tensor(0.9670) Pred:  tensor([1.0000e+00, 1.3937e-14, 3.8419e-11], grad_fn=<SoftmaxBackward0>)
# Epoch =  335 Loss =  tensor(0.9661) Pred:  tensor([1.0000e+00, 0.0000e+00, 3.5942e-39], grad_fn=<SoftmaxBackward0>)
# Epoch =  336 Loss =  tensor(0.9679) Pred:  tensor([1.0000e+00, 5.9824e-14, 4.8098e-10], grad_fn=<SoftmaxBackward0>)
# Epoch =  337 Loss =  tensor(0.9740) Pred:  tensor([9.9999e-01, 7.9192e-06, 1.6218e-10], grad_fn=<SoftmaxBackward0>)
# Epoch =  338 Loss =  tensor(0.9675) Pred:  tensor([1.0000e+00, 3.2085e-30, 6.0019e-20], grad_fn=<SoftmaxBackward0>)
# Epoch =  339 Loss =  tensor(0.9680) Pred:  tensor([1.9690e-05, 9.9998e-01, 1.3784e-07], grad_fn=<SoftmaxBackward0>)
# Epoch =  340 Loss =  tensor(0.9664) Pred:  tensor([9.7725e-01, 2.2564e-02, 1.8360e-04], grad_fn=<SoftmaxBackward0>)
# Epoch =  341 Loss =  tensor(0.9683) Pred:  tensor([1.0000e+00, 5.0755e-32, 2.9164e-21], grad_fn=<SoftmaxBackward0>)
# Epoch =  342 Loss =  tensor(0.9686) Pred:  tensor([2.1044e-13, 1.0000e+00, 5.2605e-13], grad_fn=<SoftmaxBackward0>)
# Epoch =  343 Loss =  tensor(0.9681) Pred:  tensor([8.0459e-03, 9.9188e-01, 7.2498e-05], grad_fn=<SoftmaxBackward0>)
# Epoch =  344 Loss =  tensor(0.9675) Pred:  tensor([2.5130e-06, 1.0000e+00, 1.0956e-09], grad_fn=<SoftmaxBackward0>)
# Epoch =  345 Loss =  tensor(0.9673) Pred:  tensor([1.0000e+00, 5.2354e-07, 6.8822e-07], grad_fn=<SoftmaxBackward0>)
# Epoch =  346 Loss =  tensor(0.9703) Pred:  tensor([1.0000e+00, 5.1533e-13, 4.2064e-12], grad_fn=<SoftmaxBackward0>)
# Epoch =  347 Loss =  tensor(0.9680) Pred:  tensor([5.5652e-34, 1.0000e+00, 5.6589e-24], grad_fn=<SoftmaxBackward0>)
# Epoch =  348 Loss =  tensor(0.9672) Pred:  tensor([1.0000e+00, 2.3090e-37, 3.2765e-25], grad_fn=<SoftmaxBackward0>)
# Epoch =  349 Loss =  tensor(0.9670) Pred:  tensor([1.0000e+00, 1.0319e-37, 2.3528e-24], grad_fn=<SoftmaxBackward0>)
# Epoch =  350 Loss =  tensor(0.9675) Pred:  tensor([1.0000e+00, 0.0000e+00, 7.1427e-30], grad_fn=<SoftmaxBackward0>)
# Epoch =  351 Loss =  tensor(0.9665) Pred:  tensor([6.3715e-09, 1.0000e+00, 1.2580e-10], grad_fn=<SoftmaxBackward0>)
# Epoch =  352 Loss =  tensor(0.9676) Pred:  tensor([5.5706e-19, 1.0000e+00, 3.5313e-17], grad_fn=<SoftmaxBackward0>)
# Epoch =  353 Loss =  tensor(0.9685) Pred:  tensor([1.9125e-18, 1.0000e+00, 4.7041e-14], grad_fn=<SoftmaxBackward0>)
# Epoch =  354 Loss =  tensor(0.9661) Pred:  tensor([1.1855e-14, 1.0000e+00, 1.6077e-13], grad_fn=<SoftmaxBackward0>)
# Epoch =  355 Loss =  tensor(0.9679) Pred:  tensor([1.0000e+00, 3.4314e-15, 1.1622e-10], grad_fn=<SoftmaxBackward0>)
# Epoch =  356 Loss =  tensor(0.9671) Pred:  tensor([2.9177e-15, 1.0000e+00, 1.6271e-14], grad_fn=<SoftmaxBackward0>)
# Epoch =  357 Loss =  tensor(0.9678) Pred:  tensor([1.0122e-22, 1.0000e+00, 1.4157e-19], grad_fn=<SoftmaxBackward0>)
# Epoch =  358 Loss =  tensor(0.9665) Pred:  tensor([5.0168e-08, 1.0000e+00, 4.5759e-09], grad_fn=<SoftmaxBackward0>)
# Epoch =  359 Loss =  tensor(0.9661) Pred:  tensor([1., 0., 0.], grad_fn=<SoftmaxBackward0>)
# Epoch =  360 Loss =  tensor(0.9665) Pred:  tensor([1.0000e+00, 0.0000e+00, 1.0310e-31], grad_fn=<SoftmaxBackward0>)
# Epoch =  361 Loss =  tensor(0.9668) Pred:  tensor([1.0000e+00, 1.8191e-31, 1.1681e-24], grad_fn=<SoftmaxBackward0>)
# Epoch =  362 Loss =  tensor(0.9675) Pred:  tensor([1.0000e+00, 8.6117e-34, 1.0130e-21], grad_fn=<SoftmaxBackward0>)
# Epoch =  363 Loss =  tensor(0.9675) Pred:  tensor([9.9998e-01, 2.2971e-05, 1.7904e-08], grad_fn=<SoftmaxBackward0>)
# Epoch =  364 Loss =  tensor(0.9676) Pred:  tensor([9.9955e-01, 4.4280e-04, 4.1133e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  365 Loss =  tensor(0.9672) Pred:  tensor([1., 0., 0.], grad_fn=<SoftmaxBackward0>)
# Epoch =  366 Loss =  tensor(0.9679) Pred:  tensor([1.0000e+00, 0.0000e+00, 4.6411e-42], grad_fn=<SoftmaxBackward0>)
# Epoch =  367 Loss =  tensor(0.9673) Pred:  tensor([9.9777e-01, 2.2196e-03, 5.6785e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  368 Loss =  tensor(0.9669) Pred:  tensor([1.0000e+00, 3.6705e-28, 1.5819e-18], grad_fn=<SoftmaxBackward0>)
# Epoch =  369 Loss =  tensor(0.9660) Pred:  tensor([1.0000e+00, 7.1985e-42, 1.7975e-27], grad_fn=<SoftmaxBackward0>)
# Epoch =  370 Loss =  tensor(0.9662) Pred:  tensor([1.0000e+00, 4.6576e-22, 4.7412e-15], grad_fn=<SoftmaxBackward0>)
# Epoch =  371 Loss =  tensor(0.9659) Pred:  tensor([1.0000e+00, 2.9158e-35, 5.7665e-23], grad_fn=<SoftmaxBackward0>)
# Epoch =  372 Loss =  tensor(0.9656) Pred:  tensor([1.0000e+00, 5.7338e-14, 3.5155e-10], grad_fn=<SoftmaxBackward0>)
# Epoch =  373 Loss =  tensor(0.9668) Pred:  tensor([2.9809e-31, 1.0000e+00, 2.8674e-22], grad_fn=<SoftmaxBackward0>)
# Epoch =  374 Loss =  tensor(0.9666) Pred:  tensor([1.0000e+00, 5.0226e-09, 9.8373e-08], grad_fn=<SoftmaxBackward0>)
# Epoch =  375 Loss =  tensor(0.9661) Pred:  tensor([1.0000e+00, 0.0000e+00, 1.2440e-37], grad_fn=<SoftmaxBackward0>)
# Epoch =  376 Loss =  tensor(0.9662) Pred:  tensor([1.0000e+00, 4.7670e-16, 4.6041e-11], grad_fn=<SoftmaxBackward0>)
# Epoch =  377 Loss =  tensor(0.9666) Pred:  tensor([8.2771e-18, 1.0000e+00, 6.5708e-17], grad_fn=<SoftmaxBackward0>)
# Epoch =  378 Loss =  tensor(0.9664) Pred:  tensor([1.1294e-18, 1.0000e+00, 1.9357e-17], grad_fn=<SoftmaxBackward0>)
# Epoch =  379 Loss =  tensor(0.9660) Pred:  tensor([1.1086e-08, 1.0000e+00, 1.1619e-09], grad_fn=<SoftmaxBackward0>)
# Epoch =  380 Loss =  tensor(0.9663) Pred:  tensor([1.0405e-13, 1.0000e+00, 1.0427e-12], grad_fn=<SoftmaxBackward0>)
# Epoch =  381 Loss =  tensor(0.9662) Pred:  tensor([1.0000e+00, 2.8199e-16, 2.0441e-11], grad_fn=<SoftmaxBackward0>)
# Epoch =  382 Loss =  tensor(0.9657) Pred:  tensor([1.0000e+00, 6.3785e-33, 8.7689e-22], grad_fn=<SoftmaxBackward0>)
# Epoch =  383 Loss =  tensor(0.9658) Pred:  tensor([2.9803e-18, 1.0000e+00, 1.9169e-15], grad_fn=<SoftmaxBackward0>)
# Epoch =  384 Loss =  tensor(0.9660) Pred:  tensor([7.2640e-17, 1.0000e+00, 2.1284e-13], grad_fn=<SoftmaxBackward0>)
# Epoch =  385 Loss =  tensor(0.9682) Pred:  tensor([1.0000e+00, 0.0000e+00, 7.0071e-30], grad_fn=<SoftmaxBackward0>)
# Epoch =  386 Loss =  tensor(0.9675) Pred:  tensor([9.9280e-01, 7.1798e-03, 2.2039e-05], grad_fn=<SoftmaxBackward0>)
# Epoch =  387 Loss =  tensor(0.9663) Pred:  tensor([2.1996e-15, 1.0000e+00, 1.6582e-13], grad_fn=<SoftmaxBackward0>)
# Epoch =  388 Loss =  tensor(0.9657) Pred:  tensor([4.9315e-24, 1.0000e+00, 3.1897e-20], grad_fn=<SoftmaxBackward0>)
# Epoch =  389 Loss =  tensor(0.9660) Pred:  tensor([1., 0., 0.], grad_fn=<SoftmaxBackward0>)
# Epoch =  390 Loss =  tensor(0.9662) Pred:  tensor([1.0000e+00, 0.0000e+00, 2.5924e-43], grad_fn=<SoftmaxBackward0>)
# Epoch =  391 Loss =  tensor(0.9674) Pred:  tensor([2.3451e-02, 9.7655e-01, 2.0308e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  392 Loss =  tensor(0.9663) Pred:  tensor([1., 0., 0.], grad_fn=<SoftmaxBackward0>)
# Epoch =  393 Loss =  tensor(0.9663) Pred:  tensor([1.0000e+00, 0.0000e+00, 9.3591e-35], grad_fn=<SoftmaxBackward0>)
# Epoch =  394 Loss =  tensor(0.9663) Pred:  tensor([1.0000e+00, 3.5487e-22, 3.8395e-15], grad_fn=<SoftmaxBackward0>)
# Epoch =  395 Loss =  tensor(0.9656) Pred:  tensor([1., 0., 0.], grad_fn=<SoftmaxBackward0>)
# Epoch =  396 Loss =  tensor(0.9656) Pred:  tensor([1., 0., 0.], grad_fn=<SoftmaxBackward0>)
# Epoch =  397 Loss =  tensor(0.9669) Pred:  tensor([6.7580e-03, 9.9323e-01, 7.1966e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  398 Loss =  tensor(0.9658) Pred:  tensor([1.0000e+00, 0.0000e+00, 9.2959e-41], grad_fn=<SoftmaxBackward0>)
# Epoch =  399 Loss =  tensor(0.9708) Pred:  tensor([1.0000e+00, 3.5721e-07, 5.5770e-12], grad_fn=<SoftmaxBackward0>)
# Epoch =  400 Loss =  tensor(0.9689) Pred:  tensor([1.2286e-23, 1.0000e+00, 2.8406e-18], grad_fn=<SoftmaxBackward0>)
# Epoch =  401 Loss =  tensor(0.9697) Pred:  tensor([1.0000e+00, 0.0000e+00, 1.2352e-38], grad_fn=<SoftmaxBackward0>)
# Epoch =  402 Loss =  tensor(0.9661) Pred:  tensor([1., 0., 0.], grad_fn=<SoftmaxBackward0>)
# Epoch =  403 Loss =  tensor(0.9670) Pred:  tensor([1., 0., 0.], grad_fn=<SoftmaxBackward0>)
# Epoch =  404 Loss =  tensor(0.9664) Pred:  tensor([1., 0., 0.], grad_fn=<SoftmaxBackward0>)
# Epoch =  405 Loss =  tensor(0.9663) Pred:  tensor([9.9777e-01, 2.2276e-03, 4.1166e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  406 Loss =  tensor(0.9666) Pred:  tensor([1.0000e+00, 5.3034e-12, 1.0068e-09], grad_fn=<SoftmaxBackward0>)
# Epoch =  407 Loss =  tensor(0.9665) Pred:  tensor([6.3990e-07, 1.0000e+00, 1.8572e-07], grad_fn=<SoftmaxBackward0>)
# Epoch =  408 Loss =  tensor(0.9668) Pred:  tensor([1., 0., 0.], grad_fn=<SoftmaxBackward0>)
# Epoch =  409 Loss =  tensor(0.9661) Pred:  tensor([9.8511e-34, 1.0000e+00, 1.3204e-23], grad_fn=<SoftmaxBackward0>)
# Epoch =  410 Loss =  tensor(0.9657) Pred:  tensor([1.0000e+00, 2.6551e-26, 4.7622e-19], grad_fn=<SoftmaxBackward0>)
# Epoch =  411 Loss =  tensor(0.9656) Pred:  tensor([1., 0., 0.], grad_fn=<SoftmaxBackward0>)
# Epoch =  412 Loss =  tensor(0.9657) Pred:  tensor([9.9964e-01, 3.5433e-04, 2.5356e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  413 Loss =  tensor(0.9668) Pred:  tensor([1.0840e-11, 1.0000e+00, 5.7338e-11], grad_fn=<SoftmaxBackward0>)
# Epoch =  414 Loss =  tensor(0.9664) Pred:  tensor([9.9988e-01, 1.0912e-04, 9.3473e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  415 Loss =  tensor(0.9656) Pred:  tensor([1.0000e+00, 3.0383e-20, 2.5690e-15], grad_fn=<SoftmaxBackward0>)
# Epoch =  416 Loss =  tensor(0.9657) Pred:  tensor([1.0000e+00, 1.0942e-18, 1.3299e-12], grad_fn=<SoftmaxBackward0>)
# Epoch =  417 Loss =  tensor(0.9666) Pred:  tensor([9.9997e-01, 2.4041e-05, 5.1306e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  418 Loss =  tensor(0.9667) Pred:  tensor([7.7362e-09, 1.0000e+00, 7.0509e-10], grad_fn=<SoftmaxBackward0>)
# Epoch =  419 Loss =  tensor(0.9658) Pred:  tensor([5.1852e-20, 1.0000e+00, 4.2355e-18], grad_fn=<SoftmaxBackward0>)
# Epoch =  420 Loss =  tensor(0.9657) Pred:  tensor([5.5331e-07, 1.0000e+00, 8.5397e-08], grad_fn=<SoftmaxBackward0>)
# Epoch =  421 Loss =  tensor(0.9657) Pred:  tensor([5.7721e-09, 1.0000e+00, 1.8605e-09], grad_fn=<SoftmaxBackward0>)
# Epoch =  422 Loss =  tensor(0.9657) Pred:  tensor([1.0000e+00, 0.0000e+00, 7.7251e-30], grad_fn=<SoftmaxBackward0>)
# Epoch =  423 Loss =  tensor(0.9659) Pred:  tensor([9.9993e-01, 6.1401e-05, 7.6752e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  424 Loss =  tensor(0.9656) Pred:  tensor([1.1037e-10, 1.0000e+00, 1.7673e-11], grad_fn=<SoftmaxBackward0>)
# Epoch =  425 Loss =  tensor(0.9655) Pred:  tensor([1., 0., 0.], grad_fn=<SoftmaxBackward0>)
# Epoch =  426 Loss =  tensor(0.9657) Pred:  tensor([9.9149e-01, 8.4765e-03, 3.7832e-05], grad_fn=<SoftmaxBackward0>)
# Epoch =  427 Loss =  tensor(0.9659) Pred:  tensor([1., 0., 0.], grad_fn=<SoftmaxBackward0>)
# Epoch =  428 Loss =  tensor(0.9665) Pred:  tensor([1.0000e+00, 0.0000e+00, 2.6319e-36], grad_fn=<SoftmaxBackward0>)
# Epoch =  429 Loss =  tensor(0.9660) Pred:  tensor([1.0000e+00, 1.3887e-18, 1.4399e-13], grad_fn=<SoftmaxBackward0>)
# Epoch =  430 Loss =  tensor(0.9658) Pred:  tensor([1.0000e+00, 9.2997e-18, 2.2028e-13], grad_fn=<SoftmaxBackward0>)
# Epoch =  431 Loss =  tensor(0.9658) Pred:  tensor([2.4218e-03, 9.9757e-01, 4.4827e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  432 Loss =  tensor(0.9654) Pred:  tensor([1.0000e+00, 5.7229e-13, 3.4933e-12], grad_fn=<SoftmaxBackward0>)
# Epoch =  433 Loss =  tensor(0.9656) Pred:  tensor([3.6593e-04, 9.9963e-01, 5.5290e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  434 Loss =  tensor(0.9656) Pred:  tensor([1.0021e-03, 9.9895e-01, 4.3824e-05], grad_fn=<SoftmaxBackward0>)
# Epoch =  435 Loss =  tensor(0.9657) Pred:  tensor([1., 0., 0.], grad_fn=<SoftmaxBackward0>)
# Epoch =  436 Loss =  tensor(0.9655) Pred:  tensor([7.1159e-15, 1.0000e+00, 2.6670e-13], grad_fn=<SoftmaxBackward0>)
# Epoch =  437 Loss =  tensor(0.9653) Pred:  tensor([1.0000e+00, 0.0000e+00, 6.6117e-31], grad_fn=<SoftmaxBackward0>)
# Epoch =  438 Loss =  tensor(0.9656) Pred:  tensor([9.9982e-01, 1.8210e-04, 4.2549e-08], grad_fn=<SoftmaxBackward0>)
# Epoch =  439 Loss =  tensor(0.9696) Pred:  tensor([3.9183e-22, 1.0000e+00, 1.2626e-18], grad_fn=<SoftmaxBackward0>)
# Epoch =  440 Loss =  tensor(0.9681) Pred:  tensor([9.9930e-01, 6.9771e-04, 3.9197e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  441 Loss =  tensor(0.9663) Pred:  tensor([1.4248e-17, 1.0000e+00, 2.0899e-14], grad_fn=<SoftmaxBackward0>)
# Epoch =  442 Loss =  tensor(0.9665) Pred:  tensor([1.0000e+00, 0.0000e+00, 1.4784e-35], grad_fn=<SoftmaxBackward0>)
# Epoch =  443 Loss =  tensor(0.9657) Pred:  tensor([1.7556e-07, 1.0000e+00, 8.9496e-08], grad_fn=<SoftmaxBackward0>)
# Epoch =  444 Loss =  tensor(0.9656) Pred:  tensor([1.0000e+00, 0.0000e+00, 1.7812e-31], grad_fn=<SoftmaxBackward0>)
# Epoch =  445 Loss =  tensor(0.9656) Pred:  tensor([9.9852e-01, 1.4024e-03, 8.1145e-05], grad_fn=<SoftmaxBackward0>)
# Epoch =  446 Loss =  tensor(0.9656) Pred:  tensor([3.2906e-26, 1.0000e+00, 5.2745e-21], grad_fn=<SoftmaxBackward0>)
# Epoch =  447 Loss =  tensor(0.9657) Pred:  tensor([1.0000e+00, 9.1986e-27, 4.2198e-19], grad_fn=<SoftmaxBackward0>)
# Epoch =  448 Loss =  tensor(0.9657) Pred:  tensor([4.8997e-02, 9.5100e-01, 3.7741e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  449 Loss =  tensor(0.9656) Pred:  tensor([9.9172e-01, 8.2387e-03, 3.8326e-05], grad_fn=<SoftmaxBackward0>)
# Epoch =  450 Loss =  tensor(0.9655) Pred:  tensor([1.0000e+00, 0.0000e+00, 6.0161e-31], grad_fn=<SoftmaxBackward0>)
# Epoch =  451 Loss =  tensor(0.9656) Pred:  tensor([1.8601e-19, 1.0000e+00, 1.6254e-14], grad_fn=<SoftmaxBackward0>)
# Epoch =  452 Loss =  tensor(0.9656) Pred:  tensor([1.0000e+00, 1.3737e-19, 2.0250e-13], grad_fn=<SoftmaxBackward0>)
# Epoch =  453 Loss =  tensor(0.9653) Pred:  tensor([2.4946e-17, 1.0000e+00, 7.5801e-15], grad_fn=<SoftmaxBackward0>)
# Epoch =  454 Loss =  tensor(0.9655) Pred:  tensor([3.0853e-13, 1.0000e+00, 3.5949e-12], grad_fn=<SoftmaxBackward0>)
# Epoch =  455 Loss =  tensor(0.9653) Pred:  tensor([9.9018e-01, 9.7893e-03, 2.8095e-05], grad_fn=<SoftmaxBackward0>)
# Epoch =  456 Loss =  tensor(0.9652) Pred:  tensor([1.0000e+00, 0.0000e+00, 5.6035e-41], grad_fn=<SoftmaxBackward0>)
# Epoch =  457 Loss =  tensor(0.9656) Pred:  tensor([1.0000e+00, 8.9125e-36, 5.2874e-24], grad_fn=<SoftmaxBackward0>)
# Epoch =  458 Loss =  tensor(0.9653) Pred:  tensor([9.3540e-16, 1.0000e+00, 1.0715e-13], grad_fn=<SoftmaxBackward0>)
# Epoch =  459 Loss =  tensor(0.9652) Pred:  tensor([9.9966e-01, 3.2793e-04, 1.6817e-05], grad_fn=<SoftmaxBackward0>)
# Epoch =  460 Loss =  tensor(0.9654) Pred:  tensor([4.4672e-06, 1.0000e+00, 9.3534e-08], grad_fn=<SoftmaxBackward0>)
# Epoch =  461 Loss =  tensor(0.9655) Pred:  tensor([1.0000e+00, 6.8561e-13, 3.6915e-12], grad_fn=<SoftmaxBackward0>)
# Epoch =  462 Loss =  tensor(0.9653) Pred:  tensor([1.0000e+00, 1.1238e-19, 1.8490e-13], grad_fn=<SoftmaxBackward0>)
# Epoch =  463 Loss =  tensor(0.9656) Pred:  tensor([9.9946e-01, 5.4133e-04, 1.2080e-07], grad_fn=<SoftmaxBackward0>)
# Epoch =  464 Loss =  tensor(0.9655) Pred:  tensor([5.8211e-22, 1.0000e+00, 1.9330e-16], grad_fn=<SoftmaxBackward0>)
# Epoch =  465 Loss =  tensor(0.9653) Pred:  tensor([9.9951e-01, 4.8407e-04, 3.8282e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  466 Loss =  tensor(0.9655) Pred:  tensor([1.3043e-23, 1.0000e+00, 2.3710e-18], grad_fn=<SoftmaxBackward0>)
# Epoch =  467 Loss =  tensor(0.9655) Pred:  tensor([9.9999e-01, 1.4948e-05, 2.2486e-10], grad_fn=<SoftmaxBackward0>)
# Epoch =  468 Loss =  tensor(0.9653) Pred:  tensor([7.8797e-33, 1.0000e+00, 5.0823e-23], grad_fn=<SoftmaxBackward0>)
# Epoch =  469 Loss =  tensor(0.9653) Pred:  tensor([1.0000e+00, 2.3663e-30, 2.8197e-24], grad_fn=<SoftmaxBackward0>)
# Epoch =  470 Loss =  tensor(0.9657) Pred:  tensor([1.8426e-14, 1.0000e+00, 3.5630e-12], grad_fn=<SoftmaxBackward0>)
# Epoch =  471 Loss =  tensor(0.9653) Pred:  tensor([6.3467e-31, 1.0000e+00, 3.9522e-22], grad_fn=<SoftmaxBackward0>)
# Epoch =  472 Loss =  tensor(0.9652) Pred:  tensor([1.0000e+00, 1.9889e-18, 6.8745e-13], grad_fn=<SoftmaxBackward0>)
# Epoch =  473 Loss =  tensor(0.9652) Pred:  tensor([2.7456e-20, 1.0000e+00, 7.4169e-16], grad_fn=<SoftmaxBackward0>)
# Epoch =  474 Loss =  tensor(0.9661) Pred:  tensor([1.1057e-01, 8.8942e-01, 5.9151e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  475 Loss =  tensor(0.9653) Pred:  tensor([9.9883e-01, 1.1652e-03, 4.3064e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  476 Loss =  tensor(0.9656) Pred:  tensor([1.0000e+00, 1.7765e-16, 4.1249e-11], grad_fn=<SoftmaxBackward0>)
# Epoch =  477 Loss =  tensor(0.9653) Pred:  tensor([1., 0., 0.], grad_fn=<SoftmaxBackward0>)
# Epoch =  478 Loss =  tensor(0.9655) Pred:  tensor([1.0000e+00, 0.0000e+00, 3.3400e-40], grad_fn=<SoftmaxBackward0>)
# Epoch =  479 Loss =  tensor(0.9653) Pred:  tensor([1.0000e+00, 2.0242e-30, 2.8102e-19], grad_fn=<SoftmaxBackward0>)
# Epoch =  480 Loss =  tensor(0.9655) Pred:  tensor([9.7825e-01, 2.1749e-02, 2.1199e-07], grad_fn=<SoftmaxBackward0>)
# Epoch =  481 Loss =  tensor(0.9654) Pred:  tensor([2.6814e-21, 1.0000e+00, 1.4985e-18], grad_fn=<SoftmaxBackward0>)
# Epoch =  482 Loss =  tensor(0.9653) Pred:  tensor([3.0080e-17, 1.0000e+00, 3.3849e-14], grad_fn=<SoftmaxBackward0>)
# Epoch =  483 Loss =  tensor(0.9652) Pred:  tensor([1., 0., 0.], grad_fn=<SoftmaxBackward0>)
# Epoch =  484 Loss =  tensor(0.9652) Pred:  tensor([3.6369e-26, 1.0000e+00, 8.8607e-21], grad_fn=<SoftmaxBackward0>)
# Epoch =  485 Loss =  tensor(0.9653) Pred:  tensor([1., 0., 0.], grad_fn=<SoftmaxBackward0>)
# Epoch =  486 Loss =  tensor(0.9653) Pred:  tensor([1.0000e+00, 0.0000e+00, 1.4013e-45], grad_fn=<SoftmaxBackward0>)
# Epoch =  487 Loss =  tensor(0.9653) Pred:  tensor([4.3436e-10, 1.0000e+00, 1.9431e-10], grad_fn=<SoftmaxBackward0>)
# Epoch =  488 Loss =  tensor(0.9653) Pred:  tensor([1.0000e+00, 1.5698e-32, 6.5925e-21], grad_fn=<SoftmaxBackward0>)
# Epoch =  489 Loss =  tensor(0.9652) Pred:  tensor([1.0000e+00, 0.0000e+00, 1.9969e-33], grad_fn=<SoftmaxBackward0>)
# Epoch =  490 Loss =  tensor(0.9652) Pred:  tensor([1.3368e-18, 1.0000e+00, 3.6176e-16], grad_fn=<SoftmaxBackward0>)
# Epoch =  491 Loss =  tensor(0.9652) Pred:  tensor([2.1218e-20, 1.0000e+00, 7.6169e-16], grad_fn=<SoftmaxBackward0>)
# Epoch =  492 Loss =  tensor(0.9653) Pred:  tensor([1.0000e+00, 0.0000e+00, 1.7715e-33], grad_fn=<SoftmaxBackward0>)
# Epoch =  493 Loss =  tensor(0.9652) Pred:  tensor([2.2636e-26, 1.0000e+00, 7.2003e-20], grad_fn=<SoftmaxBackward0>)
# Epoch =  494 Loss =  tensor(0.9656) Pred:  tensor([1., 0., 0.], grad_fn=<SoftmaxBackward0>)
# Epoch =  495 Loss =  tensor(0.9653) Pred:  tensor([9.9795e-01, 2.0424e-03, 4.2039e-06], grad_fn=<SoftmaxBackward0>)
# Epoch =  496 Loss =  tensor(0.9653) Pred:  tensor([1.0000e+00, 2.0450e-28, 2.2538e-18], grad_fn=<SoftmaxBackward0>)
# Epoch =  497 Loss =  tensor(0.9655) Pred:  tensor([3.2276e-17, 1.0000e+00, 1.4417e-14], grad_fn=<SoftmaxBackward0>)
# Epoch =  498 Loss =  tensor(0.9651) Pred:  tensor([6.6749e-13, 1.0000e+00, 2.9202e-12], grad_fn=<SoftmaxBackward0>)
# Epoch =  499 Loss =  tensor(0.9652) Pred:  tensor([1.0582e-22, 1.0000e+00, 1.6236e-18], grad_fn=<SoftmaxBackward0>)

# %% [markdown]
# As we see below, the model learns, but fails to acheive the same level of accuracy as the $1$-form model. This suggests that the $1$-simplices are indeed necessary for the model to learn the vector field.

# %%
# plot the loss
fig, ax = plt.subplots()

ax.plot(np.arange(epochs), torch.sum(losses, axis = 0)/batch_size)

plt.show()

# %% [markdown]
# Since everything is in low dimension, we can interpret what our model has learned. We plot the three learned features below, and see that they do not separate the paths into the three classes as well as the $1$-form model.

# %%
# make a 3d scatter plot of vf evaluated on the set of paths, colored by labels
fig = plt.figure(figsize=(10,10))

ax = fig.add_subplot(111, projection='3d')

# evaluate the accuracy of the classifier on the training data
correct = 0
total = 0

for i in range(len(paths)):
        
        p = paths[i]
        l = labels[i]
        
        out = scalar(torch.tensor(p).float())
        X = torch.sum(out, dim = 0)

        lb = torch.argmax(l)

        pred = torch.argmax(torch.nn.functional.softmax(X))

        if pred == torch.argmax(l):
                correct += 1
        total += 1
        
        
        if lb == 0:
            ax.scatter(X[0].detach().numpy(), X[1].detach().numpy(), X[2].detach().numpy(), color = 'green', alpha = 0.5)
        elif lb == 1:
            ax.scatter(X[0].detach().numpy(), X[1].detach().numpy(), X[2].detach().numpy(), color = 'red', alpha = 0.5)
        elif lb == 2:
            ax.scatter(X[0].detach().numpy(), X[1].detach().numpy(), X[2].detach().numpy(), color = 'blue', alpha = 0.5)


# add a title to the figure
ax.set_title('Final feature scalar field embedding')

# print accuracy
print('Accuracy of the network on the 300 training paths: ", %d %%' % (100 * correct / total))
# Out:
# /var/folders/w2/2q_ql79j5_s6kq_b56rg9xdc0000gn/T/ipykernel_973/2434861882.py:20: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   pred = torch.argmax(torch.nn.functional.softmax(X))
# Accuracy of the network on the 300 training paths: ", 58 %

# %% [markdown]
# Finally, below we plot the paths against the features. Learning a set of $0$-forms is akin to learning a set of densities that distinguish the points on along the path in the three classes. Since our paths have a lot of overlap, this is a difficult task. One can see the learned densities do roughly correspond to unique regions of the paths, but this is insufficient to distinguish paths reliably.
#
# In conclusions, the model does not perform as well as the $1$-form model with the same number of parameters and all else equal. Indeed, this shows that in this example the $1$-simplices seem to be helpful in classifying the paths.

# %%
fig, axs = plt.subplots(3, 1, figsize=(5, 15))

# plot the three component vector fields
for i in range(3):
    ax = axs[i]
    plot_scalar_field_comp(scalar, ax, comp = i, x_range=5, y_range=5)

# add a title to the figure
fig.suptitle('Final feature scalar fields')

# add example paths from each class
for i in range(20):

    plot_points(paths[0+i], axs[0], color = 'green', alpha = 0.6, linewidth = 2)

    plot_points(paths[100+i], axs[1], color = 'red', alpha = 0.6, linewidth = 2)

    plot_points(paths[200+i], axs[2], color = 'blue', alpha = 0.6, linewidth = 2)

plt.show()
