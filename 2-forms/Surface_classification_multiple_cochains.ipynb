# %% [markdown]
# # Surface classification using 2-forms
#
# In this notebook we classify synthetic surfaces using $2$-forms and NO MLP

# %%
import numpy as np
import matplotlib as mpl
import torch
import torch.nn as nn
from matplotlib import pyplot as plt
from matplotlib import colors as mcolors
import math
import gudhi as gd 
import scipy.special

import k_forms as kf
import k_forms_visual as vis 

import pickle

import torch.optim as optim

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
num_pts = 5 
pts , ac = kf.plot_unit_square_grid(num_pts)
simplices = []
for s in ac.get_skeleton(2):
    if len(s[0]) == 3: 
        simplices.append(s[0])

print(simplices)
# Out:
# [[0, 1, 5], [1, 2, 6], [1, 5, 6], [2, 3, 7], [2, 6, 7], [3, 4, 8], [3, 7, 8], [4, 8, 9], [5, 6, 10], [6, 7, 11], [6, 10, 11], [7, 8, 12], [7, 11, 12], [8, 9, 13], [8, 12, 13], [9, 13, 14], [10, 11, 15], [11, 12, 16], [11, 15, 16], [12, 13, 17], [12, 16, 17], [13, 14, 18], [13, 17, 18], [14, 18, 19], [15, 16, 20], [16, 17, 21], [16, 20, 21], [17, 18, 22], [17, 21, 22], [18, 19, 23], [18, 22, 23], [19, 23, 24]]

# %%
# generate surface data
num_surf = 100
eps = 3
s0 = kf.generate_surfaces_yz(num_surf, num_pts , eps) ## the surfaces are a bit too regular, change a bit the generation code later
s1 = kf.generate_surfaces_xz(num_surf, num_pts , eps)
#s2 = kf.generate_curved_surfaces(num_surf, num_pts , eps)
surfaces = s0 + s1 

# generate labels
#labels = np.concatenate((np.zeros(num_surf),np.ones(num_surf),2*np.ones(num_surf)))
labels = np.concatenate((np.zeros(num_surf),np.ones(num_surf)))

# perform a one hot encoding of the labels and transform to torch
labels_one_hot = torch.nn.functional.one_hot(torch.tensor(labels).to(torch.int64))

## shuffle the data and the labels in the same way
shuffled_indices = torch.randperm(len(surfaces)) 
surfaces_shuffled = [surfaces[i] for i in shuffled_indices]
labels_one_hot_shuffled = labels_one_hot[shuffled_indices]
labels_shuffled = labels[shuffled_indices]

# %%
surface = surfaces[0][3]
surface
# Out:
# tensor([[-6.6805, -6.5689, -8.3931],
#         [-4.4765, -6.5689, -6.8359],
#         [-2.8542, -6.5689, -7.9893],
#         [ 8.5591, -6.5689, -9.2191],
#         [ 9.9548, -6.5689, -4.9417],
#         [-6.6805, -5.2161, -7.0402],
#         [-4.4765, -5.2161, -5.4831],
#         [-2.8542, -5.2161, -6.6364],
#         [ 8.5591, -5.2161, -7.8663],
#         [ 9.9548, -5.2161, -3.5888],
#         [-6.6805, -3.5660, -5.3901],
#         [-4.4765, -3.5660, -3.8330],
#         [-2.8542, -3.5660, -4.9863],
#         [ 8.5591, -3.5660, -6.2162],
#         [ 9.9548, -3.5660, -1.9387],
#         [-6.6805,  7.1556,  5.3314],
#         [-4.4765,  7.1556,  6.8885],
#         [-2.8542,  7.1556,  5.7352],
#         [ 8.5591,  7.1556,  4.5053],
#         [ 9.9548,  7.1556,  8.7828],
#         [-6.6805,  7.9803,  6.1562],
#         [-4.4765,  7.9803,  7.7133],
#         [-2.8542,  7.9803,  6.5600],
#         [ 8.5591,  7.9803,  5.3301],
#         [ 9.9548,  7.9803,  9.6076]], dtype=torch.float64)

# %%
#make random translation vector 
translation = torch.tensor(np.random.uniform(-10, 10, 3))
translation
# Out:
# tensor([ 5.4970, -5.2885,  9.3070], dtype=torch.float64)

# %%
## making dictionaries out of the surfaces
## decide if shuffle or not when doing this 
surfaces_list = []
for surf in range(num_surf*2): 
    surface = surfaces[surf]
    surface_dict= {}
    surface_dict['simplices'] = simplices

    translation = torch.tensor(np.random.uniform(-10, 10, 3))
    
    surface_dict['points'] = surface[3]
    surface_dict['Phi'] = []
    surface_dict['b'] = []
    


    for i in range(len(surface_dict['simplices'])):
        s = surface_dict['simplices'][i]
        emb_vertices_simplex = surface_dict['points'][s]
        phi_simplex, b_simplex = kf.phi_b(emb_vertices_simplex )
        surface_dict['Phi'].append(phi_simplex)
        surface_dict['b'].append(b_simplex)

    surfaces_list.append(surface_dict)

surfaces_list_shuffled = [surfaces_list[i] for i in shuffled_indices]

len(surfaces_list_shuffled)
# Out:
# 200

# %%
# plot one surface
kf.plot_surface(surfaces[5][0],surfaces[5][1],surfaces[5][2])

# %% [markdown]
# # Learn multiple cochains

# %%
k = 2 
dim = 3 
## Precomputed things: 
det = kf.build_determinant_tensor(dim, k) ## will be needed for integration 
print(k)
print(dim)
print(det.shape)

num_sub = 2
vertices, coefs = kf.subdivide_simplex_coef_torch(num_sub)
# Out:
# 2
# 3
# torch.Size([3, 3, 3])

# %%
classes = 2
num_cochains = 2 ## number of k-forms to learn 

N = int(scipy.special.binom(dim,k))

"""kforms = nn.Sequential(
    nn.Linear(dim, N*num_cochains) ## can add layers here if needed
)"""
# Out:
# 'kforms = nn.Sequential(\n    nn.Linear(dim, N*num_cochains) ## can add layers here if needed\n)'

# %%
kforms = nn.Sequential(
    nn.Linear(dim, 50),
    nn.ReLU(),
    nn.Linear(50, 50),
    nn.ReLU(),
    nn.Linear(50, N*num_cochains) ## can add layers here if needed
)

# %%
epochs = 50

# create your optimizer
#lr = 0.1 
#lr = 1e-2 
lr = 0.1

lr = 1e-3
#

optimizer = optim.SGD(kforms.parameters(), lr) 

criterion = nn.CrossEntropyLoss()

losses = torch.zeros(epochs)

labels_one_hot_shuffled = labels_one_hot_shuffled.to(torch.float32)

torch.autograd.set_detect_anomaly(True)

Accuracies = []
Losses= []

for e in range(epochs):
    print('epoch: ', e)
    
    correct = 0
    total = 0

    for i in range(len(surfaces_list_shuffled)):
        surface_dict= surfaces_list_shuffled[i]
        l = labels_one_hot_shuffled[i]
        
        X = kf.forms2cochains(kforms, surface_dict, det,vertices, coefs, num_sub, num_cochains, dim, k) ## multiple cochains 
        X = torch.reshape(X, (len(surface_dict['simplices']), num_cochains))
        X.retain_grad() 
        X = X.sum(0)
        X.retain_grad()
        #X.grad = None
        # softmax
        sm = torch.nn.functional.softmax(X)
        #print('softmax = ',sm)
        loss = criterion(sm,l) 
        print("loss: ", loss)
        #print('********')
        loss.backward(retain_graph=True)
        optimizer.step()
        optimizer.zero_grad()
        
        pred = torch.argmax(torch.nn.functional.softmax(X))
        #print('pred: ', pred)
        #print('label: ', torch.argmax(l))
        if pred == torch.argmax(l):
            correct += 1
        total += 1
        #print('correct: ', correct)

        if i % 10 == 0:
            print("number of surfaces processed: ", i)

    print('Accuracy of the network on the {} training surfaces at epoch {} : {} '.format(num_surf*2, e, (100 * correct / total)))
    Accuracies.append(100 * correct / total)
    Losses.append(loss)

    print('-----------')
    print('***********')
    print('-----------')
# Out:
# epoch:  0
# /Users/celiahacker/opt/anaconda3/envs/celia/lib/python3.7/site-packages/ipykernel_launcher.py:41: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# loss:  tensor(1.2464, grad_fn=<DivBackward1>)
# /Users/celiahacker/opt/anaconda3/envs/celia/lib/python3.7/site-packages/ipykernel_launcher.py:50: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# number of surfaces processed:  0
# loss:  tensor(0.3509, grad_fn=<DivBackward1>)
# loss:  tensor(0.4736, grad_fn=<DivBackward1>)
# loss:  tensor(1.0999, grad_fn=<DivBackward1>)
# loss:  tensor(1.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(1.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(1.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.9055, grad_fn=<DivBackward1>)
# loss:  tensor(0.3227, grad_fn=<DivBackward1>)
# number of surfaces processed:  10
# loss:  tensor(0.3173, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(1.2977, grad_fn=<DivBackward1>)
# loss:  tensor(0.3213, grad_fn=<DivBackward1>)
# loss:  tensor(1.3071, grad_fn=<DivBackward1>)
# loss:  tensor(1.3131, grad_fn=<DivBackward1>)
# loss:  tensor(0.9537, grad_fn=<DivBackward1>)
# loss:  tensor(0.3163, grad_fn=<DivBackward1>)
# loss:  tensor(0.4163, grad_fn=<DivBackward1>)
# number of surfaces processed:  20
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3152, grad_fn=<DivBackward1>)
# loss:  tensor(0.3164, grad_fn=<DivBackward1>)
# loss:  tensor(0.3187, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(1.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3984, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.4460, grad_fn=<DivBackward1>)
# number of surfaces processed:  30
# loss:  tensor(1.3132, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3664, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3136, grad_fn=<DivBackward1>)
# loss:  tensor(1.3096, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(1.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  40
# loss:  tensor(1.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3576, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3228, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3178, grad_fn=<DivBackward1>)
# number of surfaces processed:  50
# loss:  tensor(1.3132, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3275, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3359, grad_fn=<DivBackward1>)
# loss:  tensor(1.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(1.3132, grad_fn=<DivBackward1>)
# number of surfaces processed:  60
# loss:  tensor(1.3011, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(1.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3308, grad_fn=<DivBackward1>)
# loss:  tensor(0.4053, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(1.3110, grad_fn=<DivBackward1>)
# number of surfaces processed:  70
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(1.2501, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.4508, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3135, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  80
# loss:  tensor(0.3149, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3138, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(1.2780, grad_fn=<DivBackward1>)
# loss:  tensor(0.3144, grad_fn=<DivBackward1>)
# loss:  tensor(0.9589, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  90
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3177, grad_fn=<DivBackward1>)
# loss:  tensor(0.9562, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  100
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3188, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.6360, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(1.1938, grad_fn=<DivBackward1>)
# number of surfaces processed:  110
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3545, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3667, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  120
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  130
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3344, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  140
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.6031, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  150
# loss:  tensor(0.3643, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  160
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3178, grad_fn=<DivBackward1>)
# loss:  tensor(0.3135, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  170
# loss:  tensor(0.3140, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3530, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3893, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  180
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3148, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3168, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.6720, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  190
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3400, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# Accuracy of the network on the 200 training surfaces at epoch 0 : 87.0
# -----------
# ***********
# -----------
# epoch:  1
# loss:  tensor(0.5261, grad_fn=<DivBackward1>)
# number of surfaces processed:  0
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3166, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  10
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3141, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  20
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3218, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  30
# loss:  tensor(0.3242, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3143, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  40
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  50
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  60
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3624, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  70
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3163, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  80
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3157, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  90
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  100
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3141, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.9867, grad_fn=<DivBackward1>)
# number of surfaces processed:  110
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3135, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  120
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  130
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3448, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  140
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3136, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  150
# loss:  tensor(0.3218, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  160
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3139, grad_fn=<DivBackward1>)
# loss:  tensor(0.3136, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  170
# loss:  tensor(0.3157, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3180, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3527, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  180
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3135, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# number of surfaces processed:  190
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3230, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# Accuracy of the network on the 200 training surfaces at epoch 1 : 99.5
# -----------
# ***********
# -----------
# epoch:  2
# loss:  tensor(0.4265, grad_fn=<DivBackward1>)
# number of surfaces processed:  0
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3158, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  10
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3137, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  20
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3220, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  30
# loss:  tensor(0.3189, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3142, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  40
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  50
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  60
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3173, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  70
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3167, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  80
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3136, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  90
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  100
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3680, grad_fn=<DivBackward1>)
# number of surfaces processed:  110
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3135, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  120
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  130
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3456, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  140
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3136, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  150
# loss:  tensor(0.3214, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  160
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3138, grad_fn=<DivBackward1>)
# loss:  tensor(0.3135, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  170
# loss:  tensor(0.3151, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3181, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3534, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  180
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3135, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# number of surfaces processed:  190
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3197, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# Accuracy of the network on the 200 training surfaces at epoch 2 : 100.0
# -----------
# ***********
# -----------
# epoch:  3
# loss:  tensor(0.4034, grad_fn=<DivBackward1>)
# number of surfaces processed:  0
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3153, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  10
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3136, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  20
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3219, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  30
# loss:  tensor(0.3174, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3142, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  40
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  50
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  60
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3188, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  70
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3161, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  80
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3135, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  90
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  100
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3387, grad_fn=<DivBackward1>)
# number of surfaces processed:  110
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  120
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  130
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3445, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  140
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3135, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  150
# loss:  tensor(0.3202, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  160
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3137, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  170
# loss:  tensor(0.3150, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3178, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3506, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  180
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3135, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# number of surfaces processed:  190
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3186, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# Accuracy of the network on the 200 training surfaces at epoch 3 : 100.0
# -----------
# ***********
# -----------
# epoch:  4
# loss:  tensor(0.3932, grad_fn=<DivBackward1>)
# number of surfaces processed:  0
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3152, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  10
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3136, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  20
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3216, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  30
# loss:  tensor(0.3170, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3141, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  40
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  50
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  60
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3166, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  70
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3157, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  80
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  90
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  100
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3302, grad_fn=<DivBackward1>)
# number of surfaces processed:  110
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  120
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  130
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3433, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  140
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3135, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  150
# ...
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3212, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  30
# loss:  tensor(0.3167, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3140, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  40
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  50
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  60
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3156, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  70
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3154, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  80
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  90
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  100
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3259, grad_fn=<DivBackward1>)
# number of surfaces processed:  110
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  120
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  130
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3421, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  140
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  150
# loss:  tensor(0.3188, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  160
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3136, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  170
# loss:  tensor(0.3148, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3174, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3455, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  180
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# number of surfaces processed:  190
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3173, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# Accuracy of the network on the 200 training surfaces at epoch 5 : 100.0
# -----------
# ***********
# -----------
# epoch:  6
# loss:  tensor(0.3801, grad_fn=<DivBackward1>)
# number of surfaces processed:  0
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3150, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  10
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3135, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  20
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3209, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  30
# loss:  tensor(0.3164, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3139, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# number of surfaces processed:  40
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/2j/2qw49ghn6wl0sxs7390sbf8w0000gp/T/ipykernel_63305/3559998585.py in <module>
#      32         l = labels_one_hot_shuffled[i]
#      33
# ---> 34         X = kf.forms2cochains(kforms, surface_dict, det,vertices, coefs, num_sub, num_cochains, dim, k) ## multiple cochains
#      35         X = torch.reshape(X, (len(surface_dict['simplices']), num_cochains))
#      36         X.retain_grad()
#
# ~/cochain_representation_learning/k_forms.py in forms2cochains(kform, surface_dict, deter_tensor, subdivision_vert, subdivision_coef, num_sub, l, dim, k)
#     243         phi_simplex = surface_dict['Phi'][i]
#     244         b_simplex = surface_dict['b'][i]
# --> 245         cochains[i] = integrate_kforms(kform, phi_simplex, b_simplex,deter_tensor, subdivision_vert, subdivision_coef, num_sub, l, dim, k)[:,0].float()
#     246     return cochains.float()
#     247
#
# ~/cochain_representation_learning/k_forms.py in integrate_kforms(kform, phi, b, det, subdivision_vert, subdivision_coefs, num_sub, l, dim, k)
#     220                 #print('kform: ',kform(phi_p)[ind])
#     221
# --> 222                 g_p+= kform(phi_p)[ind] * torch.matmul(torch.matmul(phi[0], det[m]), phi[1].T)
#     223
#     224             cof = subdivision_coefs[j]
#
# ~/opt/anaconda3/envs/celia/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/opt/anaconda3/envs/celia/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#     202     def forward(self, input):
#     203         for module in self:
# --> 204             input = module(input)
#     205         return input
#     206
#
# ~/opt/anaconda3/envs/celia/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/opt/anaconda3/envs/celia/lib/python3.7/site-packages/torch/nn/modules/linear.py in forward(self, input)
#     112
#     113     def forward(self, input: Tensor) -> Tensor:
# --> 114         return F.linear(input, self.weight, self.bias)
#     115
#     116     def extra_repr(self) -> str:
#
# ~/opt/anaconda3/envs/celia/lib/python3.7/site-packages/torch/fx/traceback.py in format_stack()
#      55     else:
#      56         # fallback to traceback.format_stack()
# ---> 57         return traceback.format_stack()
#      58
#      59
#
# ~/opt/anaconda3/envs/celia/lib/python3.7/traceback.py in format_stack(f, limit)
#     195     if f is None:
#     196         f = sys._getframe().f_back
# --> 197     return format_list(extract_stack(f, limit=limit))
#     198
#     199
#
# ~/opt/anaconda3/envs/celia/lib/python3.7/traceback.py in extract_stack(f, limit)
#     209     if f is None:
#     210         f = sys._getframe().f_back
# --> 211     stack = StackSummary.extract(walk_stack(f), limit=limit)
#     212     stack.reverse()
#     213     return stack
#
# ~/opt/anaconda3/envs/celia/lib/python3.7/traceback.py in extract(klass, frame_gen, limit, lookup_lines, capture_locals)
#     361         if lookup_lines:
#     362             for f in result:
# --> 363                 f.line
#     364         return result
#     365
#
# ~/opt/anaconda3/envs/celia/lib/python3.7/traceback.py in line(self)
#     283     def line(self):
#     284         if self._line is None:
# --> 285             self._line = linecache.getline(self.filename, self.lineno).strip()
#     286         return self._line
#     287
#
# ~/opt/anaconda3/envs/celia/lib/python3.7/linecache.py in getline(filename, lineno, module_globals)
#      14
#      15 def getline(filename, lineno, module_globals=None):
# ---> 16     lines = getlines(filename, module_globals)
#      17     if 1 <= lineno <= len(lines):
#      18         return lines[lineno-1]
#
# ~/opt/anaconda3/envs/celia/lib/python3.7/linecache.py in getlines(filename, module_globals)
#      41     if filename in cache:
#      42         entry = cache[filename]
# ---> 43         if len(entry) != 1:
#      44             return cache[filename][2]
#      45
#
# KeyboardInterrupt:

# %%
try_num = 5
filename = 'multiple_cochains_try'+str(try_num)

# %%
## save the data
import pickle
Losses = [loss.detach() for loss in Losses]
with open('kforms/translation/'+filename+'_losses.pkl', 'wb') as f:
    pickle.dump(Losses, f)

# dump accuracies into a pickle file
with open('kforms/translation/'+filename+'_accuracies.pkl', 'wb') as f:
    pickle.dump(Accuracies, f)

# save the model
torch.save(kforms.state_dict(), 'kforms/translation/'+filename+'_kform_model.pt')

# save the surfaces
with open('kforms/translation/'+filename+'_surfaces.pkl', 'wb') as f:
    pickle.dump(surfaces_list, f)

# %% [markdown]
# ## Plots

# %%
# plot the loss
fig, ax = plt.subplots()
ax.plot(np.arange(len(Losses)), Losses)
ax.set(xlabel='epoch', ylabel='loss', title='Loss of the network on the {} training surfaces'.format(num_surf*2))
ax.grid()
plt.show()

# plot the accuracy
fig, ax = plt.subplots()
ax.plot(np.arange(len(Accuracies)), Accuracies)
ax.set(xlabel='epoch', ylabel='accuracy', title='Accuracy of the network on the {} training surfaces'.format(num_surf*2))
ax.grid()
plt.show()

# %%
cochains = []
for i in range(len(surfaces_list)):
    surface_dict= surfaces_list[i]
    cochain = kf.forms2cochains(kforms, surface_dict, det,vertices, coefs, num_sub, num_cochains, dim, k) ## multiple cochains 
    cochain = cochain.detach().numpy()
    cochains.append(cochain)

# dump cochains into a pickle file
with open('kforms/translation/'+filename+'_cochains.pkl', 'wb') as f:
    pickle.dump(cochains, f)
