# %% [markdown]
# # Surface classification using 2-forms
#
# In this notebook we show how to integrate $2$- forms in $\mathbb{R}^n$ over the $2$-simplices of a complex and use this method to classify surfaces in $\mathbb{R}^3$

# %% [markdown]
# ### Theory
#
# A $2$-form in $\mathbb{R}^n$, denoted by $\omega \in \Omega^2(\mathbb{R}^n)$ can be written as $$\omega = \sum_{1\leq i < j \leq n} f_{i,j} dx_i\wedge dx_j$$
# where $f_{i,j}: \mathbb{R}^n\longrightarrow \mathbb{R}^N$, with $N = \binom{n}{2} $ are smooth maps.
#
# **remark 1:** this means that we can train a neural network $\mathbb{R}^n \longrightarrow \mathbb{R}^N$ to learn $2$-forms on $\mathbb{R}^n$.
#
# ##### Integrating a $2$-form on a 2-simplex:
# Denote by $\Delta$ the standard $2$-simplex in $\mathbb{R}^2$ with vertices $(0,0), (1,0), (0,1)$.
# A $2$-simplex $\sigma$ in $\mathbb{R}^n$ is obtained as the embedding of $\Delta$ via a map $\varphi: \Delta \longrightarrow \mathbb{R}^n$, $\sigma = \varphi(\Delta)$. Thus to integrate the $2$-form $\omega$ on $\sigma$ one can use the identity:
# $$ \int_{\varphi(\Delta)}\omega = \int_{\Delta}\varphi^{*}\omega$$
#
# To obtain a $2$-cochain on an embedded simplicial complex, one integrates the $2$-form on each $2$-simplex.
#
#
# **remark 2:** In more generality one can learn any $k$-form on $\mathbb{R}^n$ and integrate it on a $k$-simplex.

# %% [markdown]
# ### Algorithmically :
#
# To compute the integral on a simplex one must make an approximation in the following way.
# 1. subdivide $\Delta$ into $m^2$ $2$-simplices $\mathcal{S} = \{s_l\}_{0\leq l \leq m^2}$ of equal area
# 2. Denote by $V$ the set of vertices in the subdivision of $\Delta$
# 3. For any $p\in \Delta$ one can evaluate $\omega$ at that point and get a map $g: \Delta \rightarrow \mathbb{R}$ in the following way:
# $$ g(p) = \sum_{i<j} f_{i,j}(\varphi(p))dx_i\wedge dx_j (\varphi_{*}\frac{\partial}{\partial y_1}\mid_p,\varphi_{*}\frac{\partial}{\partial y_2}\mid_p)$$
# 4. In particular to approximate the contribution of a $2$-simplex $s\in\mathcal{S}$ to the integral one averages the value of $g(p)$ on each of its vertices $p$. Overall each vertex will contribute with weight
#     - 1 if $p\in\{(0,0),(1,0),(0,1)\}$
#     - 3 if $p$ is in the interior of an edge of $\Delta$
#     - 6 if $p$ is in the interior of $\Delta$
#
#     to the approximating sum below :
# 5. By reordering the terms we get the following expression for the integral
# $$ \int_{\varphi(\Delta)} \omega = \frac{1}{m^2} \sum_{p\in V} |cof(p)|\cdot g(p) \cdot vol(\varphi(\Delta))$$
#
#
# To compute $$dx_i\wedge dx_j (\varphi_{*}\frac{\partial}{\partial y_1}\mid_p,\varphi_{*}\frac{\partial}{\partial y_2}\mid_p)$$
# one does the following:
#
#
# <span style="color: red;">  FILLLL </span>

# %% [markdown]
# ## Tasks:
#
# 2. run for longer and make plots of accuracy

# %%
import numpy as np
import matplotlib as mpl
import torch
import torch.nn as nn
from matplotlib import pyplot as plt
from matplotlib import colors as mcolors
import gudhi as gd 
import scipy.special

import k_forms as kf


import torch.optim as optim

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 1. Creating the synthetic data set of surfaces
#
# The random surfaces in this notebook are created by embedding a triangulation of the unit square $[0,1]\times [0,1]$ in $\mathbb{R}^3$.
# We subdivide the interval $[0,1]$ in <code>num_pts</code> points to obtain a grid of vertices in the unit square and take the alpha complex of those vertices.

# %%
num_pts = 5 ##number of points to subddivide the intverval [0,1] into 

# create and plot an alpha-complex on the unit square 
pts , ac = kf.plot_unit_square_grid(num_pts)

simplices = [] #list of 2-simplices 
for s in ac.get_skeleton(2):
    if len(s[0]) == 3: 
        simplices.append(s[0])

print("The 2-simplices are: ", simplices)
print("There are ", len(simplices), " 2-simplices")
# Out:
# The 2-simplices are:  [[0, 1, 5], [1, 2, 6], [1, 5, 6], [2, 3, 7], [2, 6, 7], [3, 4, 8], [3, 7, 8], [4, 8, 9], [5, 6, 10], [6, 7, 11], [6, 10, 11], [7, 8, 12], [7, 11, 12], [8, 9, 13], [8, 12, 13], [9, 13, 14], [10, 11, 15], [11, 12, 16], [11, 15, 16], [12, 13, 17], [12, 16, 17], [13, 14, 18], [13, 17, 18], [14, 18, 19], [15, 16, 20], [16, 17, 21], [16, 20, 21], [17, 18, 22], [17, 21, 22], [18, 19, 23], [18, 22, 23], [19, 23, 24]]
# There are  32  2-simplices

# %% [markdown]
# #### 1.1 generate random surfaces
#
# We generate two classes of random surfaces with the same underlying abstact simplicial complex created above. The surfaces are obtained by embdeding randomly the nodes in $\mathbb{R}^3$ with certain constraints to get distinct classes.
#
# - There are <code>num_surf</code> in each class
#
# - <code>eps</code> is a parameter for the randomness of the surfaces

# %%
# generate surface data
num_surf = 20
eps = 3

s0 = kf.generate_surfaces_yz(num_surf, num_pts , eps) ## the surfaces are a bit too regular, change a bit the generation code later
s1 = kf.generate_surfaces_xz(num_surf, num_pts , eps)

surfaces = s0 + s1 

# generate labels
labels = np.concatenate((np.zeros(num_surf),np.ones(num_surf)))

# perform a one hot encoding of the labels and transform to torch
labels_one_hot = torch.nn.functional.one_hot(torch.tensor(labels).to(torch.int64))

## shuffle the data and the labels in the same way
shuffled_indices = torch.randperm(len(surfaces)) 
surfaces_shuffled = [surfaces[i] for i in shuffled_indices]
labels_one_hot_shuffled = labels_one_hot[shuffled_indices]
labels_shuffled = labels[shuffled_indices]

# %% [markdown]
# #### 1.2 format the data
#
# Each triangulated surface is formated into a dictionary with the following keys:
#
# - <code>'simplices'</code>: list of $2$-simplices in the underlying complex
# - <code>'points'</code>: array with the position in $\mathbb{R^3}$ of each vertex of the triangulated surface
# - <code>'Phi'</code> : for each simplex a linear map $\mathbb{R}^2 \rightarrow \mathbb{R}^3$ embedding the standard simplex into its position given by its vertices $\mathbb{R}^3$
# - <code>'b'</code> : for each simplex the affine part of its embedding

# %%
## making dictionaries out of the surfaces 
surfaces_list_shuffled = []

for surf in range(num_surf*2): 
    surface = surfaces_shuffled[surf]
    surface_dict= {}
    surface_dict['simplices'] = simplices
    surface_dict['points'] = surface[3]
    surface_dict['Phi'] = []
    surface_dict['b'] = []


    for i in range(len(surface_dict['simplices'])):
        s = surface_dict['simplices'][i]
        emb_vertices_simplex = surface_dict['points'][s]
        phi_simplex, b_simplex = kf.phi_b(emb_vertices_simplex ) # obtain the embedding maps for each simplex 
        surface_dict['Phi'].append(phi_simplex)
        surface_dict['b'].append(b_simplex)

    surfaces_list_shuffled.append(surface_dict)


print("there are ", len(surfaces_list_shuffled), " surfaces in the dataset ")
# Out:
# there are  40  surfaces in the dataset

# %%
# plot one surface
kf.plot_surface(surfaces[5][0],surfaces[5][1],surfaces[5][2])
# Out:
# /Users/celiahacker/opt/anaconda3/envs/celia/lib/python3.7/site-packages/mpl_toolkits/mplot3d/art3d.py:304: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   self._segments3d = np.asanyarray(segments)

# %% [markdown]
# ## 2. Surface classification
#
# a $2$-form is given as a layer of a neural network, it has <code> kljlk <code/>
#
#
# 1. precompute the subdivision of a $2$-simplex used for approximating the integral
# 2. precompute the tensor that will be used in the computation of the integral

# %%
k = 2 
dim = 3 
classes = 2

N = int(scipy.special.binom(dim,k))

kform = nn.Sequential(
    nn.Linear(dim, N) ## can add layers here if needed
)

## Mlp layers post integration
mlp = nn.Sequential(
    nn.Linear(1, 20),
    nn.ReLU(),
    nn.Linear(20, 10),
    nn.ReLU(),
    nn.Linear(10, classes)
)

# %%
## Precomputed things 
num_sub = 2 ## how many times we subdivide each triangle for integration 
subdivision_vert, subdivision_coefs = kf.subdivide_simplex_coef_torch(num_sub)

det = kf.build_determinant_tensor(dim, k) ## will be needed for integration

# %%
epochs = 30

# create your optimizer
optimizer = optim.SGD(kform.parameters(), lr=1e-2)

criterion = nn.CrossEntropyLoss()

losses = torch.zeros(epochs)

labels_one_hot_shuffled = labels_one_hot_shuffled.to(torch.float32)

torch.autograd.set_detect_anomaly(True)


Accuracies = []

for e in range(epochs):
    print('epoch: ', e)
    
    correct = 0
    total = 0

    for i in range(len(surfaces_list_shuffled)):
        surface_dict= surfaces_list_shuffled[i]
        l = labels_one_hot_shuffled[i]
        
        X = kf.form2cochain(kform, surface_dict, det, subdivision_vert, subdivision_coefs, num_sub, dim,  k )
        X = torch.reshape(X, (len(surface_dict['simplices']), 1))
        X.retain_grad() 
        X = mlp(X)
        X = X.sum(0)
        X.retain_grad()
        #X.grad = None
        # softmax
        sm = torch.nn.functional.softmax(X)
        #print('softmax = ',sm)
        loss = criterion(sm,l) 
        print("loss: ", loss)
        #print('********')
        loss.backward(retain_graph=True)
        optimizer.step()
        optimizer.zero_grad()
        
        pred = torch.argmax(torch.nn.functional.softmax(X))
        #print('pred: ', pred)
        #print('label: ', torch.argmax(l))
        if pred == torch.argmax(l):
            correct += 1
        total += 1
        #print('correct: ', correct)

        if i % 10 == 0:
            print("number of surfaces processed: ", i)

    print('Accuracy of the network on the {} training surfaces at epoch {} : {} '.format(num_surf*2, e, (100 * correct / total)))
    Accuracies.append(100 * correct / total)

    print('-----------')
    print('***********')
    print('-----------')
# Out:
# epoch:  0
# /Users/celiahacker/opt/anaconda3/envs/celia/lib/python3.7/site-packages/ipykernel_launcher.py:35: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# /Users/celiahacker/opt/anaconda3/envs/celia/lib/python3.7/site-packages/ipykernel_launcher.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# loss:  tensor(0.3599, grad_fn=<DivBackward1>)
# number of surfaces processed:  0
# loss:  tensor(0.4555, grad_fn=<DivBackward1>)
# loss:  tensor(0.4559, grad_fn=<DivBackward1>)
# loss:  tensor(0.4229, grad_fn=<DivBackward1>)
# loss:  tensor(1.1314, grad_fn=<DivBackward1>)
# loss:  tensor(0.3197, grad_fn=<DivBackward1>)
# loss:  tensor(0.4285, grad_fn=<DivBackward1>)
# loss:  tensor(0.4377, grad_fn=<DivBackward1>)
# loss:  tensor(0.5463, grad_fn=<DivBackward1>)
# loss:  tensor(0.5338, grad_fn=<DivBackward1>)
# loss:  tensor(0.3984, grad_fn=<DivBackward1>)
# number of surfaces processed:  10
# loss:  tensor(0.3540, grad_fn=<DivBackward1>)
# loss:  tensor(0.3800, grad_fn=<DivBackward1>)
# loss:  tensor(0.3873, grad_fn=<DivBackward1>)
# loss:  tensor(0.4917, grad_fn=<DivBackward1>)
# loss:  tensor(0.3592, grad_fn=<DivBackward1>)
# loss:  tensor(0.5442, grad_fn=<DivBackward1>)
# loss:  tensor(0.3535, grad_fn=<DivBackward1>)
# loss:  tensor(0.3186, grad_fn=<DivBackward1>)
# loss:  tensor(0.3909, grad_fn=<DivBackward1>)
# loss:  tensor(0.3912, grad_fn=<DivBackward1>)
# number of surfaces processed:  20
# loss:  tensor(0.4048, grad_fn=<DivBackward1>)
# loss:  tensor(0.8456, grad_fn=<DivBackward1>)
# loss:  tensor(0.4486, grad_fn=<DivBackward1>)
# loss:  tensor(0.3391, grad_fn=<DivBackward1>)
# loss:  tensor(0.3324, grad_fn=<DivBackward1>)
# loss:  tensor(0.8163, grad_fn=<DivBackward1>)
# loss:  tensor(0.4850, grad_fn=<DivBackward1>)
# loss:  tensor(0.5656, grad_fn=<DivBackward1>)
# loss:  tensor(0.3549, grad_fn=<DivBackward1>)
# loss:  tensor(0.9832, grad_fn=<DivBackward1>)
# number of surfaces processed:  30
# loss:  tensor(0.3420, grad_fn=<DivBackward1>)
# loss:  tensor(1.1679, grad_fn=<DivBackward1>)
# loss:  tensor(0.3749, grad_fn=<DivBackward1>)
# loss:  tensor(0.4147, grad_fn=<DivBackward1>)
# loss:  tensor(0.8554, grad_fn=<DivBackward1>)
# loss:  tensor(0.6051, grad_fn=<DivBackward1>)
# loss:  tensor(0.4592, grad_fn=<DivBackward1>)
# loss:  tensor(0.7709, grad_fn=<DivBackward1>)
# loss:  tensor(0.3165, grad_fn=<DivBackward1>)
# Accuracy of the network on the 40 training surfaces at epoch 0 : 82.5
# -----------
# ***********
# -----------
# epoch:  1
# loss:  tensor(0.3529, grad_fn=<DivBackward1>)
# number of surfaces processed:  0
# loss:  tensor(0.4126, grad_fn=<DivBackward1>)
# loss:  tensor(0.3973, grad_fn=<DivBackward1>)
# loss:  tensor(0.4249, grad_fn=<DivBackward1>)
# loss:  tensor(1.0980, grad_fn=<DivBackward1>)
# loss:  tensor(0.3153, grad_fn=<DivBackward1>)
# loss:  tensor(0.3981, grad_fn=<DivBackward1>)
# loss:  tensor(0.3898, grad_fn=<DivBackward1>)
# loss:  tensor(0.4456, grad_fn=<DivBackward1>)
# loss:  tensor(0.4981, grad_fn=<DivBackward1>)
# loss:  tensor(0.3948, grad_fn=<DivBackward1>)
# number of surfaces processed:  10
# loss:  tensor(0.3533, grad_fn=<DivBackward1>)
# loss:  tensor(0.3477, grad_fn=<DivBackward1>)
# loss:  tensor(0.3513, grad_fn=<DivBackward1>)
# loss:  tensor(0.4997, grad_fn=<DivBackward1>)
# loss:  tensor(0.3623, grad_fn=<DivBackward1>)
# loss:  tensor(0.5295, grad_fn=<DivBackward1>)
# loss:  tensor(0.3516, grad_fn=<DivBackward1>)
# loss:  tensor(0.3154, grad_fn=<DivBackward1>)
# loss:  tensor(0.3983, grad_fn=<DivBackward1>)
# loss:  tensor(0.3753, grad_fn=<DivBackward1>)
# number of surfaces processed:  20
# loss:  tensor(0.3996, grad_fn=<DivBackward1>)
# loss:  tensor(0.7397, grad_fn=<DivBackward1>)
# loss:  tensor(0.3962, grad_fn=<DivBackward1>)
# loss:  tensor(0.3268, grad_fn=<DivBackward1>)
# loss:  tensor(0.3244, grad_fn=<DivBackward1>)
# loss:  tensor(0.7421, grad_fn=<DivBackward1>)
# loss:  tensor(0.4596, grad_fn=<DivBackward1>)
# loss:  tensor(0.5592, grad_fn=<DivBackward1>)
# loss:  tensor(0.3551, grad_fn=<DivBackward1>)
# loss:  tensor(0.9485, grad_fn=<DivBackward1>)
# number of surfaces processed:  30
# loss:  tensor(0.3291, grad_fn=<DivBackward1>)
# loss:  tensor(1.1629, grad_fn=<DivBackward1>)
# loss:  tensor(0.3724, grad_fn=<DivBackward1>)
# loss:  tensor(0.4018, grad_fn=<DivBackward1>)
# loss:  tensor(0.7948, grad_fn=<DivBackward1>)
# loss:  tensor(0.5323, grad_fn=<DivBackward1>)
# loss:  tensor(0.4088, grad_fn=<DivBackward1>)
# loss:  tensor(0.7049, grad_fn=<DivBackward1>)
# loss:  tensor(0.3150, grad_fn=<DivBackward1>)
# Accuracy of the network on the 40 training surfaces at epoch 1 : 82.5
# -----------
# ***********
# -----------
# epoch:  2
# loss:  tensor(0.3534, grad_fn=<DivBackward1>)
# number of surfaces processed:  0
# loss:  tensor(0.3970, grad_fn=<DivBackward1>)
# loss:  tensor(0.3698, grad_fn=<DivBackward1>)
# loss:  tensor(0.4221, grad_fn=<DivBackward1>)
# loss:  tensor(1.0676, grad_fn=<DivBackward1>)
# loss:  tensor(0.3143, grad_fn=<DivBackward1>)
# loss:  tensor(0.3895, grad_fn=<DivBackward1>)
# loss:  tensor(0.3759, grad_fn=<DivBackward1>)
# loss:  tensor(0.4042, grad_fn=<DivBackward1>)
# loss:  tensor(0.4750, grad_fn=<DivBackward1>)
# loss:  tensor(0.3959, grad_fn=<DivBackward1>)
# number of surfaces processed:  10
# loss:  tensor(0.3526, grad_fn=<DivBackward1>)
# loss:  tensor(0.3365, grad_fn=<DivBackward1>)
# loss:  tensor(0.3381, grad_fn=<DivBackward1>)
# loss:  tensor(0.5045, grad_fn=<DivBackward1>)
# loss:  tensor(0.3636, grad_fn=<DivBackward1>)
# loss:  tensor(0.5105, grad_fn=<DivBackward1>)
# loss:  tensor(0.3512, grad_fn=<DivBackward1>)
# loss:  tensor(0.3144, grad_fn=<DivBackward1>)
# loss:  tensor(0.4135, grad_fn=<DivBackward1>)
# loss:  tensor(0.3701, grad_fn=<DivBackward1>)
# number of surfaces processed:  20
# loss:  tensor(0.3960, grad_fn=<DivBackward1>)
# loss:  tensor(0.6764, grad_fn=<DivBackward1>)
# loss:  tensor(0.3716, grad_fn=<DivBackward1>)
# loss:  tensor(0.3212, grad_fn=<DivBackward1>)
# loss:  tensor(0.3204, grad_fn=<DivBackward1>)
# loss:  tensor(0.6824, grad_fn=<DivBackward1>)
# loss:  tensor(0.4468, grad_fn=<DivBackward1>)
# loss:  tensor(0.5624, grad_fn=<DivBackward1>)
# loss:  tensor(0.3548, grad_fn=<DivBackward1>)
# loss:  tensor(0.9115, grad_fn=<DivBackward1>)
# number of surfaces processed:  30
# loss:  tensor(0.3237, grad_fn=<DivBackward1>)
# loss:  tensor(1.1583, grad_fn=<DivBackward1>)
# loss:  tensor(0.3726, grad_fn=<DivBackward1>)
# loss:  tensor(0.3989, grad_fn=<DivBackward1>)
# loss:  tensor(0.7455, grad_fn=<DivBackward1>)
# loss:  tensor(0.4841, grad_fn=<DivBackward1>)
# loss:  tensor(0.3840, grad_fn=<DivBackward1>)
# loss:  tensor(0.6461, grad_fn=<DivBackward1>)
# loss:  tensor(0.3144, grad_fn=<DivBackward1>)
# Accuracy of the network on the 40 training surfaces at epoch 2 : 90.0
# -----------
# ***********
# -----------
# epoch:  3
# loss:  tensor(0.3546, grad_fn=<DivBackward1>)
# number of surfaces processed:  0
# loss:  tensor(0.3903, grad_fn=<DivBackward1>)
# loss:  tensor(0.3536, grad_fn=<DivBackward1>)
# loss:  tensor(0.4230, grad_fn=<DivBackward1>)
# loss:  tensor(1.0399, grad_fn=<DivBackward1>)
# loss:  tensor(0.3138, grad_fn=<DivBackward1>)
# loss:  tensor(0.3882, grad_fn=<DivBackward1>)
# loss:  tensor(0.3715, grad_fn=<DivBackward1>)
# loss:  tensor(0.3809, grad_fn=<DivBackward1>)
# loss:  tensor(0.4583, grad_fn=<DivBackward1>)
# loss:  tensor(0.3940, grad_fn=<DivBackward1>)
# number of surfaces processed:  10
# loss:  tensor(0.3523, grad_fn=<DivBackward1>)
# loss:  tensor(0.3306, grad_fn=<DivBackward1>)
# loss:  tensor(0.3314, grad_fn=<DivBackward1>)
# loss:  tensor(0.5028, grad_fn=<DivBackward1>)
# loss:  tensor(0.3639, grad_fn=<DivBackward1>)
# loss:  tensor(0.5001, grad_fn=<DivBackward1>)
# loss:  tensor(0.3513, grad_fn=<DivBackward1>)
# loss:  tensor(0.3139, grad_fn=<DivBackward1>)
# loss:  tensor(0.4245, grad_fn=<DivBackward1>)
# loss:  tensor(0.3684, grad_fn=<DivBackward1>)
# number of surfaces processed:  20
# loss:  tensor(0.3958, grad_fn=<DivBackward1>)
# loss:  tensor(0.6305, grad_fn=<DivBackward1>)
# loss:  tensor(0.3577, grad_fn=<DivBackward1>)
# loss:  tensor(0.3182, grad_fn=<DivBackward1>)
# loss:  tensor(0.3182, grad_fn=<DivBackward1>)
# loss:  tensor(0.6335, grad_fn=<DivBackward1>)
# loss:  tensor(0.4377, grad_fn=<DivBackward1>)
# loss:  tensor(0.5618, grad_fn=<DivBackward1>)
# loss:  tensor(0.3543, grad_fn=<DivBackward1>)
# loss:  tensor(0.8752, grad_fn=<DivBackward1>)
# number of surfaces processed:  30
# loss:  tensor(0.3210, grad_fn=<DivBackward1>)
# loss:  tensor(1.1548, grad_fn=<DivBackward1>)
# loss:  tensor(0.3739, grad_fn=<DivBackward1>)
# loss:  tensor(0.3944, grad_fn=<DivBackward1>)
# loss:  tensor(0.7077, grad_fn=<DivBackward1>)
# loss:  tensor(0.4520, grad_fn=<DivBackward1>)
# loss:  tensor(0.3707, grad_fn=<DivBackward1>)
# loss:  tensor(0.5969, grad_fn=<DivBackward1>)
# loss:  tensor(0.3141, grad_fn=<DivBackward1>)
# Accuracy of the network on the 40 training surfaces at epoch 3 : 90.0
# -----------
# ***********
# -----------
# epoch:  4
# loss:  tensor(0.3551, grad_fn=<DivBackward1>)
# number of surfaces processed:  0
# loss:  tensor(0.3863, grad_fn=<DivBackward1>)
# loss:  tensor(0.3434, grad_fn=<DivBackward1>)
# loss:  tensor(0.4189, grad_fn=<DivBackward1>)
# loss:  tensor(1.0122, grad_fn=<DivBackward1>)
# loss:  tensor(0.3136, grad_fn=<DivBackward1>)
# loss:  tensor(0.3872, grad_fn=<DivBackward1>)
# loss:  tensor(0.3724, grad_fn=<DivBackward1>)
# loss:  tensor(0.3664, grad_fn=<DivBackward1>)
# loss:  tensor(0.4485, grad_fn=<DivBackward1>)
# loss:  tensor(0.3876, grad_fn=<DivBackward1>)
# number of surfaces processed:  10
# loss:  tensor(0.3522, grad_fn=<DivBackward1>)
# loss:  tensor(0.3273, grad_fn=<DivBackward1>)
# loss:  tensor(0.3279, grad_fn=<DivBackward1>)
# loss:  tensor(0.5044, grad_fn=<DivBackward1>)
# loss:  tensor(0.3636, grad_fn=<DivBackward1>)
# loss:  tensor(0.4877, grad_fn=<DivBackward1>)
# loss:  tensor(0.3510, grad_fn=<DivBackward1>)
# loss:  tensor(0.3137, grad_fn=<DivBackward1>)
# loss:  tensor(0.4283, grad_fn=<DivBackward1>)
# loss:  tensor(0.3678, grad_fn=<DivBackward1>)
# number of surfaces processed:  20
# loss:  tensor(0.3924, grad_fn=<DivBackward1>)
# loss:  tensor(0.6037, grad_fn=<DivBackward1>)
# loss:  tensor(0.3499, grad_fn=<DivBackward1>)
# loss:  tensor(0.3166, grad_fn=<DivBackward1>)
# loss:  tensor(0.3168, grad_fn=<DivBackward1>)
# loss:  tensor(0.5957, grad_fn=<DivBackward1>)
# loss:  tensor(0.4245, grad_fn=<DivBackward1>)
# loss:  tensor(0.5594, grad_fn=<DivBackward1>)
# loss:  tensor(0.3541, grad_fn=<DivBackward1>)
# loss:  tensor(0.8400, grad_fn=<DivBackward1>)
# number of surfaces processed:  30
# loss:  tensor(0.3197, grad_fn=<DivBackward1>)
# loss:  tensor(1.1504, grad_fn=<DivBackward1>)
# loss:  tensor(0.3762, grad_fn=<DivBackward1>)
# loss:  tensor(0.3888, grad_fn=<DivBackward1>)
# loss:  tensor(0.6796, grad_fn=<DivBackward1>)
# loss:  tensor(0.4301, grad_fn=<DivBackward1>)
# loss:  tensor(0.3635, grad_fn=<DivBackward1>)
# loss:  tensor(0.5539, grad_fn=<DivBackward1>)
# loss:  tensor(0.3139, grad_fn=<DivBackward1>)
# Accuracy of the network on the 40 training surfaces at epoch 4 : 92.5
# -----------
# ***********
# -----------
# epoch:  5
# loss:  tensor(0.3559, grad_fn=<DivBackward1>)
# number of surfaces processed:  0
# loss:  tensor(0.3847, grad_fn=<DivBackward1>)
# loss:  tensor(0.3362, grad_fn=<DivBackward1>)
# loss:  tensor(0.4114, grad_fn=<DivBackward1>)
# loss:  tensor(0.9845, grad_fn=<DivBackward1>)
# loss:  tensor(0.3135, grad_fn=<DivBackward1>)
# loss:  tensor(0.3850, grad_fn=<DivBackward1>)
# loss:  tensor(0.3745, grad_fn=<DivBackward1>)
# loss:  tensor(0.3564, grad_fn=<DivBackward1>)
# loss:  tensor(0.4340, grad_fn=<DivBackward1>)
# loss:  tensor(0.3812, grad_fn=<DivBackward1>)
# number of surfaces processed:  10
# loss:  tensor(0.3522, grad_fn=<DivBackward1>)
# loss:  tensor(0.3249, grad_fn=<DivBackward1>)
# loss:  tensor(0.3254, grad_fn=<DivBackward1>)
# loss:  tensor(0.5051, grad_fn=<DivBackward1>)
# loss:  tensor(0.3633, grad_fn=<DivBackward1>)
# loss:  tensor(0.4738, grad_fn=<DivBackward1>)
# loss:  tensor(0.3508, grad_fn=<DivBackward1>)
# loss:  tensor(0.3135, grad_fn=<DivBackward1>)
# loss:  tensor(0.4312, grad_fn=<DivBackward1>)
# loss:  tensor(0.3669, grad_fn=<DivBackward1>)
# number of surfaces processed:  20
# loss:  tensor(0.3896, grad_fn=<DivBackward1>)
# loss:  tensor(0.5793, grad_fn=<DivBackward1>)
# loss:  tensor(0.3432, grad_fn=<DivBackward1>)
# loss:  tensor(0.3156, grad_fn=<DivBackward1>)
# loss:  tensor(0.3159, grad_fn=<DivBackward1>)
# loss:  tensor(0.5640, grad_fn=<DivBackward1>)
# loss:  tensor(0.4134, grad_fn=<DivBackward1>)
# loss:  tensor(0.5613, grad_fn=<DivBackward1>)
# loss:  tensor(0.3539, grad_fn=<DivBackward1>)
# loss:  tensor(0.8090, grad_fn=<DivBackward1>)
# number of surfaces processed:  30
# loss:  tensor(0.3185, grad_fn=<DivBackward1>)
# loss:  tensor(1.1453, grad_fn=<DivBackward1>)
# loss:  tensor(0.3781, grad_fn=<DivBackward1>)
# loss:  tensor(0.3844, grad_fn=<DivBackward1>)
# loss:  tensor(0.6542, grad_fn=<DivBackward1>)
# loss:  tensor(0.4126, grad_fn=<DivBackward1>)
# loss:  tensor(0.3570, grad_fn=<DivBackward1>)
# loss:  tensor(0.5195, grad_fn=<DivBackward1>)
# loss:  tensor(0.3138, grad_fn=<DivBackward1>)
# Accuracy of the network on the 40 training surfaces at epoch 5 : 92.5
# -----------
# ***********
# -----------
# epoch:  6
# loss:  tensor(0.3580, grad_fn=<DivBackward1>)
# number of surfaces processed:  0
# loss:  tensor(0.3821, grad_fn=<DivBackward1>)
# loss:  tensor(0.3310, grad_fn=<DivBackward1>)
# loss:  tensor(0.4057, grad_fn=<DivBackward1>)
# loss:  tensor(0.9580, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3836, grad_fn=<DivBackward1>)
# loss:  tensor(0.3753, grad_fn=<DivBackward1>)
# loss:  tensor(0.3486, grad_fn=<DivBackward1>)
# loss:  tensor(0.4234, grad_fn=<DivBackward1>)
# loss:  tensor(0.3777, grad_fn=<DivBackward1>)
# number of surfaces processed:  10
# loss:  tensor(0.3525, grad_fn=<DivBackward1>)
# loss:  tensor(0.3232, grad_fn=<DivBackward1>)
# loss:  tensor(0.3234, grad_fn=<DivBackward1>)
# loss:  tensor(0.5086, grad_fn=<DivBackward1>)
# loss:  tensor(0.3633, grad_fn=<DivBackward1>)
# loss:  tensor(0.4676, grad_fn=<DivBackward1>)
# loss:  tensor(0.3506, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.4345, grad_fn=<DivBackward1>)
# loss:  tensor(0.3672, grad_fn=<DivBackward1>)
# number of surfaces processed:  20
# loss:  tensor(0.3879, grad_fn=<DivBackward1>)
# loss:  tensor(0.5581, grad_fn=<DivBackward1>)
# loss:  tensor(0.3381, grad_fn=<DivBackward1>)
# loss:  tensor(0.3149, grad_fn=<DivBackward1>)
# loss:  tensor(0.3152, grad_fn=<DivBackward1>)
# loss:  tensor(0.5367, grad_fn=<DivBackward1>)
# loss:  tensor(0.4057, grad_fn=<DivBackward1>)
# loss:  tensor(0.5657, grad_fn=<DivBackward1>)
# loss:  tensor(0.3538, grad_fn=<DivBackward1>)
# loss:  tensor(0.7811, grad_fn=<DivBackward1>)
# number of surfaces processed:  30
# loss:  tensor(0.3175, grad_fn=<DivBackward1>)
# loss:  tensor(1.1407, grad_fn=<DivBackward1>)
# loss:  tensor(0.3801, grad_fn=<DivBackward1>)
# loss:  tensor(0.3827, grad_fn=<DivBackward1>)
# loss:  tensor(0.6304, grad_fn=<DivBackward1>)
# loss:  tensor(0.3984, grad_fn=<DivBackward1>)
# loss:  tensor(0.3512, grad_fn=<DivBackward1>)
# loss:  tensor(0.4911, grad_fn=<DivBackward1>)
# loss:  tensor(0.3137, grad_fn=<DivBackward1>)
# Accuracy of the network on the 40 training surfaces at epoch 6 : 92.5
# -----------
# ***********
# -----------
# epoch:  7
# loss:  tensor(0.3594, grad_fn=<DivBackward1>)
# number of surfaces processed:  0
# loss:  tensor(0.3814, grad_fn=<DivBackward1>)
# loss:  tensor(0.3274, grad_fn=<DivBackward1>)
# loss:  tensor(0.4036, grad_fn=<DivBackward1>)
# loss:  tensor(0.9341, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3853, grad_fn=<DivBackward1>)
# loss:  tensor(0.3766, grad_fn=<DivBackward1>)
# loss:  tensor(0.3419, grad_fn=<DivBackward1>)
# loss:  tensor(0.4165, grad_fn=<DivBackward1>)
# loss:  tensor(0.3779, grad_fn=<DivBackward1>)
# number of surfaces processed:  10
# loss:  tensor(0.3527, grad_fn=<DivBackward1>)
# loss:  tensor(0.3215, grad_fn=<DivBackward1>)
# loss:  tensor(0.3215, grad_fn=<DivBackward1>)
# loss:  tensor(0.5128, grad_fn=<DivBackward1>)
# loss:  tensor(0.3638, grad_fn=<DivBackward1>)
# loss:  tensor(0.4653, grad_fn=<DivBackward1>)
# loss:  tensor(0.3508, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.4422, grad_fn=<DivBackward1>)
# loss:  tensor(0.3677, grad_fn=<DivBackward1>)
# number of surfaces processed:  20
# loss:  tensor(0.3874, grad_fn=<DivBackward1>)
# loss:  tensor(0.5360, grad_fn=<DivBackward1>)
# loss:  tensor(0.3339, grad_fn=<DivBackward1>)
# loss:  tensor(0.3145, grad_fn=<DivBackward1>)
# loss:  tensor(0.3148, grad_fn=<DivBackward1>)
# loss:  tensor(0.5134, grad_fn=<DivBackward1>)
# loss:  tensor(0.4017, grad_fn=<DivBackward1>)
# loss:  tensor(0.5707, grad_fn=<DivBackward1>)
# loss:  tensor(0.3538, grad_fn=<DivBackward1>)
# loss:  tensor(0.7588, grad_fn=<DivBackward1>)
# number of surfaces processed:  30
# loss:  tensor(0.3167, grad_fn=<DivBackward1>)
# loss:  tensor(1.1366, grad_fn=<DivBackward1>)
# loss:  tensor(0.3810, grad_fn=<DivBackward1>)
# loss:  tensor(0.3827, grad_fn=<DivBackward1>)
# loss:  tensor(0.6087, grad_fn=<DivBackward1>)
# loss:  tensor(0.3870, grad_fn=<DivBackward1>)
# loss:  tensor(0.3459, grad_fn=<DivBackward1>)
# loss:  tensor(0.4697, grad_fn=<DivBackward1>)
# loss:  tensor(0.3136, grad_fn=<DivBackward1>)
# Accuracy of the network on the 40 training surfaces at epoch 7 : 92.5
# -----------
# ***********
# -----------
# epoch:  8
# loss:  tensor(0.3609, grad_fn=<DivBackward1>)
# number of surfaces processed:  0
# loss:  tensor(0.3799, grad_fn=<DivBackward1>)
# loss:  tensor(0.3248, grad_fn=<DivBackward1>)
# loss:  tensor(0.4042, grad_fn=<DivBackward1>)
# loss:  tensor(0.9122, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3868, grad_fn=<DivBackward1>)
# loss:  tensor(0.3774, grad_fn=<DivBackward1>)
# loss:  tensor(0.3370, grad_fn=<DivBackward1>)
# loss:  tensor(0.4115, grad_fn=<DivBackward1>)
# loss:  tensor(0.3777, grad_fn=<DivBackward1>)
# number of surfaces processed:  10
# loss:  tensor(0.3531, grad_fn=<DivBackward1>)
# loss:  tensor(0.3203, grad_fn=<DivBackward1>)
# loss:  tensor(0.3201, grad_fn=<DivBackward1>)
# loss:  tensor(0.5157, grad_fn=<DivBackward1>)
# loss:  tensor(0.3641, grad_fn=<DivBackward1>)
# loss:  tensor(0.4664, grad_fn=<DivBackward1>)
# loss:  tensor(0.3509, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.4489, grad_fn=<DivBackward1>)
# loss:  tensor(0.3682, grad_fn=<DivBackward1>)
# number of surfaces processed:  20
# loss:  tensor(0.3863, grad_fn=<DivBackward1>)
# loss:  tensor(0.5199, grad_fn=<DivBackward1>)
# loss:  tensor(0.3309, grad_fn=<DivBackward1>)
# loss:  tensor(0.3142, grad_fn=<DivBackward1>)
# loss:  tensor(0.3145, grad_fn=<DivBackward1>)
# loss:  tensor(0.4945, grad_fn=<DivBackward1>)
# loss:  tensor(0.3975, grad_fn=<DivBackward1>)
# loss:  tensor(0.5810, grad_fn=<DivBackward1>)
# loss:  tensor(0.3538, grad_fn=<DivBackward1>)
# loss:  tensor(0.7382, grad_fn=<DivBackward1>)
# number of surfaces processed:  30
# loss:  tensor(0.3161, grad_fn=<DivBackward1>)
# loss:  tensor(1.1326, grad_fn=<DivBackward1>)
# loss:  tensor(0.3821, grad_fn=<DivBackward1>)
# loss:  tensor(0.3831, grad_fn=<DivBackward1>)
# loss:  tensor(0.5906, grad_fn=<DivBackward1>)
# loss:  tensor(0.3784, grad_fn=<DivBackward1>)
# loss:  tensor(0.3421, grad_fn=<DivBackward1>)
# loss:  tensor(0.4521, grad_fn=<DivBackward1>)
# loss:  tensor(0.3135, grad_fn=<DivBackward1>)
# Accuracy of the network on the 40 training surfaces at epoch 8 : 92.5
# -----------
# ***********
# -----------
# epoch:  9
# loss:  tensor(0.3625, grad_fn=<DivBackward1>)
# number of surfaces processed:  0
# loss:  tensor(0.3788, grad_fn=<DivBackward1>)
# loss:  tensor(0.3229, grad_fn=<DivBackward1>)
# loss:  tensor(0.4047, grad_fn=<DivBackward1>)
# loss:  tensor(0.8926, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3882, grad_fn=<DivBackward1>)
# loss:  tensor(0.3794, grad_fn=<DivBackward1>)
# loss:  tensor(0.3335, grad_fn=<DivBackward1>)
# loss:  tensor(0.4069, grad_fn=<DivBackward1>)
# loss:  tensor(0.3777, grad_fn=<DivBackward1>)
# number of surfaces processed:  10
# loss:  tensor(0.3535, grad_fn=<DivBackward1>)
# loss:  tensor(0.3193, grad_fn=<DivBackward1>)
# loss:  tensor(0.3191, grad_fn=<DivBackward1>)
# loss:  tensor(0.5187, grad_fn=<DivBackward1>)
# loss:  tensor(0.3643, grad_fn=<DivBackward1>)
# loss:  tensor(0.4653, grad_fn=<DivBackward1>)
# loss:  tensor(0.3510, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.4553, grad_fn=<DivBackward1>)
# loss:  tensor(0.3683, grad_fn=<DivBackward1>)
# number of surfaces processed:  20
# loss:  tensor(0.3861, grad_fn=<DivBackward1>)
# loss:  tensor(0.5070, grad_fn=<DivBackward1>)
# loss:  tensor(0.3287, grad_fn=<DivBackward1>)
# loss:  tensor(0.3140, grad_fn=<DivBackward1>)
# loss:  tensor(0.3143, grad_fn=<DivBackward1>)
# loss:  tensor(0.4792, grad_fn=<DivBackward1>)
# loss:  tensor(0.3940, grad_fn=<DivBackward1>)
# loss:  tensor(0.5894, grad_fn=<DivBackward1>)
# loss:  tensor(0.3539, grad_fn=<DivBackward1>)
# loss:  tensor(0.7200, grad_fn=<DivBackward1>)
# number of surfaces processed:  30
# loss:  tensor(0.3157, grad_fn=<DivBackward1>)
# loss:  tensor(1.1288, grad_fn=<DivBackward1>)
# loss:  tensor(0.3829, grad_fn=<DivBackward1>)
# loss:  tensor(0.3835, grad_fn=<DivBackward1>)
# loss:  tensor(0.5772, grad_fn=<DivBackward1>)
# loss:  tensor(0.3717, grad_fn=<DivBackward1>)
# loss:  tensor(0.3395, grad_fn=<DivBackward1>)
# loss:  tensor(0.4384, grad_fn=<DivBackward1>)
# loss:  tensor(0.3135, grad_fn=<DivBackward1>)
# Accuracy of the network on the 40 training surfaces at epoch 9 : 92.5
# -----------
# ***********
# -----------
# epoch:  10
# loss:  tensor(0.3641, grad_fn=<DivBackward1>)
# number of surfaces processed:  0
# loss:  tensor(0.3776, grad_fn=<DivBackward1>)
# loss:  tensor(0.3215, grad_fn=<DivBackward1>)
# loss:  tensor(0.4049, grad_fn=<DivBackward1>)
# loss:  tensor(0.8744, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3899, grad_fn=<DivBackward1>)
# loss:  tensor(0.3823, grad_fn=<DivBackward1>)
# loss:  tensor(0.3308, grad_fn=<DivBackward1>)
# loss:  tensor(0.4034, grad_fn=<DivBackward1>)
# loss:  tensor(0.3778, grad_fn=<DivBackward1>)
# number of surfaces processed:  10
# loss:  tensor(0.3540, grad_fn=<DivBackward1>)
# loss:  tensor(0.3186, grad_fn=<DivBackward1>)
# loss:  tensor(0.3183, grad_fn=<DivBackward1>)
# loss:  tensor(0.5214, grad_fn=<DivBackward1>)
# loss:  tensor(0.3645, grad_fn=<DivBackward1>)
# loss:  tensor(0.4639, grad_fn=<DivBackward1>)
# loss:  tensor(0.3512, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.4623, grad_fn=<DivBackward1>)
# loss:  tensor(0.3684, grad_fn=<DivBackward1>)
# number of surfaces processed:  20
# loss:  tensor(0.3871, grad_fn=<DivBackward1>)
# loss:  tensor(0.4934, grad_fn=<DivBackward1>)
# loss:  tensor(0.3268, grad_fn=<DivBackward1>)
# loss:  tensor(0.3139, grad_fn=<DivBackward1>)
# loss:  tensor(0.3141, grad_fn=<DivBackward1>)
# loss:  tensor(0.4652, grad_fn=<DivBackward1>)
# loss:  tensor(0.3917, grad_fn=<DivBackward1>)
# loss:  tensor(0.5987, grad_fn=<DivBackward1>)
# loss:  tensor(0.3540, grad_fn=<DivBackward1>)
# loss:  tensor(0.7041, grad_fn=<DivBackward1>)
# number of surfaces processed:  30
# loss:  tensor(0.3154, grad_fn=<DivBackward1>)
# loss:  tensor(1.1252, grad_fn=<DivBackward1>)
# loss:  tensor(0.3835, grad_fn=<DivBackward1>)
# loss:  tensor(0.3839, grad_fn=<DivBackward1>)
# loss:  tensor(0.5631, grad_fn=<DivBackward1>)
# loss:  tensor(0.3658, grad_fn=<DivBackward1>)
# loss:  tensor(0.3368, grad_fn=<DivBackward1>)
# loss:  tensor(0.4269, grad_fn=<DivBackward1>)
# loss:  tensor(0.3135, grad_fn=<DivBackward1>)
# Accuracy of the network on the 40 training surfaces at epoch 10 : 92.5
# -----------
# ***********
# -----------
# epoch:  11
# loss:  tensor(0.3657, grad_fn=<DivBackward1>)
# number of surfaces processed:  0
# loss:  tensor(0.3767, grad_fn=<DivBackward1>)
# loss:  tensor(0.3203, grad_fn=<DivBackward1>)
# loss:  tensor(0.4065, grad_fn=<DivBackward1>)
# loss:  tensor(0.8575, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3909, grad_fn=<DivBackward1>)
# loss:  tensor(0.3858, grad_fn=<DivBackward1>)
# loss:  tensor(0.3285, grad_fn=<DivBackward1>)
# loss:  tensor(0.4021, grad_fn=<DivBackward1>)
# loss:  tensor(0.3781, grad_fn=<DivBackward1>)
# number of surfaces processed:  10
# loss:  tensor(0.3543, grad_fn=<DivBackward1>)
# loss:  tensor(0.3179, grad_fn=<DivBackward1>)
# loss:  tensor(0.3176, grad_fn=<DivBackward1>)
# loss:  tensor(0.5255, grad_fn=<DivBackward1>)
# loss:  tensor(0.3648, grad_fn=<DivBackward1>)
# loss:  tensor(0.4644, grad_fn=<DivBackward1>)
# loss:  tensor(0.3514, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.4684, grad_fn=<DivBackward1>)
# loss:  tensor(0.3688, grad_fn=<DivBackward1>)
# number of surfaces processed:  20
# loss:  tensor(0.3882, grad_fn=<DivBackward1>)
# loss:  tensor(0.4809, grad_fn=<DivBackward1>)
# loss:  tensor(0.3250, grad_fn=<DivBackward1>)
# loss:  tensor(0.3138, grad_fn=<DivBackward1>)
# loss:  tensor(0.3139, grad_fn=<DivBackward1>)
# loss:  tensor(0.4525, grad_fn=<DivBackward1>)
# loss:  tensor(0.3906, grad_fn=<DivBackward1>)
# loss:  tensor(0.6094, grad_fn=<DivBackward1>)
# loss:  tensor(0.3540, grad_fn=<DivBackward1>)
# loss:  tensor(0.6896, grad_fn=<DivBackward1>)
# number of surfaces processed:  30
# loss:  tensor(0.3150, grad_fn=<DivBackward1>)
# loss:  tensor(1.1219, grad_fn=<DivBackward1>)
# loss:  tensor(0.3842, grad_fn=<DivBackward1>)
# loss:  tensor(0.3849, grad_fn=<DivBackward1>)
# loss:  tensor(0.5489, grad_fn=<DivBackward1>)
# loss:  tensor(0.3607, grad_fn=<DivBackward1>)
# loss:  tensor(0.3341, grad_fn=<DivBackward1>)
# loss:  tensor(0.4167, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# Accuracy of the network on the 40 training surfaces at epoch 11 : 95.0
# -----------
# ***********
# -----------
# epoch:  12
# loss:  tensor(0.3673, grad_fn=<DivBackward1>)
# number of surfaces processed:  0
# loss:  tensor(0.3765, grad_fn=<DivBackward1>)
# loss:  tensor(0.3194, grad_fn=<DivBackward1>)
# loss:  tensor(0.4087, grad_fn=<DivBackward1>)
# loss:  tensor(0.8428, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3921, grad_fn=<DivBackward1>)
# loss:  tensor(0.3887, grad_fn=<DivBackward1>)
# loss:  tensor(0.3266, grad_fn=<DivBackward1>)
# loss:  tensor(0.4006, grad_fn=<DivBackward1>)
# loss:  tensor(0.3785, grad_fn=<DivBackward1>)
# number of surfaces processed:  10
# loss:  tensor(0.3547, grad_fn=<DivBackward1>)
# loss:  tensor(0.3173, grad_fn=<DivBackward1>)
# loss:  tensor(0.3170, grad_fn=<DivBackward1>)
# loss:  tensor(0.5293, grad_fn=<DivBackward1>)
# loss:  tensor(0.3652, grad_fn=<DivBackward1>)
# loss:  tensor(0.4657, grad_fn=<DivBackward1>)
# loss:  tensor(0.3517, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.4752, grad_fn=<DivBackward1>)
# loss:  tensor(0.3690, grad_fn=<DivBackward1>)
# number of surfaces processed:  20
# loss:  tensor(0.3896, grad_fn=<DivBackward1>)
# loss:  tensor(0.4697, grad_fn=<DivBackward1>)
# loss:  tensor(0.3237, grad_fn=<DivBackward1>)
# loss:  tensor(0.3137, grad_fn=<DivBackward1>)
# loss:  tensor(0.3138, grad_fn=<DivBackward1>)
# loss:  tensor(0.4421, grad_fn=<DivBackward1>)
# loss:  tensor(0.3899, grad_fn=<DivBackward1>)
# loss:  tensor(0.6180, grad_fn=<DivBackward1>)
# loss:  tensor(0.3541, grad_fn=<DivBackward1>)
# loss:  tensor(0.6785, grad_fn=<DivBackward1>)
# number of surfaces processed:  30
# loss:  tensor(0.3148, grad_fn=<DivBackward1>)
# loss:  tensor(1.1189, grad_fn=<DivBackward1>)
# loss:  tensor(0.3845, grad_fn=<DivBackward1>)
# loss:  tensor(0.3865, grad_fn=<DivBackward1>)
# loss:  tensor(0.5363, grad_fn=<DivBackward1>)
# loss:  tensor(0.3567, grad_fn=<DivBackward1>)
# loss:  tensor(0.3318, grad_fn=<DivBackward1>)
# loss:  tensor(0.4087, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# Accuracy of the network on the 40 training surfaces at epoch 12 : 95.0
# -----------
# ***********
# -----------
# epoch:  13
# loss:  tensor(0.3690, grad_fn=<DivBackward1>)
# number of surfaces processed:  0
# loss:  tensor(0.3760, grad_fn=<DivBackward1>)
# loss:  tensor(0.3187, grad_fn=<DivBackward1>)
# loss:  tensor(0.4112, grad_fn=<DivBackward1>)
# loss:  tensor(0.8300, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3928, grad_fn=<DivBackward1>)
# loss:  tensor(0.3913, grad_fn=<DivBackward1>)
# loss:  tensor(0.3251, grad_fn=<DivBackward1>)
# loss:  tensor(0.3989, grad_fn=<DivBackward1>)
# loss:  tensor(0.3796, grad_fn=<DivBackward1>)
# number of surfaces processed:  10
# loss:  tensor(0.3550, grad_fn=<DivBackward1>)
# loss:  tensor(0.3169, grad_fn=<DivBackward1>)
# loss:  tensor(0.3165, grad_fn=<DivBackward1>)
# loss:  tensor(0.5330, grad_fn=<DivBackward1>)
# loss:  tensor(0.3657, grad_fn=<DivBackward1>)
# loss:  tensor(0.4675, grad_fn=<DivBackward1>)
# loss:  tensor(0.3521, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.4815, grad_fn=<DivBackward1>)
# loss:  tensor(0.3696, grad_fn=<DivBackward1>)
# number of surfaces processed:  20
# loss:  tensor(0.3912, grad_fn=<DivBackward1>)
# loss:  tensor(0.4598, grad_fn=<DivBackward1>)
# loss:  tensor(0.3226, grad_fn=<DivBackward1>)
# loss:  tensor(0.3136, grad_fn=<DivBackward1>)
# loss:  tensor(0.3138, grad_fn=<DivBackward1>)
# loss:  tensor(0.4334, grad_fn=<DivBackward1>)
# loss:  tensor(0.3898, grad_fn=<DivBackward1>)
# loss:  tensor(0.6263, grad_fn=<DivBackward1>)
# loss:  tensor(0.3541, grad_fn=<DivBackward1>)
# loss:  tensor(0.6680, grad_fn=<DivBackward1>)
# number of surfaces processed:  30
# loss:  tensor(0.3146, grad_fn=<DivBackward1>)
# loss:  tensor(1.1162, grad_fn=<DivBackward1>)
# loss:  tensor(0.3850, grad_fn=<DivBackward1>)
# loss:  tensor(0.3879, grad_fn=<DivBackward1>)
# loss:  tensor(0.5257, grad_fn=<DivBackward1>)
# loss:  tensor(0.3533, grad_fn=<DivBackward1>)
# loss:  tensor(0.3301, grad_fn=<DivBackward1>)
# loss:  tensor(0.4019, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# Accuracy of the network on the 40 training surfaces at epoch 13 : 95.0
# -----------
# ***********
# -----------
# epoch:  14
# loss:  tensor(0.3706, grad_fn=<DivBackward1>)
# number of surfaces processed:  0
# loss:  tensor(0.3758, grad_fn=<DivBackward1>)
# loss:  tensor(0.3181, grad_fn=<DivBackward1>)
# loss:  tensor(0.4132, grad_fn=<DivBackward1>)
# loss:  tensor(0.8188, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3940, grad_fn=<DivBackward1>)
# loss:  tensor(0.3935, grad_fn=<DivBackward1>)
# loss:  tensor(0.3239, grad_fn=<DivBackward1>)
# loss:  tensor(0.3982, grad_fn=<DivBackward1>)
# loss:  tensor(0.3803, grad_fn=<DivBackward1>)
# number of surfaces processed:  10
# loss:  tensor(0.3552, grad_fn=<DivBackward1>)
# loss:  tensor(0.3165, grad_fn=<DivBackward1>)
# loss:  tensor(0.3162, grad_fn=<DivBackward1>)
# loss:  tensor(0.5362, grad_fn=<DivBackward1>)
# loss:  tensor(0.3661, grad_fn=<DivBackward1>)
# loss:  tensor(0.4697, grad_fn=<DivBackward1>)
# loss:  tensor(0.3523, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.4864, grad_fn=<DivBackward1>)
# loss:  tensor(0.3702, grad_fn=<DivBackward1>)
# number of surfaces processed:  20
# loss:  tensor(0.3921, grad_fn=<DivBackward1>)
# loss:  tensor(0.4522, grad_fn=<DivBackward1>)
# loss:  tensor(0.3217, grad_fn=<DivBackward1>)
# loss:  tensor(0.3136, grad_fn=<DivBackward1>)
# loss:  tensor(0.3137, grad_fn=<DivBackward1>)
# loss:  tensor(0.4260, grad_fn=<DivBackward1>)
# loss:  tensor(0.3894, grad_fn=<DivBackward1>)
# loss:  tensor(0.6345, grad_fn=<DivBackward1>)
# loss:  tensor(0.3542, grad_fn=<DivBackward1>)
# loss:  tensor(0.6573, grad_fn=<DivBackward1>)
# number of surfaces processed:  30
# loss:  tensor(0.3145, grad_fn=<DivBackward1>)
# loss:  tensor(1.1137, grad_fn=<DivBackward1>)
# loss:  tensor(0.3858, grad_fn=<DivBackward1>)
# loss:  tensor(0.3894, grad_fn=<DivBackward1>)
# loss:  tensor(0.5189, grad_fn=<DivBackward1>)
# loss:  tensor(0.3508, grad_fn=<DivBackward1>)
# loss:  tensor(0.3291, grad_fn=<DivBackward1>)
# loss:  tensor(0.3961, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# Accuracy of the network on the 40 training surfaces at epoch 14 : 95.0
# -----------
# ***********
# -----------
# epoch:  15
# loss:  tensor(0.3721, grad_fn=<DivBackward1>)
# number of surfaces processed:  0
# loss:  tensor(0.3758, grad_fn=<DivBackward1>)
# loss:  tensor(0.3177, grad_fn=<DivBackward1>)
# loss:  tensor(0.4135, grad_fn=<DivBackward1>)
# loss:  tensor(0.8083, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3953, grad_fn=<DivBackward1>)
# loss:  tensor(0.3960, grad_fn=<DivBackward1>)
# loss:  tensor(0.3231, grad_fn=<DivBackward1>)
# loss:  tensor(0.3975, grad_fn=<DivBackward1>)
# loss:  tensor(0.3799, grad_fn=<DivBackward1>)
# number of surfaces processed:  10
# loss:  tensor(0.3556, grad_fn=<DivBackward1>)
# loss:  tensor(0.3163, grad_fn=<DivBackward1>)
# loss:  tensor(0.3159, grad_fn=<DivBackward1>)
# loss:  tensor(0.5372, grad_fn=<DivBackward1>)
# loss:  tensor(0.3662, grad_fn=<DivBackward1>)
# loss:  tensor(0.4709, grad_fn=<DivBackward1>)
# loss:  tensor(0.3524, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.4899, grad_fn=<DivBackward1>)
# loss:  tensor(0.3708, grad_fn=<DivBackward1>)
# number of surfaces processed:  20
# loss:  tensor(0.3922, grad_fn=<DivBackward1>)
# loss:  tensor(0.4472, grad_fn=<DivBackward1>)
# loss:  tensor(0.3212, grad_fn=<DivBackward1>)
# loss:  tensor(0.3135, grad_fn=<DivBackward1>)
# loss:  tensor(0.3137, grad_fn=<DivBackward1>)
# loss:  tensor(0.4202, grad_fn=<DivBackward1>)
# loss:  tensor(0.3877, grad_fn=<DivBackward1>)
# loss:  tensor(0.6394, grad_fn=<DivBackward1>)
# loss:  tensor(0.3543, grad_fn=<DivBackward1>)
# loss:  tensor(0.6456, grad_fn=<DivBackward1>)
# number of surfaces processed:  30
# loss:  tensor(0.3144, grad_fn=<DivBackward1>)
# loss:  tensor(1.1113, grad_fn=<DivBackward1>)
# loss:  tensor(0.3872, grad_fn=<DivBackward1>)
# loss:  tensor(0.3911, grad_fn=<DivBackward1>)
# loss:  tensor(0.5155, grad_fn=<DivBackward1>)
# loss:  tensor(0.3490, grad_fn=<DivBackward1>)
# loss:  tensor(0.3287, grad_fn=<DivBackward1>)
# loss:  tensor(0.3909, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# Accuracy of the network on the 40 training surfaces at epoch 15 : 95.0
# -----------
# ***********
# -----------
# epoch:  16
# loss:  tensor(0.3728, grad_fn=<DivBackward1>)
# number of surfaces processed:  0
# loss:  tensor(0.3768, grad_fn=<DivBackward1>)
# loss:  tensor(0.3173, grad_fn=<DivBackward1>)
# loss:  tensor(0.4108, grad_fn=<DivBackward1>)
# loss:  tensor(0.7986, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3974, grad_fn=<DivBackward1>)
# loss:  tensor(0.3986, grad_fn=<DivBackward1>)
# loss:  tensor(0.3225, grad_fn=<DivBackward1>)
# loss:  tensor(0.3964, grad_fn=<DivBackward1>)
# loss:  tensor(0.3786, grad_fn=<DivBackward1>)
# number of surfaces processed:  10
# loss:  tensor(0.3560, grad_fn=<DivBackward1>)
# loss:  tensor(0.3162, grad_fn=<DivBackward1>)
# loss:  tensor(0.3158, grad_fn=<DivBackward1>)
# loss:  tensor(0.5360, grad_fn=<DivBackward1>)
# loss:  tensor(0.3661, grad_fn=<DivBackward1>)
# loss:  tensor(0.4703, grad_fn=<DivBackward1>)
# loss:  tensor(0.3525, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.4926, grad_fn=<DivBackward1>)
# loss:  tensor(0.3714, grad_fn=<DivBackward1>)
# number of surfaces processed:  20
# loss:  tensor(0.3916, grad_fn=<DivBackward1>)
# loss:  tensor(0.4448, grad_fn=<DivBackward1>)
# loss:  tensor(0.3208, grad_fn=<DivBackward1>)
# loss:  tensor(0.3135, grad_fn=<DivBackward1>)
# loss:  tensor(0.3136, grad_fn=<DivBackward1>)
# loss:  tensor(0.4166, grad_fn=<DivBackward1>)
# loss:  tensor(0.3840, grad_fn=<DivBackward1>)
# loss:  tensor(0.6394, grad_fn=<DivBackward1>)
# loss:  tensor(0.3543, grad_fn=<DivBackward1>)
# loss:  tensor(0.6379, grad_fn=<DivBackward1>)
# number of surfaces processed:  30
# loss:  tensor(0.3144, grad_fn=<DivBackward1>)
# loss:  tensor(1.1093, grad_fn=<DivBackward1>)
# loss:  tensor(0.3873, grad_fn=<DivBackward1>)
# loss:  tensor(0.3921, grad_fn=<DivBackward1>)
# loss:  tensor(0.5128, grad_fn=<DivBackward1>)
# loss:  tensor(0.3475, grad_fn=<DivBackward1>)
# loss:  tensor(0.3285, grad_fn=<DivBackward1>)
# loss:  tensor(0.3870, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# Accuracy of the network on the 40 training surfaces at epoch 16 : 95.0
# -----------
# ***********
# -----------
# epoch:  17
# loss:  tensor(0.3750, grad_fn=<DivBackward1>)
# number of surfaces processed:  0
# loss:  tensor(0.3759, grad_fn=<DivBackward1>)
# loss:  tensor(0.3170, grad_fn=<DivBackward1>)
# loss:  tensor(0.4087, grad_fn=<DivBackward1>)
# loss:  tensor(0.7894, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3985, grad_fn=<DivBackward1>)
# loss:  tensor(0.4015, grad_fn=<DivBackward1>)
# loss:  tensor(0.3221, grad_fn=<DivBackward1>)
# loss:  tensor(0.3932, grad_fn=<DivBackward1>)
# loss:  tensor(0.3776, grad_fn=<DivBackward1>)
# number of surfaces processed:  10
# loss:  tensor(0.3565, grad_fn=<DivBackward1>)
# loss:  tensor(0.3161, grad_fn=<DivBackward1>)
# loss:  tensor(0.3157, grad_fn=<DivBackward1>)
# loss:  tensor(0.5353, grad_fn=<DivBackward1>)
# loss:  tensor(0.3662, grad_fn=<DivBackward1>)
# loss:  tensor(0.4683, grad_fn=<DivBackward1>)
# loss:  tensor(0.3525, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.4956, grad_fn=<DivBackward1>)
# loss:  tensor(0.3720, grad_fn=<DivBackward1>)
# number of surfaces processed:  20
# loss:  tensor(0.3908, grad_fn=<DivBackward1>)
# loss:  tensor(0.4431, grad_fn=<DivBackward1>)
# loss:  tensor(0.3206, grad_fn=<DivBackward1>)
# loss:  tensor(0.3135, grad_fn=<DivBackward1>)
# loss:  tensor(0.3136, grad_fn=<DivBackward1>)
# loss:  tensor(0.4133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3800, grad_fn=<DivBackward1>)
# loss:  tensor(0.6410, grad_fn=<DivBackward1>)
# loss:  tensor(0.3545, grad_fn=<DivBackward1>)
# loss:  tensor(0.6290, grad_fn=<DivBackward1>)
# number of surfaces processed:  30
# loss:  tensor(0.3143, grad_fn=<DivBackward1>)
# loss:  tensor(1.1073, grad_fn=<DivBackward1>)
# loss:  tensor(0.3880, grad_fn=<DivBackward1>)
# loss:  tensor(0.3929, grad_fn=<DivBackward1>)
# loss:  tensor(0.5096, grad_fn=<DivBackward1>)
# loss:  tensor(0.3460, grad_fn=<DivBackward1>)
# loss:  tensor(0.3282, grad_fn=<DivBackward1>)
# loss:  tensor(0.3830, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# Accuracy of the network on the 40 training surfaces at epoch 17 : 95.0
# -----------
# ***********
# -----------
# epoch:  18
# loss:  tensor(0.3763, grad_fn=<DivBackward1>)
# number of surfaces processed:  0
# loss:  tensor(0.3764, grad_fn=<DivBackward1>)
# loss:  tensor(0.3167, grad_fn=<DivBackward1>)
# loss:  tensor(0.4069, grad_fn=<DivBackward1>)
# loss:  tensor(0.7805, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.4003, grad_fn=<DivBackward1>)
# loss:  tensor(0.4039, grad_fn=<DivBackward1>)
# loss:  tensor(0.3216, grad_fn=<DivBackward1>)
# loss:  tensor(0.3924, grad_fn=<DivBackward1>)
# loss:  tensor(0.3765, grad_fn=<DivBackward1>)
# number of surfaces processed:  10
# loss:  tensor(0.3569, grad_fn=<DivBackward1>)
# loss:  tensor(0.3160, grad_fn=<DivBackward1>)
# loss:  tensor(0.3156, grad_fn=<DivBackward1>)
# loss:  tensor(0.5353, grad_fn=<DivBackward1>)
# loss:  tensor(0.3662, grad_fn=<DivBackward1>)
# loss:  tensor(0.4666, grad_fn=<DivBackward1>)
# loss:  tensor(0.3526, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.4989, grad_fn=<DivBackward1>)
# loss:  tensor(0.3725, grad_fn=<DivBackward1>)
# number of surfaces processed:  20
# loss:  tensor(0.3905, grad_fn=<DivBackward1>)
# loss:  tensor(0.4408, grad_fn=<DivBackward1>)
# loss:  tensor(0.3203, grad_fn=<DivBackward1>)
# loss:  tensor(0.3135, grad_fn=<DivBackward1>)
# loss:  tensor(0.3136, grad_fn=<DivBackward1>)
# loss:  tensor(0.4098, grad_fn=<DivBackward1>)
# loss:  tensor(0.3776, grad_fn=<DivBackward1>)
# loss:  tensor(0.6427, grad_fn=<DivBackward1>)
# loss:  tensor(0.3547, grad_fn=<DivBackward1>)
# loss:  tensor(0.6218, grad_fn=<DivBackward1>)
# number of surfaces processed:  30
# loss:  tensor(0.3143, grad_fn=<DivBackward1>)
# loss:  tensor(1.1055, grad_fn=<DivBackward1>)
# loss:  tensor(0.3884, grad_fn=<DivBackward1>)
# loss:  tensor(0.3941, grad_fn=<DivBackward1>)
# loss:  tensor(0.5059, grad_fn=<DivBackward1>)
# loss:  tensor(0.3446, grad_fn=<DivBackward1>)
# loss:  tensor(0.3277, grad_fn=<DivBackward1>)
# loss:  tensor(0.3797, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# Accuracy of the network on the 40 training surfaces at epoch 18 : 95.0
# -----------
# ***********
# -----------
# epoch:  19
# loss:  tensor(0.3784, grad_fn=<DivBackward1>)
# number of surfaces processed:  0
# loss:  tensor(0.3762, grad_fn=<DivBackward1>)
# loss:  tensor(0.3164, grad_fn=<DivBackward1>)
# loss:  tensor(0.4063, grad_fn=<DivBackward1>)
# loss:  tensor(0.7720, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.4011, grad_fn=<DivBackward1>)
# loss:  tensor(0.4068, grad_fn=<DivBackward1>)
# loss:  tensor(0.3212, grad_fn=<DivBackward1>)
# loss:  tensor(0.3916, grad_fn=<DivBackward1>)
# loss:  tensor(0.3761, grad_fn=<DivBackward1>)
# number of surfaces processed:  10
# loss:  tensor(0.3573, grad_fn=<DivBackward1>)
# loss:  tensor(0.3158, grad_fn=<DivBackward1>)
# loss:  tensor(0.3155, grad_fn=<DivBackward1>)
# loss:  tensor(0.5360, grad_fn=<DivBackward1>)
# loss:  tensor(0.3663, grad_fn=<DivBackward1>)
# loss:  tensor(0.4659, grad_fn=<DivBackward1>)
# loss:  tensor(0.3527, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.5021, grad_fn=<DivBackward1>)
# loss:  tensor(0.3732, grad_fn=<DivBackward1>)
# number of surfaces processed:  20
# loss:  tensor(0.3903, grad_fn=<DivBackward1>)
# loss:  tensor(0.4378, grad_fn=<DivBackward1>)
# loss:  tensor(0.3199, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3135, grad_fn=<DivBackward1>)
# loss:  tensor(0.4059, grad_fn=<DivBackward1>)
# loss:  tensor(0.3761, grad_fn=<DivBackward1>)
# loss:  tensor(0.6467, grad_fn=<DivBackward1>)
# loss:  tensor(0.3549, grad_fn=<DivBackward1>)
# loss:  tensor(0.6142, grad_fn=<DivBackward1>)
# number of surfaces processed:  30
# loss:  tensor(0.3142, grad_fn=<DivBackward1>)
# loss:  tensor(1.1037, grad_fn=<DivBackward1>)
# loss:  tensor(0.3891, grad_fn=<DivBackward1>)
# loss:  tensor(0.3946, grad_fn=<DivBackward1>)
# loss:  tensor(0.5021, grad_fn=<DivBackward1>)
# loss:  tensor(0.3433, grad_fn=<DivBackward1>)
# loss:  tensor(0.3273, grad_fn=<DivBackward1>)
# loss:  tensor(0.3762, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# Accuracy of the network on the 40 training surfaces at epoch 19 : 95.0
# -----------
# ***********
# -----------
# epoch:  20
# loss:  tensor(0.3796, grad_fn=<DivBackward1>)
# number of surfaces processed:  0
# loss:  tensor(0.3768, grad_fn=<DivBackward1>)
# loss:  tensor(0.3162, grad_fn=<DivBackward1>)
# loss:  tensor(0.4052, grad_fn=<DivBackward1>)
# loss:  tensor(0.7638, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.4028, grad_fn=<DivBackward1>)
# loss:  tensor(0.4096, grad_fn=<DivBackward1>)
# loss:  tensor(0.3207, grad_fn=<DivBackward1>)
# loss:  tensor(0.3909, grad_fn=<DivBackward1>)
# loss:  tensor(0.3755, grad_fn=<DivBackward1>)
# number of surfaces processed:  10
# loss:  tensor(0.3577, grad_fn=<DivBackward1>)
# loss:  tensor(0.3158, grad_fn=<DivBackward1>)
# loss:  tensor(0.3154, grad_fn=<DivBackward1>)
# loss:  tensor(0.5361, grad_fn=<DivBackward1>)
# loss:  tensor(0.3664, grad_fn=<DivBackward1>)
# loss:  tensor(0.4655, grad_fn=<DivBackward1>)
# loss:  tensor(0.3528, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.5055, grad_fn=<DivBackward1>)
# loss:  tensor(0.3737, grad_fn=<DivBackward1>)
# number of surfaces processed:  20
# loss:  tensor(0.3905, grad_fn=<DivBackward1>)
# loss:  tensor(0.4341, grad_fn=<DivBackward1>)
# loss:  tensor(0.3195, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3135, grad_fn=<DivBackward1>)
# loss:  tensor(0.4019, grad_fn=<DivBackward1>)
# loss:  tensor(0.3754, grad_fn=<DivBackward1>)
# loss:  tensor(0.6515, grad_fn=<DivBackward1>)
# loss:  tensor(0.3551, grad_fn=<DivBackward1>)
# loss:  tensor(0.6072, grad_fn=<DivBackward1>)
# number of surfaces processed:  30
# loss:  tensor(0.3141, grad_fn=<DivBackward1>)
# loss:  tensor(1.1018, grad_fn=<DivBackward1>)
# loss:  tensor(0.3899, grad_fn=<DivBackward1>)
# loss:  tensor(0.3956, grad_fn=<DivBackward1>)
# loss:  tensor(0.4971, grad_fn=<DivBackward1>)
# loss:  tensor(0.3419, grad_fn=<DivBackward1>)
# loss:  tensor(0.3266, grad_fn=<DivBackward1>)
# loss:  tensor(0.3729, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# Accuracy of the network on the 40 training surfaces at epoch 20 : 95.0
# -----------
# ***********
# -----------
# epoch:  21
# loss:  tensor(0.3805, grad_fn=<DivBackward1>)
# number of surfaces processed:  0
# loss:  tensor(0.3776, grad_fn=<DivBackward1>)
# loss:  tensor(0.3160, grad_fn=<DivBackward1>)
# loss:  tensor(0.4049, grad_fn=<DivBackward1>)
# loss:  tensor(0.7561, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.4048, grad_fn=<DivBackward1>)
# loss:  tensor(0.4110, grad_fn=<DivBackward1>)
# loss:  tensor(0.3203, grad_fn=<DivBackward1>)
# loss:  tensor(0.3912, grad_fn=<DivBackward1>)
# loss:  tensor(0.3748, grad_fn=<DivBackward1>)
# number of surfaces processed:  10
# loss:  tensor(0.3580, grad_fn=<DivBackward1>)
# loss:  tensor(0.3156, grad_fn=<DivBackward1>)
# loss:  tensor(0.3153, grad_fn=<DivBackward1>)
# loss:  tensor(0.5370, grad_fn=<DivBackward1>)
# loss:  tensor(0.3663, grad_fn=<DivBackward1>)
# loss:  tensor(0.4675, grad_fn=<DivBackward1>)
# loss:  tensor(0.3527, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.5072, grad_fn=<DivBackward1>)
# loss:  tensor(0.3745, grad_fn=<DivBackward1>)
# number of surfaces processed:  20
# loss:  tensor(0.3898, grad_fn=<DivBackward1>)
# loss:  tensor(0.4318, grad_fn=<DivBackward1>)
# loss:  tensor(0.3193, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3135, grad_fn=<DivBackward1>)
# loss:  tensor(0.3985, grad_fn=<DivBackward1>)
# loss:  tensor(0.3742, grad_fn=<DivBackward1>)
# loss:  tensor(0.6564, grad_fn=<DivBackward1>)
# loss:  tensor(0.3552, grad_fn=<DivBackward1>)
# loss:  tensor(0.6003, grad_fn=<DivBackward1>)
# number of surfaces processed:  30
# loss:  tensor(0.3141, grad_fn=<DivBackward1>)
# loss:  tensor(1.0998, grad_fn=<DivBackward1>)
# loss:  tensor(0.3906, grad_fn=<DivBackward1>)
# loss:  tensor(0.3969, grad_fn=<DivBackward1>)
# loss:  tensor(0.4938, grad_fn=<DivBackward1>)
# loss:  tensor(0.3408, grad_fn=<DivBackward1>)
# loss:  tensor(0.3262, grad_fn=<DivBackward1>)
# loss:  tensor(0.3701, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# Accuracy of the network on the 40 training surfaces at epoch 21 : 95.0
# -----------
# ***********
# -----------
# epoch:  22
# loss:  tensor(0.3812, grad_fn=<DivBackward1>)
# number of surfaces processed:  0
# loss:  tensor(0.3785, grad_fn=<DivBackward1>)
# loss:  tensor(0.3158, grad_fn=<DivBackward1>)
# loss:  tensor(0.4038, grad_fn=<DivBackward1>)
# loss:  tensor(0.7488, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.4068, grad_fn=<DivBackward1>)
# loss:  tensor(0.4128, grad_fn=<DivBackward1>)
# loss:  tensor(0.3199, grad_fn=<DivBackward1>)
# loss:  tensor(0.3914, grad_fn=<DivBackward1>)
# loss:  tensor(0.3739, grad_fn=<DivBackward1>)
# number of surfaces processed:  10
# loss:  tensor(0.3583, grad_fn=<DivBackward1>)
# loss:  tensor(0.3155, grad_fn=<DivBackward1>)
# loss:  tensor(0.3152, grad_fn=<DivBackward1>)
# loss:  tensor(0.5374, grad_fn=<DivBackward1>)
# loss:  tensor(0.3662, grad_fn=<DivBackward1>)
# loss:  tensor(0.4694, grad_fn=<DivBackward1>)
# loss:  tensor(0.3527, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.5091, grad_fn=<DivBackward1>)
# loss:  tensor(0.3752, grad_fn=<DivBackward1>)
# number of surfaces processed:  20
# loss:  tensor(0.3893, grad_fn=<DivBackward1>)
# loss:  tensor(0.4293, grad_fn=<DivBackward1>)
# loss:  tensor(0.3190, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3135, grad_fn=<DivBackward1>)
# loss:  tensor(0.3954, grad_fn=<DivBackward1>)
# loss:  tensor(0.3732, grad_fn=<DivBackward1>)
# loss:  tensor(0.6611, grad_fn=<DivBackward1>)
# loss:  tensor(0.3553, grad_fn=<DivBackward1>)
# loss:  tensor(0.5944, grad_fn=<DivBackward1>)
# number of surfaces processed:  30
# loss:  tensor(0.3140, grad_fn=<DivBackward1>)
# loss:  tensor(1.0978, grad_fn=<DivBackward1>)
# loss:  tensor(0.3911, grad_fn=<DivBackward1>)
# loss:  tensor(0.3982, grad_fn=<DivBackward1>)
# loss:  tensor(0.4897, grad_fn=<DivBackward1>)
# loss:  tensor(0.3396, grad_fn=<DivBackward1>)
# loss:  tensor(0.3257, grad_fn=<DivBackward1>)
# loss:  tensor(0.3676, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# Accuracy of the network on the 40 training surfaces at epoch 22 : 95.0
# -----------
# ***********
# -----------
# epoch:  23
# loss:  tensor(0.3823, grad_fn=<DivBackward1>)
# number of surfaces processed:  0
# loss:  tensor(0.3787, grad_fn=<DivBackward1>)
# loss:  tensor(0.3156, grad_fn=<DivBackward1>)
# loss:  tensor(0.4038, grad_fn=<DivBackward1>)
# loss:  tensor(0.7420, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.4080, grad_fn=<DivBackward1>)
# loss:  tensor(0.4147, grad_fn=<DivBackward1>)
# loss:  tensor(0.3196, grad_fn=<DivBackward1>)
# loss:  tensor(0.3909, grad_fn=<DivBackward1>)
# loss:  tensor(0.3737, grad_fn=<DivBackward1>)
# number of surfaces processed:  10
# loss:  tensor(0.3585, grad_fn=<DivBackward1>)
# loss:  tensor(0.3154, grad_fn=<DivBackward1>)
# loss:  tensor(0.3151, grad_fn=<DivBackward1>)
# loss:  tensor(0.5386, grad_fn=<DivBackward1>)
# loss:  tensor(0.3663, grad_fn=<DivBackward1>)
# loss:  tensor(0.4711, grad_fn=<DivBackward1>)
# loss:  tensor(0.3529, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.5123, grad_fn=<DivBackward1>)
# loss:  tensor(0.3759, grad_fn=<DivBackward1>)
# number of surfaces processed:  20
# loss:  tensor(0.3893, grad_fn=<DivBackward1>)
# loss:  tensor(0.4265, grad_fn=<DivBackward1>)
# loss:  tensor(0.3187, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3135, grad_fn=<DivBackward1>)
# loss:  tensor(0.3923, grad_fn=<DivBackward1>)
# loss:  tensor(0.3730, grad_fn=<DivBackward1>)
# loss:  tensor(0.6665, grad_fn=<DivBackward1>)
# loss:  tensor(0.3554, grad_fn=<DivBackward1>)
# loss:  tensor(0.5886, grad_fn=<DivBackward1>)
# number of surfaces processed:  30
# loss:  tensor(0.3140, grad_fn=<DivBackward1>)
# loss:  tensor(1.0958, grad_fn=<DivBackward1>)
# loss:  tensor(0.3918, grad_fn=<DivBackward1>)
# loss:  tensor(0.3993, grad_fn=<DivBackward1>)
# loss:  tensor(0.4860, grad_fn=<DivBackward1>)
# loss:  tensor(0.3386, grad_fn=<DivBackward1>)
# loss:  tensor(0.3252, grad_fn=<DivBackward1>)
# loss:  tensor(0.3653, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# Accuracy of the network on the 40 training surfaces at epoch 23 : 95.0
# -----------
# ***********
# -----------
# epoch:  24
# loss:  tensor(0.3830, grad_fn=<DivBackward1>)
# number of surfaces processed:  0
# loss:  tensor(0.3793, grad_fn=<DivBackward1>)
# loss:  tensor(0.3155, grad_fn=<DivBackward1>)
# loss:  tensor(0.4031, grad_fn=<DivBackward1>)
# loss:  tensor(0.7357, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.4098, grad_fn=<DivBackward1>)
# loss:  tensor(0.4161, grad_fn=<DivBackward1>)
# loss:  tensor(0.3193, grad_fn=<DivBackward1>)
# loss:  tensor(0.3915, grad_fn=<DivBackward1>)
# loss:  tensor(0.3729, grad_fn=<DivBackward1>)
# number of surfaces processed:  10
# loss:  tensor(0.3587, grad_fn=<DivBackward1>)
# loss:  tensor(0.3154, grad_fn=<DivBackward1>)
# loss:  tensor(0.3151, grad_fn=<DivBackward1>)
# loss:  tensor(0.5392, grad_fn=<DivBackward1>)
# loss:  tensor(0.3662, grad_fn=<DivBackward1>)
# loss:  tensor(0.4729, grad_fn=<DivBackward1>)
# loss:  tensor(0.3528, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.5134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3764, grad_fn=<DivBackward1>)
# number of surfaces processed:  20
# loss:  tensor(0.3893, grad_fn=<DivBackward1>)
# loss:  tensor(0.4241, grad_fn=<DivBackward1>)
# loss:  tensor(0.3185, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3135, grad_fn=<DivBackward1>)
# loss:  tensor(0.3897, grad_fn=<DivBackward1>)
# loss:  tensor(0.3727, grad_fn=<DivBackward1>)
# loss:  tensor(0.6709, grad_fn=<DivBackward1>)
# loss:  tensor(0.3555, grad_fn=<DivBackward1>)
# loss:  tensor(0.5833, grad_fn=<DivBackward1>)
# number of surfaces processed:  30
# loss:  tensor(0.3139, grad_fn=<DivBackward1>)
# loss:  tensor(1.0940, grad_fn=<DivBackward1>)
# loss:  tensor(0.3924, grad_fn=<DivBackward1>)
# loss:  tensor(0.4004, grad_fn=<DivBackward1>)
# loss:  tensor(0.4828, grad_fn=<DivBackward1>)
# loss:  tensor(0.3377, grad_fn=<DivBackward1>)
# loss:  tensor(0.3248, grad_fn=<DivBackward1>)
# loss:  tensor(0.3633, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# Accuracy of the network on the 40 training surfaces at epoch 24 : 95.0
# -----------
# ***********
# -----------
# epoch:  25
# loss:  tensor(0.3837, grad_fn=<DivBackward1>)
# number of surfaces processed:  0
# loss:  tensor(0.3797, grad_fn=<DivBackward1>)
# loss:  tensor(0.3153, grad_fn=<DivBackward1>)
# loss:  tensor(0.4027, grad_fn=<DivBackward1>)
# loss:  tensor(0.7297, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.4111, grad_fn=<DivBackward1>)
# loss:  tensor(0.4175, grad_fn=<DivBackward1>)
# loss:  tensor(0.3190, grad_fn=<DivBackward1>)
# loss:  tensor(0.3917, grad_fn=<DivBackward1>)
# loss:  tensor(0.3728, grad_fn=<DivBackward1>)
# number of surfaces processed:  10
# loss:  tensor(0.3588, grad_fn=<DivBackward1>)
# loss:  tensor(0.3153, grad_fn=<DivBackward1>)
# loss:  tensor(0.3150, grad_fn=<DivBackward1>)
# loss:  tensor(0.5404, grad_fn=<DivBackward1>)
# loss:  tensor(0.3663, grad_fn=<DivBackward1>)
# loss:  tensor(0.4745, grad_fn=<DivBackward1>)
# loss:  tensor(0.3529, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.5159, grad_fn=<DivBackward1>)
# loss:  tensor(0.3767, grad_fn=<DivBackward1>)
# number of surfaces processed:  20
# loss:  tensor(0.3896, grad_fn=<DivBackward1>)
# loss:  tensor(0.4217, grad_fn=<DivBackward1>)
# loss:  tensor(0.3183, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3874, grad_fn=<DivBackward1>)
# loss:  tensor(0.3723, grad_fn=<DivBackward1>)
# loss:  tensor(0.6741, grad_fn=<DivBackward1>)
# loss:  tensor(0.3556, grad_fn=<DivBackward1>)
# loss:  tensor(0.5786, grad_fn=<DivBackward1>)
# number of surfaces processed:  30
# loss:  tensor(0.3139, grad_fn=<DivBackward1>)
# loss:  tensor(1.0923, grad_fn=<DivBackward1>)
# loss:  tensor(0.3928, grad_fn=<DivBackward1>)
# loss:  tensor(0.4014, grad_fn=<DivBackward1>)
# loss:  tensor(0.4799, grad_fn=<DivBackward1>)
# loss:  tensor(0.3369, grad_fn=<DivBackward1>)
# loss:  tensor(0.3245, grad_fn=<DivBackward1>)
# loss:  tensor(0.3615, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# Accuracy of the network on the 40 training surfaces at epoch 25 : 95.0
# -----------
# ***********
# -----------
# epoch:  26
# loss:  tensor(0.3845, grad_fn=<DivBackward1>)
# number of surfaces processed:  0
# loss:  tensor(0.3799, grad_fn=<DivBackward1>)
# loss:  tensor(0.3152, grad_fn=<DivBackward1>)
# loss:  tensor(0.4024, grad_fn=<DivBackward1>)
# loss:  tensor(0.7245, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.4119, grad_fn=<DivBackward1>)
# loss:  tensor(0.4191, grad_fn=<DivBackward1>)
# loss:  tensor(0.3188, grad_fn=<DivBackward1>)
# loss:  tensor(0.3914, grad_fn=<DivBackward1>)
# loss:  tensor(0.3726, grad_fn=<DivBackward1>)
# number of surfaces processed:  10
# loss:  tensor(0.3589, grad_fn=<DivBackward1>)
# loss:  tensor(0.3152, grad_fn=<DivBackward1>)
# loss:  tensor(0.3149, grad_fn=<DivBackward1>)
# loss:  tensor(0.5412, grad_fn=<DivBackward1>)
# loss:  tensor(0.3663, grad_fn=<DivBackward1>)
# loss:  tensor(0.4761, grad_fn=<DivBackward1>)
# loss:  tensor(0.3529, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.5184, grad_fn=<DivBackward1>)
# loss:  tensor(0.3770, grad_fn=<DivBackward1>)
# number of surfaces processed:  20
# loss:  tensor(0.3895, grad_fn=<DivBackward1>)
# loss:  tensor(0.4201, grad_fn=<DivBackward1>)
# loss:  tensor(0.3181, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3856, grad_fn=<DivBackward1>)
# loss:  tensor(0.3719, grad_fn=<DivBackward1>)
# loss:  tensor(0.6777, grad_fn=<DivBackward1>)
# loss:  tensor(0.3556, grad_fn=<DivBackward1>)
# loss:  tensor(0.5752, grad_fn=<DivBackward1>)
# number of surfaces processed:  30
# loss:  tensor(0.3139, grad_fn=<DivBackward1>)
# loss:  tensor(1.0910, grad_fn=<DivBackward1>)
# loss:  tensor(0.3927, grad_fn=<DivBackward1>)
# loss:  tensor(0.4023, grad_fn=<DivBackward1>)
# loss:  tensor(0.4765, grad_fn=<DivBackward1>)
# loss:  tensor(0.3362, grad_fn=<DivBackward1>)
# loss:  tensor(0.3241, grad_fn=<DivBackward1>)
# loss:  tensor(0.3601, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# Accuracy of the network on the 40 training surfaces at epoch 26 : 95.0
# -----------
# ***********
# -----------
# epoch:  27
# loss:  tensor(0.3857, grad_fn=<DivBackward1>)
# number of surfaces processed:  0
# loss:  tensor(0.3796, grad_fn=<DivBackward1>)
# loss:  tensor(0.3151, grad_fn=<DivBackward1>)
# loss:  tensor(0.4028, grad_fn=<DivBackward1>)
# loss:  tensor(0.7196, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.4123, grad_fn=<DivBackward1>)
# loss:  tensor(0.4207, grad_fn=<DivBackward1>)
# loss:  tensor(0.3186, grad_fn=<DivBackward1>)
# loss:  tensor(0.3904, grad_fn=<DivBackward1>)
# loss:  tensor(0.3730, grad_fn=<DivBackward1>)
# number of surfaces processed:  10
# loss:  tensor(0.3590, grad_fn=<DivBackward1>)
# loss:  tensor(0.3151, grad_fn=<DivBackward1>)
# loss:  tensor(0.3148, grad_fn=<DivBackward1>)
# loss:  tensor(0.5427, grad_fn=<DivBackward1>)
# loss:  tensor(0.3665, grad_fn=<DivBackward1>)
# loss:  tensor(0.4776, grad_fn=<DivBackward1>)
# loss:  tensor(0.3531, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.5214, grad_fn=<DivBackward1>)
# loss:  tensor(0.3772, grad_fn=<DivBackward1>)
# number of surfaces processed:  20
# loss:  tensor(0.3899, grad_fn=<DivBackward1>)
# loss:  tensor(0.4178, grad_fn=<DivBackward1>)
# loss:  tensor(0.3179, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3836, grad_fn=<DivBackward1>)
# loss:  tensor(0.3719, grad_fn=<DivBackward1>)
# loss:  tensor(0.6811, grad_fn=<DivBackward1>)
# loss:  tensor(0.3557, grad_fn=<DivBackward1>)
# loss:  tensor(0.5717, grad_fn=<DivBackward1>)
# number of surfaces processed:  30
# loss:  tensor(0.3138, grad_fn=<DivBackward1>)
# loss:  tensor(1.0897, grad_fn=<DivBackward1>)
# loss:  tensor(0.3930, grad_fn=<DivBackward1>)
# loss:  tensor(0.4031, grad_fn=<DivBackward1>)
# loss:  tensor(0.4736, grad_fn=<DivBackward1>)
# loss:  tensor(0.3355, grad_fn=<DivBackward1>)
# loss:  tensor(0.3237, grad_fn=<DivBackward1>)
# loss:  tensor(0.3587, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# Accuracy of the network on the 40 training surfaces at epoch 27 : 95.0
# -----------
# ***********
# -----------
# epoch:  28
# loss:  tensor(0.3866, grad_fn=<DivBackward1>)
# number of surfaces processed:  0
# loss:  tensor(0.3796, grad_fn=<DivBackward1>)
# loss:  tensor(0.3151, grad_fn=<DivBackward1>)
# loss:  tensor(0.4030, grad_fn=<DivBackward1>)
# loss:  tensor(0.7151, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.4129, grad_fn=<DivBackward1>)
# loss:  tensor(0.4220, grad_fn=<DivBackward1>)
# loss:  tensor(0.3184, grad_fn=<DivBackward1>)
# loss:  tensor(0.3902, grad_fn=<DivBackward1>)
# loss:  tensor(0.3732, grad_fn=<DivBackward1>)
# number of surfaces processed:  10
# loss:  tensor(0.3590, grad_fn=<DivBackward1>)
# loss:  tensor(0.3150, grad_fn=<DivBackward1>)
# loss:  tensor(0.3148, grad_fn=<DivBackward1>)
# loss:  tensor(0.5441, grad_fn=<DivBackward1>)
# loss:  tensor(0.3666, grad_fn=<DivBackward1>)
# loss:  tensor(0.4790, grad_fn=<DivBackward1>)
# loss:  tensor(0.3531, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.5234, grad_fn=<DivBackward1>)
# loss:  tensor(0.3776, grad_fn=<DivBackward1>)
# number of surfaces processed:  20
# loss:  tensor(0.3902, grad_fn=<DivBackward1>)
# loss:  tensor(0.4156, grad_fn=<DivBackward1>)
# loss:  tensor(0.3177, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3817, grad_fn=<DivBackward1>)
# loss:  tensor(0.3720, grad_fn=<DivBackward1>)
# loss:  tensor(0.6851, grad_fn=<DivBackward1>)
# loss:  tensor(0.3557, grad_fn=<DivBackward1>)
# loss:  tensor(0.5683, grad_fn=<DivBackward1>)
# number of surfaces processed:  30
# loss:  tensor(0.3138, grad_fn=<DivBackward1>)
# loss:  tensor(1.0884, grad_fn=<DivBackward1>)
# loss:  tensor(0.3934, grad_fn=<DivBackward1>)
# loss:  tensor(0.4038, grad_fn=<DivBackward1>)
# loss:  tensor(0.4709, grad_fn=<DivBackward1>)
# loss:  tensor(0.3349, grad_fn=<DivBackward1>)
# loss:  tensor(0.3234, grad_fn=<DivBackward1>)
# loss:  tensor(0.3574, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# Accuracy of the network on the 40 training surfaces at epoch 28 : 95.0
# -----------
# ***********
# -----------
# epoch:  29
# loss:  tensor(0.3871, grad_fn=<DivBackward1>)
# number of surfaces processed:  0
# loss:  tensor(0.3799, grad_fn=<DivBackward1>)
# loss:  tensor(0.3150, grad_fn=<DivBackward1>)
# loss:  tensor(0.4031, grad_fn=<DivBackward1>)
# loss:  tensor(0.7110, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.4138, grad_fn=<DivBackward1>)
# loss:  tensor(0.4230, grad_fn=<DivBackward1>)
# loss:  tensor(0.3182, grad_fn=<DivBackward1>)
# loss:  tensor(0.3905, grad_fn=<DivBackward1>)
# loss:  tensor(0.3732, grad_fn=<DivBackward1>)
# number of surfaces processed:  10
# loss:  tensor(0.3591, grad_fn=<DivBackward1>)
# loss:  tensor(0.3150, grad_fn=<DivBackward1>)
# loss:  tensor(0.3147, grad_fn=<DivBackward1>)
# loss:  tensor(0.5453, grad_fn=<DivBackward1>)
# loss:  tensor(0.3667, grad_fn=<DivBackward1>)
# loss:  tensor(0.4803, grad_fn=<DivBackward1>)
# loss:  tensor(0.3532, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.5250, grad_fn=<DivBackward1>)
# loss:  tensor(0.3780, grad_fn=<DivBackward1>)
# number of surfaces processed:  20
# loss:  tensor(0.3904, grad_fn=<DivBackward1>)
# loss:  tensor(0.4138, grad_fn=<DivBackward1>)
# loss:  tensor(0.3176, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# loss:  tensor(0.3134, grad_fn=<DivBackward1>)
# loss:  tensor(0.3801, grad_fn=<DivBackward1>)
# loss:  tensor(0.3720, grad_fn=<DivBackward1>)
# loss:  tensor(0.6888, grad_fn=<DivBackward1>)
# loss:  tensor(0.3558, grad_fn=<DivBackward1>)
# loss:  tensor(0.5651, grad_fn=<DivBackward1>)
# number of surfaces processed:  30
# loss:  tensor(0.3138, grad_fn=<DivBackward1>)
# loss:  tensor(1.0872, grad_fn=<DivBackward1>)
# loss:  tensor(0.3937, grad_fn=<DivBackward1>)
# loss:  tensor(0.4045, grad_fn=<DivBackward1>)
# loss:  tensor(0.4686, grad_fn=<DivBackward1>)
# loss:  tensor(0.3343, grad_fn=<DivBackward1>)
# loss:  tensor(0.3231, grad_fn=<DivBackward1>)
# loss:  tensor(0.3563, grad_fn=<DivBackward1>)
# loss:  tensor(0.3133, grad_fn=<DivBackward1>)
# Accuracy of the network on the 40 training surfaces at epoch 29 : 95.0
# -----------
# ***********
# -----------

# %%
# plot on x axis the epchs and on y axis the accuracy

# plot the loss
fig, ax = plt.subplots()

ax.plot(np.arange(len(Accuracies)), Accuracies)

plt.show()

# %% [markdown]
# ## Old version

# %%
epochs = 3
dim = 3
num_sub = 3 ## how many times we subdivide each triangle for integration 

# create your optimizer
optimizer = optim.SGD(kform.parameters(), lr=1e-5)

criterion = nn.CrossEntropyLoss()

losses = torch.zeros(epochs)

labels_one_hot_shuffled = labels_one_hot_shuffled.to(torch.float32)

torch.autograd.set_detect_anomaly(True)

for e in range(epochs):
    print('epoch: ', e)
    
    correct = 0
    total = 0

    for i in range(len(surfaces_shuffled)):
        _, _, _, Emb_comp = surfaces_shuffled[i]
        l = labels_one_hot_shuffled[i]
        
        X = kf.form2cochain(kform, Emb_comp, simplices, dim, num_sub, det, k )
        X = torch.reshape(X, (len(simplices), 1))
        X.retain_grad() 
        X = mlp(X)
        X = X.sum(0)
        X.retain_grad()
        #X.grad = None
        # softmax
        sm = torch.nn.functional.softmax(X)
        #print('softmax = ',sm)
        loss = criterion(sm,l) 
        #print("loss: ", loss)
        #print('********')
        loss.backward(retain_graph=True)
        optimizer.step()
        optimizer.zero_grad()
        
        pred = torch.argmax(torch.nn.functional.softmax(X))
        #print('pred: ', pred)
        #print('label: ', torch.argmax(l))
        if pred == torch.argmax(l):
            correct += 1
        total += 1
        #print('correct: ', correct)

        if i % 10 == 0:
            print("number of surfaces processed: ", i)

    print('Accuracy of the network on the {} training surfaces at epoch {} : {} '.format(num_surf*3, e, (100 * correct / total)))


    print('-----------')
    print('***********')
    print('-----------')

# %% [markdown]
# # graveyard

# %%
def form2cochain(kform, phi, simplices, dim, num_sub): 
    cochain = torch.zeros(len(simplices))
    deter_tensor = build_big_deter_tensor(dim,2) ## maybe this computation can be done outside the function 
    for i in range(len(simplices)):
        simplex = simplices[i]
        phi_simplex = torch.zeros((len(simplex), dim))
        phi_simplex = phi[torch.tensor(simplex)]
        cochain[i] = kf.integral_simplex(kform, phi_simplex, deter_tensor, num_sub)

    return cochain

def form2cochain_output(kform, phi, simplices, dim, num_sub, mlp, classes = 3): 
    output = torch.zeros(len(simplices),classes)
    cochain = torch.zeros(len(simplices),1)
    deter_tensor = kf.build_big_deter_tensor(dim,2) ## maybe this computation can be done outside the function 
    
    for i in range(len(simplices)):
        simplex = simplices[i]
        phi_simplex = torch.zeros((len(simplex), dim))
        phi_simplex = phi[torch.tensor(simplex)]
        cochain[i] = kf.integral_simplex(kform, phi_simplex, deter_tensor, num_sub)

    #output = mlp(cochain)

    return cochain

# %%
def integrate_kform(kform, phi, b, det, subdivision_vert, subdivision_coefs, dim = 3, k = 2):
                    
    """ Integrate a $2$-form over $2$-simplex
    Input: 
        kform: a 2-form
        phi: a matrix containing the embedding of the vertices of the simplex in R^dim
        b: a vector containing the embedding of the basepoint of the simplex in R^dim
        det: the tensor computed by build_determinant_tensor
        dim: the dimension of the embedding space
        k: the dimension of the form
        subdivision_vert: a list of vertices of the subdivision of the simplex
        subdivision_coefs: a list of coefficients for the contribution of each vertex to the integral
        num_sub: the number of subdivisions of the simplex 
    Output:
        integral: the value of integral of the 2-form over the 2-simplex 
    """

    ## TODO: add assert to check inputs are good 

    num_sub = subdivision_vert.shape[0] ## I think num_sub**2 is the number of simplices in the subdivision 
    num_simplices = int(num_sub**2)
    integral = torch.tensor([0]).float()

    N = int(scipy.special.binom(dim,k))

    for i in range(len(subdivision_vert)): ## This is the slow part  
        p = subdivision_vert[i]
        phi_p = phi.T @ p + b
        g_p = torch.tensor([0]).float() 
        for ind in range(N):
            g_p+= kform(phi_p)[ind] * torch.matmul(torch.matmul(phi[0], det[ind]), phi[1].T)
        cof = subdivision_coefs[i]
        integral += torch.mul(g_p,cof)

    vol = torch.tensor([1/(2*(num_sub**2))]).float() ## I'm not sure we need this but double check the theory 
    return (integral* vol )/num_simplices 


def form2cochain(kform, surface_dict, deter_tensor,subivision_vert, subdivision_coeffs, dim =3 ,k = 2): 

    """From a 2-form we get a 2-cochain by integrating the form over every 2-simplex in the simplicial complex
    Input:
        kform: a 2-form
        surface_dict: a dictionary containing all of the information of the triangulated surface in R^dim
        deter_tensor: the tensor computed by build_determinant_tensor
        dim: the dimension of the embedding space
        k: the dimension of the form
        subivision_vert: a list of vertices of the subdivision of the simplex
        subdivision_coefs: a list of coefficients for the contribution of each vertex to the integral
    
    Output:
        cochain: a 2-cochain
     """


    Emb_comp = surface_dict['points']
    assert Emb_comp.shape[1] == dim, "The dimension of the embedding space is not equal to the number of columns of the matrix Emb_comp"

    cochain = torch.zeros(len(surface_dict['simplices']))
    for i in range(len(surface_dict['simplices'])):
     
        phi_simplex = surface_dict['Phi'][i]
        b_simplex = surface_dict['b'][i]
        cochain[i] = integrate_kform(kform, phi_simplex, b_simplex, deter_tensor, subivision_vert, subdivision_coeffs, dim, k)

    return cochain
